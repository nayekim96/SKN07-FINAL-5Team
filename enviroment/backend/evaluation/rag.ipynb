# %%
import os
import sys
import pandas as pd
import chromadb
import chromadb.utils.embedding_functions as embedding_functions
from chromadb.config import Settings
from langchain.schema import Document
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader

# %%
df = pd.read_csv('./data/job_opening.csv')

# %%
documents = [Document(page_content=f"{row['rec_idx']}: {row['jd_text']} {row['recruit_title']} {row['recruit_kewdcdnm']} {row['company_place']} {row['career']} {row['education']}", metadata={"id": idx}) for idx, row in df.iterrows()]

# %%
# chromadb 연결

client = chromadb.HttpClient(host='43.202.186.183', port=8000, settings=Settings(allow_reset=True, anonymized_telemetry=False))

# %%
# openai 임베딩 생성
from dotenv import load_dotenv
import chromadb.utils.embedding_functions as embedding_functions

load_dotenv()

embeddings = embedding_functions.OpenAIEmbeddingFunction(
        api_key=os.environ.get('OPENAI_API_KEY'),
        model_name="text-embedding-ada-002"
    )

# %%
#collection 생성

from datetime import datetime

collection = client.create_collection(
    name="job_opening", 
    embedding_function=embeddings,
    metadata={
        "description": "for recommend job_opening",
        "created": str(datetime.now())
    }  
)

# %%
collection = client.get_collection(name="job_opening")

# %%
documents[0].metadata['id']
# Out:
# 0

# %%
# 문서 삽입
try:
    for document in documents:
        if document.page_content is not None:
            collection.add(
                documents = [document.page_content],
                ids = [str(document.metadata['id'])]
            )
except Exception as e:
    print(f"An error occurred: {e}")

# %%
db = Chroma(client=client, collection_name="job_opening",embedding_function=embeddings)

# %%
retriever = db.as_retriever(
    search_type="similarity",
    search_kwargs={'k': 20}
)

docs = retriever.invoke("데이터 분석 AI 모델링 감성 분석 영화 추천 시스템 개발 IT 빅데이터와 관련된 문서를 찾고싶어.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[140], line 6
#       1 retriever = db.as_retriever(
#       2     search_type="similarity",
#       3     search_kwargs={'k': 20}
#       4 )
# ----> 6 docs = retriever.invoke("데이터 분석 AI 모델링 감성 분석 영화 추천 시스템 개발 IT 빅데이터와 관련된 문서를 찾고싶어.")
#
# File ~/miniconda3/envs/langchain/lib/python3.10/site-packages/langchain_core/retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     257 _kwargs = kwargs if self._expects_other_args else {}
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#     263     result = self._get_relevant_documents(input, **_kwargs)
#
# File ~/miniconda3/envs/langchain/lib/python3.10/site-packages/langchain_core/vectorstores/base.py:1077, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1075 _kwargs = self.search_kwargs | kwargs
#    1076 if self.search_type == "similarity":
# -> 1077     docs = self.vectorstore.similarity_search(query, **_kwargs)
#    1078 elif self.search_type == "similarity_score_threshold":
#    1079     docs_and_similarities = (
#    1080         self.vectorstore.similarity_search_with_relevance_scores(
#    1081             query, **_kwargs
#    1082         )
#    1083     )
#
# File ~/miniconda3/envs/langchain/lib/python3.10/site-packages/langchain_community/vectorstores/chroma.py:350, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     333 def similarity_search(
#     334     self,
#     335     query: str,
#    (...)
#     338     **kwargs: Any,
#     339 ) -> List[Document]:
#     340     """Run similarity search with Chroma.
#     341
#     342     Args:
#    (...)
#     348         List[Document]: List of documents most similar to the query text.
#     349     """
# --> 350     docs_and_scores = self.similarity_search_with_score(
#     351         query, k, filter=filter, **kwargs
#     352     )
#     353     return [doc for doc, _ in docs_and_scores]
#
# File ~/miniconda3/envs/langchain/lib/python3.10/site-packages/langchain_community/vectorstores/chroma.py:439, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     431     results = self.__query_collection(
#     432         query_texts=[query],
#     433         n_results=k,
#    (...)
#     436         **kwargs,
#     437     )
#     438 else:
# --> 439     query_embedding = self._embedding_function.embed_query(query)
#     440     results = self.__query_collection(
#     441         query_embeddings=[query_embedding],
#     442         n_results=k,
#    (...)
#     445         **kwargs,
#     446     )
#     448 return _results_to_docs_and_scores(results)
#
# AttributeError: 'OpenAIEmbeddingFunction' object has no attribute 'embed_query'

# %%
docs
# Out:
# [Document(metadata={}, page_content="공고ID: 50139999, 공고내용: \n채용공고 상세\n[코스닥기업] 업무시스템 개발자 채용2005년 04월 02일에 설립된 응용 소프트웨어 개발 및 공급업업종의 AI기반데이터 분석,로우코드솔루션 개발,공급사업을 하는 코스닥,중소기업,주식회사기업 입니다.모집부문 및 상세내용모집부문상세내용업무시스템 개발자2명ㆍ솔루션 기반 업무시스템 개발ㆍ솔루션 개발 리더자격요건주요업무담당업무ㆍ자격요건ㆍ관련 경력 5년 이상ㆍ DB, SQL 및 데이터 지식 보유자ㆍjavascript 사용 가능자우대사항ㆍ동종업계 관련 업무 경험자ㆍ솔루션을 활용한 포털 및 업무시스템 구축 경험자ㆍ고객사 사용자 관점의 우수한 커뮤니케이션 스킬 보유자\nㆍ기타 필수 사항\n우대사항근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:ㆍ근무지역:(135-080) 서울 강남구 역삼동 708-8 세방빌딩 신관17층 -\xa0서울 2호선 선릉역에서 1분 이내전형절차 서류전형(※서류합격자에 한하여간단한 전화인터뷰 진행) 1차면접 2차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 3월 4일 (화) 17시~ 2025년 3월 31일 (월) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:이력서\xa0및 자기소개서(사진, 연락처, 희망연봉 반드시 기재요망)경력기술서 (프로젝트별 Skill inventory 포함 우대)ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.\n, 공고제목: [코스닥기업] 업무시스템 개발자 채용, 직무구분: ['웹개발', '데이터시각화', '솔루션', '컨설턴트', 'BI 엔지니어'], 지역: 서울 강남구, 경력구분: 경력 5년↑ · 정규직, 학력: 대학(2,3년)↑"),
#  Document(metadata={}, page_content="공고ID: 50283013, 공고내용: \n채용공고 상세\n서비스 기획자\xa0채용(주)덴컴은 국/내외 치과 분야에 AI Solution을 탑재한 인공지능 차트를 제공하는 기업으로,2016년부터 사업을 시작하여 2022년 의료기기, 바이오 분야에 시리즈A 투자 60억을 받았으며,2024년 2월 100억원 규모의 시리즈A2 투자 유치에 성공하였습니다.이로서 덴컴의 누적 투자 유치 금액은 160억원을 넘어섰으며, 의료 분야의 혁신을 이끌며 급격하게 성장하고 있습니다.현재 덴컴에는 AI 핵심 솔루션 및 글로벌 제품 개발을 위한 국/내외 석, 박사 출신의 인력들이 함께하고 있으며,해당 분야에 특허권(영상, 음성AI 등)과 자체 AI 엔진 개발 등의 보유 기술력으로 글로벌 제품 상용화 단계에 접어 들고 있습니다.또한, 수평적인 조직 문화와 애자일 업무 문화, 자유로운 사내 호칭제도, 임직원이 서로 원활하게 커뮤니케이션 하며 공동의 목표를 향해 한 방향으로 소통하는 문화를 가지고 있으며 대부분의 직원들이 20~30대로 젊고 건강한 조직문화를 가지고 있습니다.가장 빠르게, 안정적으로 성장하고 있는 덴컴에서 세계적인 기업으로 성장해 나갈 인재를 채용하니 많은 지원 바랍니다.모집부문 및 상세내용세부 내용담당 업무- 음성 인식 AI 기술이 적용된 EDR(Electronic Dental Record) 솔루션 기획/설계/운영- 사용자 분석, 요구사항 수집, 기획안 작성, 정책 수립 등 전반적인 서비스 기획- 가설 검증 기반의 서비스 기능 고도화- 지표로 실행의 결과를 파악하고, 후속 기획과 활성화 방안 모색- 마켓 트렌드 및 유사 제품 리서치자격 요건-\xa0학력 : 대졸 이상-\xa0기획/PM/PO/운영 경험 3년 이상-\xa0프로덕트 기획 초기부터 참여하여 상용화/운영까지 경험한 분-\xa0개발, 디자인, 전략, 영업 등 다양한 이해 관계자들과 원활한 커뮤니케이션이 가능한 분우대 사항-\xa0음성 인식 AI기술에 대해 관심이 있는 분-\xa0의료 산업에 대한 경험이 있는 분-\xa0유사 서비스 사용 및 리서치에 적극적인 분-\xa0UX 기획 및 개선 경험이 있는 분-\xa0Figma, Google Workspace, Microsoft Office, Confluence, Jira, Slack 등 협업 툴 사용에 익숙한 분전형 절차ㆍ서류전형 > 1차면접 > 2차면접 > 최종합격ㆍ면접일정은 추후 통보됩니다.유의 사항ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.\n, 공고제목: 음성인식 AI 혁신을 이끌 [서비스기획 담당자] 모집, 직무구분: ['Figma', '상품기획', '서비스기획', '앱기획', '웹기획'], 지역: 서울 강남구 외, 경력구분: 경력 3년↑ · 정규직, 학력: 대학교(4년)↑"),
#  Document(metadata={}, page_content="공고ID: 50282974, 공고내용: \n채용공고 상세\n서비스 기획 팀장\xa0채용(주)덴컴은 국/내외 치과 분야에 AI Solution을 탑재한 인공지능 차트를 제공하는 기업으로,2016년부터 사업을 시작하여 2022년 의료기기, 바이오 분야에 시리즈A 투자 60억을 받았으며,2024년 2월 100억원 규모의 시리즈A2 투자 유치에 성공하였습니다.이로서 덴컴의 누적 투자 유치 금액은 160억원을 넘어섰으며, 의료 분야의 혁신을 이끌며 급격하게 성장하고 있습니다.현재 덴컴에는 AI 핵심 솔루션 및 글로벌 제품 개발을 위한 국/내외 석, 박사 출신의 인력들이 함께하고 있으며,해당 분야에 특허권(영상, 음성AI 등)과 자체 AI 엔진 개발 등의 보유 기술력으로 글로벌 제품 상용화 단계에 접어 들고 있습니다.또한, 수평적인 조직 문화와 애자일 업무 문화, 자유로운 사내 호칭제도, 임직원이 서로 원활하게 커뮤니케이션 하며 공동의 목표를 향해 한 방향으로 소통하는 문화를 가지고 있으며 대부분의 직원들이 20~30대로 젊고 건강한 조직문화를 가지고 있습니다.가장 빠르게, 안정적으로 성장하고 있는 덴컴에서 세계적인 기업으로 성장해 나갈 인재를 채용하니 많은 지원 바랍니다.모집부문 및 상세내용세부 내용담당 업무- 서비스기획팀 리딩-\xa0음성 인식 AI 서비스 기획 책임 관리-\xa0음성 인식 AI 기술이 적용된\xa0AI medical solution\xa0솔루션 프로젝트 관리-\xa0프로젝트 관련 일정 기획-\xa0가설 검증 기반의 서비스 기능 고도화 계획 수립-\xa0서비스 관련 주요 이슈 개선 계획 수립자격 요건-\xa0학력 : 대졸 이상-\xa0서비스기획 경력 8년 이상-\xa0팀 운영 및 프로젝트 리딩 경력자-\xa0IT 프로젝트 수행 경력자우대 사항-\xa0애자일 방법론을 통한 프로젝트 리딩 경험 보유자-\xa0의료 산업에 대한 경험이 있는 분-\xa0IT 서비스기획 경력자전형 절차ㆍ서류전형 > 1차면접 > 2차면접 > 최종합격ㆍ면접일정은 추후 통보됩니다.유의 사항ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.\n, 공고제목: 음성인식 AI 혁신을 이끌 [서비스기획 팀장] 모집, 직무구분: ['Figma', '상품기획', '서비스기획', '앱기획', '웹기획'], 지역: 서울 강남구 외, 경력구분: 경력 8년↑ · 정규직, 학력: 대학교(4년)↑"),
#  Document(metadata={}, page_content="공고ID: 50197577, 공고내용: \n채용공고 상세\nㅡ\n㈜경동도시가스\n 데이터 분석 및 관련\n사업개발 전문가 채용\n데이터 분석 및 관련사업 전문가 (정규직)\n\xa0\n담당업무 \n\nㆍ데이터 관련 시장동향 분석\nㆍ신규 사업기회 발굴 및 \nㆍ관련 투자사 사업지원\nㆍ빅데이터, AI분석, 서비스 알고리즘 개발 및 활용 전략 수립\nㆍ데이터 분석 및 결합, 전처리, 탐색 등 기술 지원\n자격요건\n\nㆍ학력 : 경영,통계,회계 및 데이터 관련 분야 석사이상 학위 소지자\n\xa0\xa0\xa0* 데이터 관련분야(전산학, 응용소프트웨어, 정보통신 공학 등)\nㆍ해당전공 석사 학위 취득 후, 해당분야 최소 4년이상 경력자\n우대사항\nㆍ빅데이터 분석 및 AI 서비스 개발 10년차 이상 선호\nㆍ공공, 국책과제 수행 및 사업화 경험 필수\nㆍ기타 데이터 신규 서비스 개발, 사업기회 발굴 등 사업화 경험 우대\n필요역량\nㆍPython, R, JAVA 등 1개이상 프로그래밍 능력(필수)\nㆍ상업용 DB 분석 관련 자격/경력 보유 우대\nㆍ데이터 전처리,탐색, 분석기반 기술\n모집인원\nㆍ1명 (정규직)\n근무조건\nㆍ근무형태 : 정규직\nㆍ급여 : 연봉 8,000만원 수준 (최종 합격자와 별도 협의)\nㆍ근무시간 : 주 5일 근무, 09:00 ~ 18:00\nㆍ근무지역 : 경동도시가스 본사 (울산광역시 북구 진장동 939)\nㆍ데이터 사업 관련, 출장이 잦을 수 있음.\nㆍ투자사 관리 및 대외 협력업무 출장 필수(출장비 지원)\n전형절차\nSTEP1\n서류전형\n(4월 중)\n\xa0\nSTEP2\n온라인\n인적성검사(4월 중)\n\xa0\nSTEP3\n실무면접\n(5월 초)\n\xa0\nSTEP4\n임원면접\n(5월 중순)\n\xa0\nSTEP5\n최종합격자\n발표\n 서류전형 제출서류\nㆍ입사지원서 및 자기소개서(당사 양식)\nㆍ최종학교 졸업(예정) 증명서 및 성적 증명서, 기타 자격증 증빙 자료\n입사지원서 양식\n자기소개서 양식\n개인정보 이용 동의서\n 접수기간 및 방법 \n ㆍ접수기간 : \n \n2025년 03월 17일(월) ~ 03월 30일(일), 2주 \n\nㆍ접수방법 : 사람인 온라인 입사지원\n문의처\nㆍ경동도시가스 인사담당자 김종훈 과장(052-219-5317, kjh3253@kdgas.co.kr)\n\n※ 채용 서류 반환에 관한 고지\n\xa0\xa01. 이 고지는 ｢채용절차의 공정화에 관한 법률｣ 제11조 제5항에 따른 것으로, \n\xa0\xa0\xa0\xa0최종합격자를 제외한 구직자를 대상으로 기 제출한 채용 서류를 반환 받을 수 있습니다.\n\xa0\xa02. 당사 채용에 응시한 구직자 중 최종 합격이 되지 못한 구직자는 채용 여부가 확정된 날로부터 \n\xa0\xa0\xa0\xa014일에서 180일 사이의 기간 동안 제출한 채용 서류의 반환을 청구할 수 있음을 알려드립니다. \n\xa0\xa0\xa0 \xa0다만, 홈페이지 또는 전자우편으로 제출된 경우나 구직자가 당사의 요구 없이 자발적으로 제출한 경우에는 \n\xa0\xa0 \xa0\xa0그러하지 아니하며, 천재지변이나 그 밖에 당사에게 책임 없는 사유로 채용 서류가 멸실된 경우에는 \n\xa0\xa0\xa0\xa0 반환한 것으로 봅니다.\n\xa0\xa03. 채용 서류 반환 청구를 하려는 구직자는 채용 서류 반환청구서\n\xa0\xa0\xa0\xa0 [채용절차의 공정화에 관한 법률 시행규칙 별지 제3호 서식]를 작성하여 당사 \n\xa0\xa0\xa0\xa0 이메일(kjh3253@kdgas.co.kr)로 제출하면, \n\xa0\xa0\xa0\xa0 제출이 확인된 날로부터 14일 이내에 지정한 주소지로 등기우편을 통하여 발송해 드립니다.\n\xa0\xa04. 당사는 구직자의 반환 청구에 대비하여 구인자 반환의 청구기간까지 채용 서류를 보관하게 되며, \n\xa0\xa0\xa0\xa0 그때까지 채용 서류의 반환을 청구하지 아니할 경우에는 ｢개인정보 보호법｣에 따라 지체 없이 채용 서류 일체를\n\xa0\xa0\xa0\xa0 파기할 예정입니다.\n, 공고제목: 경동도시가스 데이터 분석 및 관련 사업개발 전문가 채용, 직무구분: ['데이터분석가', '데이터엔지니어', 'DBA', 'IT컨설팅', 'ICT컨설팅'], 지역: 울산 북구, 경력구분: 신입 · 경력 · 정규직, 학력: 석사↑"),
#  Document(metadata={}, page_content="공고ID: 50234809, 공고내용: \n채용공고 상세\n한국정보통신진흥협회 2025년 상반기 신규인력 채용\n협회·단체 > 협회\n기획·전략 > 직무·직업 > 기획\n기획·전략 > 직무·직업 > 문화기획\n기획·전략 > 직무·직업 > 브랜드기획\n기획·전략 > 직무·직업 > 사업기획\n기획·전략 > 직무·직업 > 상품기획\n기획·전략 > 직무·직업 > 전략기획\n기획·전략 > 전문분야 > 신사업기획\n마케팅·홍보·조사 > 전문분야 > 통계/분석\n회계·세무·재무 > 직무·직업 > 전산회계\n총무·법무·사무 > 전문분야 > 사무행정\n총무·법무·사무 > 전문분야 > 전산총무\n총무·법무·사무 > 전문분야 > 정보처리\nIT개발·데이터 > 직무·직업 > 데이터분석가\nIT개발·데이터 > 직무·직업 > 데이터엔지니어\nIT개발·데이터 > 직무·직업 > 백엔드/서버개발\nIT개발·데이터 > 직무·직업 > 보안관제\nIT개발·데이터 > 직무·직업 > 보안컨설팅\nIT개발·데이터 > 직무·직업 > 정보보안\nIT개발·데이터 > 직무·직업 > CISO\nIT개발·데이터 > 직무·직업 > ICT컨설팅\nIT개발·데이터 > 직무·직업 > IT컨설팅\nIT개발·데이터 > 직무·직업 > SE(시스템엔지니어)\nIT개발·데이터 > 전문분야 > 네트워크\nIT개발·데이터 > 전문분야 > 데이터라벨링\nIT개발·데이터 > 전문분야 > 데이터마이닝\nIT개발·데이터 > 전문분야 > 데이터시각화\nIT개발·데이터 > 전문분야 > 방화벽\nIT개발·데이터 > 전문분야 > 정보통신\nIT개발·데이터 > 전문분야 > 취약점진단\nIT개발·데이터 > 전문분야 > IDC\nIT개발·데이터 > 전문분야 > IIS\nIT개발·데이터 > 전문분야 > ISMS\nIT개발·데이터 > 전문분야 > S/W\nIT개발·데이터 > 전문분야 > Windows\nIT개발·데이터 > 기술스택 > Apache\nIT개발·데이터 > 기술스택 > C#\nIT개발·데이터 > 기술스택 > C++\nIT개발·데이터 > 기술스택 > CentOS\nIT개발·데이터 > 기술스택 > C언어\nIT개발·데이터 > 기술스택 > Java\nIT개발·데이터 > 기술스택 > Javascript\nIT개발·데이터 > 기술스택 > Unix\n연구·R&D > 직무·직업 > 인증심사원\n, 공고제목: 한국정보통신진흥협회 2025년 상반기 신규인력 채용, 직무구분: ['데이터분석가', '데이터엔지니어', '백엔드/서버개발', '보안컨설팅', '정보보안'], 지역: 서울전체, 경력구분: 신입 · 경력 · 계약직, 학력: 학력무관"),
#  Document(metadata={}, page_content="공고ID: 50235054, 공고내용: \n채용공고 상세\n \n, 공고제목: [미래아이엔씨] 마케팅 개발기획자 모집(경력직), 직무구분: ['기술지원', '백엔드/서버개발', '웹개발', '머신러닝', '마케팅기획'], 지역: 서울 금천구 외, 경력구분: 경력 3년↑ · 정규직, 학력: 대학교(4년)↑"),
#  Document(metadata={}, page_content="공고ID: 50235424, 공고내용: \n채용공고 상세\n, 공고제목: [브이드림] 전략사업팀 과제 기획 및 운영 부분 채용(서울), 직무구분: ['경영기획', '사업기획', '데이터분석', '사업개발', '사업관리'], 지역: 서울 서초구, 경력구분: 경력 3년↑ · 계약직, 학력: 학력무관"),
#  Document(metadata={}, page_content="공고ID: 50222180, 공고내용: \n채용공고 상세\n\xa0\n 모집부문 및 상세 내용\n구분\nㆍ팔로알토 영업(부장급)\n 직무내용\nㆍPalo Alto Solution 기반의 사이버 보안 분야에서 매출 성장을 이끌기 위한 효과적인 영업 전략을 \n\xa0\xa0\xa0개발하고 실행\n\t\tㆍ신규 비즈니스 기회를 식별하고, 회사의 고객 및 파트너 기반을 확장\n\t\tㆍ잠재 고객에게 우리의 IT인프라 솔루션 Portfolio와 서비스를 설명\n\t\tㆍ내부 팀과 협력하여 고객 만족도와 프로젝트 성공을 보장\n\t\tㆍ제안서, 계약서, 협상을 준비하고 제시하여 거래 성사\n\t\tㆍ업계 동향, 경쟁사 활동, 새로운 시장 수요에 대해 최신 정보 유지\n\t\tㆍ회사에서 설정한 영업 목표와 KPI를 이해하고 초과 달성\n\tㆍ업계 행사, 컨퍼런스 및 네트워킹 기회에 참여하여 회사를 홍보하고 리드를 생성\n상세내용\n지원자격\n\t\tㆍ사이버 보안 Solution 기반 사이버 보안 Infra 분야에서 영업 목표를 달성한 입증된 경력 보유\n\t\tㆍ업무관련 기술 및 산업동향에 대한 강력한 이해\n\t\tㆍ총판업무 경험, 벤더와 파트너십 유지 관리\n\t\tㆍ보안, 비보안 파트너사에 지속적으로 벤더 최신 정보 제공 가능\n\t\tㆍ자기 주도적, 결과 지향적이고, 독립적으로 일할 수 있는 능력 및 팀의 일원으로 일할 수 있는 능력\n\t\tㆍ고객 또는 파트너사의 요구 분석 및 문제 해결 능력\n\n우대사항\n\t\tㆍ사이버 보안 Solution 기반 경력 보유자 우대(포티넷, 안랩 방확벽 등)\n\t\tㆍPalo Alto networks 솔루션 사업 경험자 우대\n\t\tㆍ팔로알토와 경쟁하는 벤더사의 총판에서 영업 경험 \n\n근무형태\n\tㆍ정규직\n인원\nㆍ보안/AI 사업팀 1명\n구분\nㆍ팔로알토 프리세일즈(차장~이사급)\n 직무내용\nㆍ영업팀과 고객 연결, 기술적 전문성 및 통찰력을 제공하여 새로운 비즈니스를 확보\n\t\tㆍ고객 요구 분석, 기술 솔루션 정의, IT 인프라 통합 설계\n\t\tㆍ제품 데모 및 기술 프레젠테이션 제공\n\t\tㆍ제안서와 작업 명세서(SOW), 규격(Specification) 작성\n\t\tㆍ제품 및 서비스 이해, 비기술 이해관계자에게 기술 개념 설명\n\t\tㆍ고객 관계 구축 및 영업 기회 모색\n상세내용\n지원자격\n\t\tㆍ프리세일즈 또는 기술 컨설팅 역할의 경험자\n\t\tㆍ사이버 보안 프리세일즈 또는 기술 컨설팅 역할의 경험자\n\t\tㆍ뛰어난 커뮤니케이션 및 프레젠테이션 능력\n\t\tㆍ복잡한 기술 개념을 비기술적 이해관계자에게 설명할 수 있는 능력\n\t\tㆍ분석 및 문제 해결 능력\n\t\tㆍ팀의 일원으로, 팀원 및 파트너사와 함께 일할 수 있는 능력\n\t\tㆍ빠르게 변화하는 환경에서의 유연성과 적응력\n\n우대사항\n\t\tㆍ사이버보안 인프라 스트럭쳐, SASE ,XDR, Cloud DR, Network보안\n\t\tㆍPalo Alto 솔루션 Presales, SA/TA 경험자 우대\n\n근무형태\n\t\tㆍ정규직\n인원\nㆍ보안/AI 사업팀 1명\n구분\nㆍSI 영업(과장~차장급)\n 직무내용\nㆍSolution 기반의 SI(AI, BigData, Infra SI) 분야에서 매출 성장을 이끌기 위한 효과적인 영업 전략을 \n\xa0\xa0\xa0개발하고 실행\n\t\tㆍ신규 비즈니스 기회를 식별하고, 회사의 고객 및 파트너 기반을 확장\n\t\tㆍ잠재 고객에게 우리의 IT인프라 솔루션 Portfolio와 서비스를 설명\n\t\tㆍ내부 팀과 협력하여 고객 만족도와 프로젝트 성공을 보장\n\t\tㆍ제안서, 계약서, 협상을 준비하고 제시하여 거래 성사\n\t\tㆍ업계 동향, 경쟁사 활동, 새로운 시장 수요에 대해 최신 정보 유지\n\t\tㆍ회사에서 설정한 영업 목표와 KPI를 이해하고 초과 달성\n\tㆍ업계 행사, 컨퍼런스 및 네트워킹 기회에 참여하여 회사를 홍보하고 리드를 생성 \n상세내용\n지원자격\n\t\tㆍ10년 전후의 영업 경력\n\t\tㆍDell, HPE 등 서버, 스토리지 분야에서 영업 목표를 달성한 입증된 경력 보유\n\t\tㆍ업무관련 기술 및 산업동향에 대한 강력한 이해\n\t\tㆍ뛰어난 의사소통, 협상 능력\n\t\tㆍ고객의 주요 의사결정자와 관계를 구축하고 유지할 수 있는 능력\n\t\tㆍ자기 주도적, 결과 지향적이고, 독립적으로 일할 수 있는 능력 및 팀의 일원으로 일할 수 있는 능력\n\t\tㆍ고객 또는 파트너사의 요구 분석 및 문제 해결 능력\n\n우대사항\n\t\tㆍ서버 총판업무 7년 이상의 경력 보유자 우대\n\t\t\n\n\t\t비고\n\t\tㆍ인프라 SI영업, AI Infra 장비(GPU서버 등) 영업\n\t\tㆍDell의 솔루션을 기반으로 다른 솔루션을 합쳐서 고객에게SI인프라 솔루션을 영업\n\n근무형태\n\tㆍ정규직\n인원\nㆍ보안/AI 사업팀 1명\n구분\nㆍ시스템엔지니어(차장~부장급)\n 직무내용\nㆍ영업팀과 고객을 연결하고, 비즈니스 요구에 맞춘 인프라 솔루션을 제안하며, IT 인프라를 설계, \n\xa0\xa0\xa0구현, 유지 관리\n\t\tㆍ제품 데모와 기술 프레젠테이션 제공\n\t\tㆍ제안서와 작업 명세서(SOW), 규격(Specification) 작성\n\t\tㆍ하드웨어, 소프트웨어, 네트워크 등 복잡한 시스템을 관리 및 문제 해.\n\t\tㆍ하드웨어 및 소프트웨어 설치\n\t\tㆍ시스템 성능 모니터링\n\tㆍ최신 기술 동향을 습득하여 적용 및 제안, 파트너교육 실시\n상세내용\n자격요건\n\t\tㆍ경력 3년이상(차장~부장급)\n\n우대사항\n\t\tㆍNvidia/Intel/AMD GPU/Accelerator, Openstack 또는 Container,\n\xa0 \xa0기반의 인프라 관련 솔루션 설치 및 운영 경험자 우대\n\n비고\n\t\tㆍDell설치&지원 업무를 중심으로하나, 프리세일즈 성격이 가미됨.\n\n근무형태\n\tㆍ정규직\n인원\nㆍ시스템엔지니어(Kubernetes/OpenStack) 1명 \n\t\tㆍ시스템엔지니어(GPU/AI) 1명\n구분\nㆍDell Tech 총판 채널 영업(신입)\n 직무내용\nㆍDell Technologies 총판 채널 및 고객 영업 \n\tㆍSUSE 총판영업, 채널 및 고객 영업\n상세내용\n자격요건 \n\t\tㆍ신입 (졸업예정자 가능) \n\t\tㆍIT산업에 대해 이해도가 높으신 분\n\n우대조건 \n\t\tㆍ영어 소통 가능한자 우대\n\t\tㆍ컴퓨터 활용 우수자\n\n근무형태\n\tㆍ계약직 1년(정규직 전환 가능)\n인원\nㆍ시스템사업2팀 1명\n구분\nㆍDell Tech 총판 채널 영업(경력)\n 직무내용\nㆍDell Technologies 총판 채널 및 고객 영업 \nㆍSUSE 총판영업, 채널 및 고객 영업\n상세내용\n자격요건 \n\t\tㆍIT 영업 경력 3년 이상\n\t\tㆍIT산업에 대해 이해도가 높으신 분\n\n우대조건 \n\t\tㆍ영어 소통 가능한자 우대\n\t\tㆍ컴퓨터 활용 우수자\n\n근무형태\n\tㆍ계약직 1년(정규직 전환 가능)\n인원\nㆍ시스템사업2팀 1명\n근무조건 \nㆍ근무형태 : 정규직(수습기간 3개월)\n\xa0\xa0\xa0* Dell Tech. 총판 영업 : 계약직 1년(정규직 전환 가능)\nㆍ근무시간 : 주 5일(월~금) 09:00 ~ 18:00\nㆍ급여 : 면접 후 결정\n\xa0\n, 공고제목: 각 부문별 신입/경력 모집, 직무구분: ['유지보수', '정보보안', 'SE(시스템엔지니어)', '네트워크', '솔루션'], 지역: 서울 강남구, 경력구분: 신입 · 경력 · 정규직 외, 학력: 대학(2,3년)↑"),
#  Document(metadata={}, page_content="공고ID: 50179159, 공고내용: \n채용공고 상세\n[D.WAY] 컨설팅본부 마이데이터 과금체계 수립 신입 모집2021년 09월 03일에 설립된 응용 소프트웨어 개발 및 공급업업종의 응용 소프트웨어 개발 및 공급업사업을 하는 중소기업 입니다.모집부문 및 상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년)경영컨설턴트 0명주요업무담당업무ㆍ지원자격ㆍ경력 : 신입 \nㆍ기타 필수 사항\n우대사항근무조건ㆍ근무형태:정규직(수습기간)-4개월ㆍ근무일시:ㆍ근무지역:(06109) 서울 강남구 봉은사로37길 5 캠프지(논현동) - 서울 9호선 언주 에서 300m 이내전형절차 서류전형 1차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 3월 7일 (금) 10시~ 2025년 4월 6일 (일) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.\n, 공고제목: [D.WAY] 컨설팅본부 마이데이터 과금체계 수립 신입 모집, 직무구분: ['경영컨설팅'], 지역: 서울 강남구, 경력구분: 신입 · 정규직, 학력: 대학교(4년)↑"),
#  Document(metadata={}, page_content="공고ID: 50283028, 공고내용: \n채용공고 상세\n[알리바바닷컴코리아] 사업개발(BD) 보조 채용기업 소개 또는 채용 안내를 작성해보세요. 불필요시 '기업 소개'를 한번더 클릭하면 소개 영역이 숨겨집니다.*본 채용공고는 알리익스프레스(AliExpress)와 무관한 알리바바닷컴(Alibaba.com) 공고임을 안내드립니다.모집부문 및 상세내용모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년)사업개발 0명주요업무담당업무ㆍ주요 업무- 신규 시장 및 비즈니스 기회 발굴 및 분석- 전략적 파트너십 구축 및 협상 진행- 사업 확장을 위한 신규 고객 및 B2B 네트워크 개발- 내·외부 이해관계자와 협력하여 사업 전략 수립 및 실행- 데이터 기반 시장 분석 및 성장 전략 수립- 경쟁사 및 업계 동향 조사 및 인사이트 제공필수 요건- 1년 이상의 사업기획 및 사업개발 경험이 있는 분- 본사 및 유관 부서와의 협업을 위한 뛰어난 커뮤니케이션 능력을 보유한 분- 비즈니스 레벨의 중국어 필수우대 사항- IT, 플랫폼, 크로스보더 이커머스 업계 경험이 있는 분- SQL 및 데이터 분석 역량을 갖춘 분- 능동적이고 핵심을 파악하여 문제해결 능력이 뛰어난 분채용형태: 계약직 (업무 성과에 따른 전환가능)지원자격ㆍ경력 : 무관 (신입도 지원 가능)\nㆍ기타 필수 사항\n우대사항근무조건ㆍ근무형태:계약직(정규직 전환가능)-1년ㆍ근무일시:ㆍ근무지역:(04631) 서울 중구 퇴계로 100 스테이트타워 남산 - 서울 4호선 명동 에서 500m 이내전형절차 서류전형 1차면접 2차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 3월 19일 (수) 13시~ 2025년 5월 18일 (일) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.\n, 공고제목: [알리바바닷컴코리아] 사업개발(BD) 보조 채용, 직무구분: ['사업기획', '전략기획', 'PM(프로젝트매니저)', '사업개발', '사업관리'], 지역: 서울 중구, 경력구분: 경력무관 · 계약직, 학력: 대학교(4년)↑"),
#  Document(metadata={}, page_content="공고ID: 50274739, 공고내용: \n채용공고 상세\n정보통신 사업관리 및 수행 업무관련 경력 및 신입 모집.2017년 09월 14일에 설립된 컴퓨터시스템 통합 자문 및 구축 서비스업업종의 컴퓨터 시스템 통합 자문 및 구축 서비스업사업을 하는 중소기업 입니다.모집부문 및 상세내용모집부문상세내용공통 자격요건ㆍ학력 : 고졸 이상사업관리(PM/PL)SI(System Integration) 사업부 2명회사 소개\xa0ㆍ\xa0지속적인 혁신과 성장을 통해 업계를 선도하는 기업으로 자리 잡고 있습니다. 창립 이후 매년 꾸준한 성장세를 기록하며, 고객과 파트너사에게 신뢰받는 기업으로 발전해가고 있으며, 단순한 성장이 아닌 지속 가능한 성장을 목표로 합니다. 사회적 책임 이행, 윤리 경영을 바탕으로 기업의 사회적 가치를 실현하고 있으며, 함께 성장하는 기업 문화를 만들어 가기 위해 함꼐 소통을\xa0 중요시 하는 회사입니다.ㆍ주요 사업으로는 '공공사업(군,광공서 등) 및 민간사업(기업, 대학교 등)' 정보통신과 관련된 주요 업무를 계약 진행 및 수행하며, 다수의 기업들과 파트너쉽을 유지해 가고 있는 회사라고 자부합니다.\xa0\xa0ㆍ 밝고 긍정적인 에너지가진 직원들과 함께 발마춰서 갈수 있는 인재를 모십니
#  Document(metadata={}, page_content='공고ID: 50261016, 공고내용: \n채용공고 상세\nProduct 서비스부\xa0 B2B 서비스기획자\xa0채용 (경력)\xa0"직원이 행복해야 회사가 행복합니다."날리지큐브는 직원이 행복한 회사를 꿈꿉니다.자신의 꿈을 실현할 수 있을 뿐만 아니라 회사와 함께 도전하는 것이 즐거운업무 환경을 유지하기 위해 자유로운 조직문화를 만들어가고 있습니다.직원들의 워라밸을 적극 지지하며 지원도 아끼지 않고 있습니다.직원의 행복한 삶을 위해 회사가 할 수 있는 일이 무엇인지항상 고민하고 함께 제도를 만들어 갑니다.날리지큐브와 함께 성장하고 꿈을 키울 날큐인을 공개 모집합니다.\xa0날리지큐브는 구글 워크스페이스 공식 리셀러로 Google Workspace를 자사 업무 포털인 KCUBE ON과 연동하여 기업의 업무효율을 극대화 하는 초연결 업무포털 서비스를 제공합니다.\xa0매년 100% 이상 성장하고 있는 KCUBE ON과 함께 성장할 인재를 기다립니다. 상단의 사람인 입사지원을 통해 제출해주세요.협업에 포털을 더하다업무포털, 케이큐브온for Google Workspace\xa0모집부문\n\xa0모집부문\n\xa0담당업무 및 상세 요건\n\n클라우드 서비스기획 부문모집인원: 0명\n\xa0담당업무\xa0- 자사 B2B 클라우드 업무포털 "KCUBE ON" 서비스 신규 / 고도화 기획\xa0\xa0- Google Workspace 연동 서비스 기획\xa0\xa0- Front(웹, 모바일 앱) / Backend UI/UX 설계\xa0\xa0- 기능 테스트 및 운영 지원 (전담 운영 파트 있으며, 필요 시 지원)\xa0지원자격\xa0- 클라우드 서비스 또는 관련 분야에서 4년 이상의 경력 보유자\xa0- Backend 기획 업무 경험\xa0\xa0- IT 및 SaaS에 대한 높은 이해도\xa0- 프로토타입 툴(Axure, Adobe XD 등) 활용 역량 보유자\xa0-\xa0Google Workspace 유경험자\xa0\xa0\xa0우대사항\xa0- 웹/모바일 신규 서비스 기획 및 런칭 경험\xa0- API 활용 연동 서비스 기획 경험\xa0- 최신 UI/UX 트렌드에 대한 관심 및 이해도 높은 분\xa0- 사용자 경험 개선을 위한 데이터 모니터링 및 분석영량 있으신분\xa0\n근무조건\xa0ㆍ근무형태 : 정규직\xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0(수습기간 3개월 적용 - 급여 및 처우에 대한 차별은 없어요. 서로를 알아가는 시간일 뿐!)ㆍ근무일시 : 주 5일(월~금), 탄력근무제 사용(8:00 ~ 10:00 사이 30분 단위로 지정 가능)ㆍ급\xa0 \xa0 \xa0 여 : 회사 내규에 따름ㆍ근무지역 : 서울특별시 서초구 서초중앙로 14, 진로빌딩 15층ㆍ휴가 : 눈치 보지 않고 사용하는 휴가 반차, 반반차 지원ㆍ넉넉한 점심시간 : 11시 30분~13시00분\xa0ㆍ초역세권 : 서울 3호선 남부터미널역 4번출구에서 느긋~하게 걸어서 2분 (4-1 출구 개통시 1분 미만)ㆍ리프레시 : 4년 만근 시 5일 리프레시 휴가 이후 3년 만근시 3주 휴가 + 휴가비 혹은 7년 만근 시 4주 휴가 및 휴가비\xa0복리후생\xa0전형절차\xa0\xa0제출서류\xa0ㆍ이력서, 자기소개서\xa0접수방법 및 기간\xa0ㆍ접수방법 :\xa0사람인 온라인 입사지원ㆍ접수기간 : 2025년 3월 17일 ~ 2025년 4월 16일 \xa0기타 유의사항\xa0ㆍ입사지원 서류에 허위 사실이 발견될 
3/30 실시간 채팅 14:00~18:00\n\n(실시간 채팅이 아니더라도 질문은 월금 9:00~18:00 내 언제든 가능합니다.)\n현업담당자들에게 직무관련 궁금사항을 직접 물어보시고 답변을 받으세요!\n아성다이소 오픈채팅방\n영업본부\n온라인사업본부\n상품본부\n물류본부\nTQC본부\n\xa0\nIT본부\n인사총무본부\n재경본부\n법무지원부\n\xa0\n아성 오픈채팅방\n\xa0\n\xa0\n디자인\n상품안전관리\n해외영업\n\xa0\n\xa0\n아성HMP 오픈채팅방\n\xa0\n\xa0\n\xa0\n\xa0\n해외영업/영업관리\n\xa0\n\xa0\n\xa0\n\xa0\n캠퍼스 채용상담회\n일시\n시간\n장소\n3월 20일 (목)\n10:00~17:00\n홍익대학교\n홍문관 로비\n3월 26일 (수)\n10:00~17:00\n고려대학교\n418기념관 3층\n10:00~17:00\n중앙대학교\n310관 2층 로비\n10:00~17:00\n숙명여자대학교\n진리관 106호\n급여 및 복리후생\nㆍ대졸 신입 초임 4,700만원 (인센티브 별도)\nㆍ복리후생: 일부 복리후생은 관계사별로 상이할 수 있습니다. \n\xa0\n공통 자격요건\n· 최소학력 : 대졸 이상[2025년 8월 졸업 예정자 및 기 졸업자]\n· 국가보훈대상자는 관련법에 의거하여 우대\n· 병역필 또는 면제자로 해외여행 및 건강상 결격사유가 없는 자\n제출서류\n· 입사지원서 : 사진첨부(최근 6개월 이내 사진 첨부), 긴급연락처, 희망연봉 등 반드시 기재할 것\n· 자기소개서\n· 경력기술서(경력 지원자의 경우 작성 필수, 신입의 경우 인턴 및 직무 관련 경험 기술)\n· 회사(시장)분석 리포트(서류전형 합격자에 한함)\n· 포트폴리오(제출 필수 직무에 한함)\n· 최종학력 졸업증명서, 성적증명서, 경력증명서 각 1부(최종합격자에 한함)\n· 보훈대상자 취업지원대상자 증명서(최종합격자 및 해당자에 한함)\n제출방법\n구분\n채용홈페이지\n비고\nhttp://daiso.saramin.co.kr/\nㆍ입사지원서 : 채용홈페이지 內 관계사별 모집공고를 통해 \n\u3000온라인 작성 및 제출\nㆍ포트폴리오 제출 직무 : 제출처 및 상세 내용은 모집부문 \n\u3000'자세히 보기'에서 확인\n\u3000[필수] 아성다이소 _ 영업_매장디자인, 온라인_카피라이터\n\u3000\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 아성 : 디자인_캐릭터 상품 및 패키지 디자인\n\u3000[권장] 아성다이소 : 온라인_서비스기획\n기타사항\nㆍ입사지원서 내 입력한 자격/경력사항 등은 입사 후 증빙자료 제출이 가능해야 하며, \n\xa0\xa0 기재한 내용이 허위임이 밝혀질 시 채용이 취소됩니다. \nㆍ현 주소와 전화번호, e-mail은 연락 가능한 곳으로 정확히 기재 바랍니다.\n[채용서류 반환 관련]\n채용 전형과정에서 직접 제출받은 서류(채용홈페이지나 전자우편을 통해 제출된 서류 제외)의 경우, \n지원자가 희망하는 경우 서류를 반환해드리고 있습니다. \n\xa0* 반환가능 기간 : 최종 합격 발표 후 14일이 지난 후부터 60일 이내 \n\xa0* 신청방법 : 채용홈페이지 '질문하기' 게시판을 통해 반환청구 요청\n\u3000(이름, 수험번호, 지원직무, 연락처, 우편번호, 주소 기재 必) \n\xa0▶ 요청일로부터 14일 이내 요청서류 반환(등기/소포 배송_반환 시 발생하는 비용은 회사에서 부담)\n접수마감일\nㆍ2025년 3월 30일(일) 23:59\n※ 마감일 당일은 홈페이지 접속 인원이 급증할 것으로 예상되오니, \n\u3000마감일 이전에 충분히 여유를 가지고 등록하여 주시기 바랍니다.\n※ 입사지원서 작성 시, 항목별 작성요령을 필히 확인해주시기 바랍니다.\xa0 \n※ 입사지원서 작성 완료 후 최종제출 하셔야 입사지원이 완료됩니다.\n, 공고제목: 2025년 상반기 아성다이소 및 관계사 신입/경력사원 공개채용, 직무구분: ['백엔드/서버개발', '웹개발', '정보보안', '프론트엔드', 'IT컨설팅'], 지역: 서울 강남구 외, 경력구분: 신입 · 경력 · 정규직, 학력: 대학교(4년)↑"),
#  Document(metadata={}, page_content="공고ID: 50111469, 공고내용: \n채용공고 상세\n땡큐 베리 매치 사람인 | 취업, 채용, 커리어 매칭 플랫폼\n\xa0\n(주)아이엔티매니지먼트\n\t\t\t데이터센터 운영 채용 공고\n함께 할 구성원을 찾습니다\n#정규직\xa0\xa0#경력사원\n 데이터센터 운영 \n 모집인원 0명 \n 담당업무\n\nㆍ데이터센터 내 인프라 점검\n\t\xa0\xa0\xa0- IDC 내 서버 / 네트워크 관제전파\n\t\xa0\xa0\xa0- 서버룸 환경 점검\n\nㆍ서버 HW/SW 설치 지원 및 장애 대응\n\t\xa0\xa0\xa0- 서버 HW 인프라 설치 지원 -x86 서버\n\t\xa0\xa0\xa0- 서버 SW설치 지원 - 윈도우 서버, 리눅스계열 위주\n\t\xa0\xa0\xa0- HW 장애 Trouble Shooting 지원 - x86 서버 하드웨어 장애 관련\n\n\tㆍ네트워크 HW 설치 지원\n\xa0\xa0\xa0- 보안장비,네트워크 스위치 설치 지원 - 방화벽,웹방화벽,L4,L3,L2 스위치 등\n\nㆍ고객 지원\n\xa0\xa0\xa0- 고객 기술 문의 응대\n\xa0\xa0\xa0- 고객 CS 응대\n\xa0\xa0\xa0- 고객사의 서버룸 출입관리\n 자격요건\n\nㆍ긍정적이고 적극적인 마인드를 보유하고 있으며, 주변인과 커뮤니케이션이 원활하신 분\n\tㆍ유관 경력 2년 이상\n 우대사항\nㆍ관련 전공/학과 이수자\n\tㆍ관련 자격증 소지자\n\tㆍIDC 근무 경험 있으신 분\n근무조건을 확인해주세요\nㆍ근무형태 : 정규직(수습기간 3개월)\n\tㆍ근무시간 : 주 5일(월~금) , 9시 ~ 18시\n\tㆍ근무지역 : 서울시 마포구 월드컵북로 416,14층\n\tㆍ급여조건 : (주40시간/퇴직금별도)\xa0협의\n임직원을 위한 지원을 아끼지 않아요\nㆍ스낵바 및 커피, 음료 제공\n\tㆍ체력단력비 및 통신비 일부 지원\n\tㆍ명절선물 지급\n\tㆍ장기근속 포상\n\tㆍ업무 관련 교육비 지원\n\tㆍ매년 떠나는 해외 워크샵\n함께 하기 위한 여정이에요\n제출서류를 체크해주세요\nㆍ이력서, 자기소개서\n접수기간 및 방법\nㆍ접수기간 : 2025년 03월 28일 마감\n\tㆍ접수방법 : 사람인 온라인 입사지원\n아래 내용을 꼭 유의해주세요\nㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다
과 열정이 있는 분\nㆍ커뮤니케이션 역량이 뛰어나며 긍정적인 에너지가 많은 분\n웹 UX/UI\n기획자\n(0명) \nㆍShopify 혹은 카페24 기반\nㆍ이커머스 사이트 구축/운영 기획\nㆍ웹사이트 구조 및 플로우 기획,\nㆍ주요 화면 Mock-up, UX/UI 설계\nㆍ클라이언트 커뮤니케이션\nㆍ프로젝트 일정 관리(WBS),\nㆍ제작팀 관리\nㆍ리스크 관리 및 이슈 해결방안 도출\n자격요건\n[신입]\nㆍShopify 혹은 카페24 기반 구축/운영 경험 (필수)\nㆍ기획, 디자인, 프론트엔드(웹퍼블리싱), 백엔드\nㆍ전반적인 업무 범위 및 연계에 대한 이해 및 컨트롤 역량\nㆍ프로젝트 수행계획, 진척관리 방법론/툴 사용 역량 및\n\xa0\xa0\xa0적절한 방법 제안 능력\nUX/UI\n디자이너\n(0명) \nㆍ이커머스 플랫폼 구축\n\xa0\xa0\xa0 UX/UI 디자인 제작\nㆍ오픈마켓, 종합몰, 브랜드몰,\n\xa0\xa0\xa0 멀티/편집샵 디자인 제작\nㆍPC/MO web, APP UX/UI\n\xa0\xa0\xa0 디자인 제작\n자격요건\nㆍ경력 : 신입/경력1~15년\nㆍ피그마(figma), 스케치(sketch), 제플린(zeplin)의\n\xa0\xa0\xa0\n원활한 사용 필수(우대)\nㆍ이커머스 플랫폼 UX/UI 디자인 제작 유경험자\nㆍ백오피스(인트라넷, 어드민) 플랫폼 UX/UI 디자인 제작 유경험자\nㆍ브랜드와 플랫폼의 이커머스 디자인 가이드를 이해 가능자\nㆍ커뮤니케이션이 원활하고 팀웍이 좋은 분\n\n우대사항\nㆍWeb Agency/이커머스 플랫폼 출신의 디자이너 우대\n마케팅\n디자이너\n(계약직,\n연장 가능)\nㆍ이커머스 플랫폼의 마케팅 콘텐츠\n\xa0\xa0\xa0 제작 (브랜딩, 이벤트, 프로모션) 및\n\xa0\xa0\xa0\n운영(배너, SNS) 디자인\n자격요건\nㆍ경력 5~10년\nㆍ기본적인 Adobe 툴(포토샵, 일러스트레이터)\n\xa0\xa0\xa0 사용이 가능하신 분\nㆍ이커머스 사이트 제작 가이드에 대한 기본적인 이해와\n\xa0\xa0\xa0 콘텐츠 디자인 제작 경험이 있으신 분\nㆍ전반적인 트렌드에 관심이 높으며 다양한 마케팅 디자인 업무\n\xa0\xa0\xa0 (브랜딩, 프로모션/이벤트, 광고, 배너)에 대한 크리에이티브 한\n\xa0\xa0\xa0\n역량을 갖추신 분\nㆍ타부서 간 유연하고 원활한 커뮤니케이션 역량과\n\xa0\xa0\xa0 협업 능력을 보유하신 분 \n\n우대사항\nㆍ영상 편집 작업 가능하신 분 우대\n근무조건\n근무형태\n정규직, 계약직\n근무지역\n(06141) 서울 강남구 테헤란로29길 8, 2층-10층\n복리후생\n급여제도\n퇴직연금, 4대 보험\n\n선물\n명절선물/귀향비, 웰컴키트 지급\n교육/생활\n자기계발비 지원, 음료제공(차, 커피)\n\n근무 환경\n카페테리아\n조직문화\n자유복장, 자유로운 연차사용\n\n리프레시\n연차, 경조휴가제, 산전 후 휴가, 육아휴직\n전형절차\n※ 포트폴리오 중심의 기획/디자인 역량과 마인드에 대한 질의 및 직무 리뷰\n※ 합격자 개별 통보 후 면접이 진행됩니다.\n접수기간 및 방법\n접수기간 \xa0 \n \n채용시 마감 \n접수방법 \xa0 사람인 온라인 입사지원\n이력서양식 \xa0자유 형식의 이력서 (희망연봉, 출근가능일 기재 必)\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0포트폴리오 첨부 必 (pdf/파일명 : 이름_경력_파일이름)\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0간단한 자기소개서 (반드시 경력 중심으로 기재)\n유의사항\n유의사항 \xa0입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.\n, 공고제목: 각 부문별 채용, 직무구분: ['백엔드/서버개발', '웹개발', '웹마스터', '유지보수', '퍼 ...
#  Document(metadata={}, page_content="공고ID: 50283259, 공고내용: \n채용공고 상세\n저희는 체험교육 분야에서 차별화된 경험과 뛰어난 품질을 제공하는 콘텐츠기업입니다. \n단기 프로젝트 진행응 위해 아래와 같은 유니티 3D 그래픽 및 타임라인 개발을 도움주실 프리랜서를 모집하고 있습니다.\n\n[모집분야] 유니티(Unity 3D) 그래픽개발 및 타임라인 제작\n\n[주요업무] \n- 유니티(Unity 3D)를 활용한 게임 그래픽 개발을 담당합니다.\n- 타임라인 제작 및 애니메이션 작업을 수행합니다.\n- 게임 환경 및 캐릭터 모델링을 진행합니다.\n- 그래픽 요소의 최적화 및 성능 개선을 책임집니다.\n- 다양한 팀과 협업하여 프로젝트 목표를 달성합니다.\n\n[자격요건] \n- 유니티(Unity 3D)를 이용한 그래픽 개발 경험이 있습니다.\n- 게임 개발 관련 학위 또는 이에 상응하는 경력을 보유하고 있습니다.\n- 타임라인 및 애니메이션 제작에 대한 이해가 깊습니다.\n- 3D 모델링 및 텍스처링에 능숙합니다.\n- 팀 협업 및 커뮤니케이션 능력이 뛰어납니다.\n\n[우대사항] \n- 관련 업계에서 3년 이상의 경력을 보유한 분을 우대합니다.\n- AR/VR 프로젝트 경험이 있으신 분을 환영합니다.함께하기 위한 방법접수기간 : 2025년 03월 19일 (수)14시 00분 ~ 2025년 03월 25일 (화) 15시 00분접수방법 : 사람인 입사지원이력서양식 : 사람인 이력서 양식함께하기 위한 여정서류전형1차면접최종합격\n, 공고제목: [유니티 그래픽개발 및 타임라인 제작] 게임기획 경력직, 직무구분: ['게임개발', '그래픽디자인', '애니메이터', '콘텐츠디자인', '3D디자인'], 지역: 대전 유성구, 경력구분: 경력 2년↑ · 아르바이트 외, 학력: 학력무관")]

# %%
rec_ids = [ doc.page_content.split(', ')[0].split(': ')[1] for doc in docs ]

# %%
rec_ids
# Out:
# ['50139999',
#  '50197577',
#  '50283013',
#  '50235054',
#  '50282974',
#  '50179159',
#  '50213940',
#  '50235424',
#  '50102550',
#  '50234809',
#  '50222180',
#  '50283469',
#  '50042760',
#  '50283455',
#  '50235644',
#  '50111469',
#  '50215717',
#  '50254512',
#  '50207599',
#  '50274739']

# %%
from langchain_core.runnables import RunnableMap
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain_core.runnables import RunnableLambda

llm = ChatOpenAI(
        model="gpt-4",
        temperature=0
    )

# %%
prompt = PromptTemplate.from_template(
    """
    당신은 채용 공고 추천 전문가입니다.
    참고 문서:
    {docs}

    질문:
    {question}
    """

    )

# chat_prompt_template = ChatPromptTemplate.from_messages([human_message_prompt])

# %%
# 체인 생성
chain = LLMChain(
    llm=llm, 
    prompt=prompt)

retriever_chain = RunnableLambda(lambda x: {"docs": retriever.get_relevant_documents(x["question"])})

full_chain = RunnableMap({
    "question": lambda x: x["question"],
    "docs": lambda x: retriever.get_relevant_documents(x["question"])
}) | chain

# # invoke 호출
# response = chain.invoke({
#     "docs": docs
# })
# result = response['text']

response = full_chain.invoke({"question": """
    사용자 정보는 다음과 같습니다:
    - 지원 직무: 데이터 분석, AI 모델링, 감성 분석, 영화 추천 시스템 개발
    - 관심 산업/도메인: IT, 빅데이터
    - 기술/스킬: Python, SQL, R, Scikit-learn, TensorFlow, PyTorch, Pandas, NumPy, Jupyter, Git, Docker, Tableau, MySQL, MongoDB, Hadoop(HDFS), Spark, Google Colab, AWS EC2 & S3, KoNLPy, Word2Vec, Streamlit
    - 학력 및 경력: 고려대학교 컴퓨터학과 졸업, 신입
    - 희망 지역: 서울특별시 강남구

    ### 출력 형식 예시
    1. **직무명**: AI 분석가 (신입)
    - **산업 분야**: IT 서비스 / 빅데이터 분석
    - **필요 기술**: Python, TensorFlow, SQL, Pandas
    - **공고 링크**: https://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=50139999
    - **추천 사유**: 사용자의 AI 모델링 및 분석 역량과 유사한 프로젝트 경험이 있고, 기술 스택이 직무 요건과 높은 일치율을 보입니다. 서울 강남 지역에 위치해 있어 위치 조건도 부합합니다.

    사용자 정보에 가장 적합한 채용 공고 20개를 추천해주세요.
    출력 형식과 동일한 형식으로 출력해주세요.
"""})

print(response)
# Out:
# {'question': '\n    사용자 정보는 다음과 같습니다:\n    - 지원 직무: 데이터 분석, AI 모델링, 감성 분석, 영화 추천 시스템 개발\n    - 관심 산업/도메인: IT, 빅데이터\n    - 기술/스킬: Python, SQL, R, Scikit-learn, TensorFlow, PyTorch, Pandas, NumPy, Jupyter, Git, Docker, Tableau, MySQL, MongoDB, Hadoop(HDFS), Spark, Google Colab, AWS EC2 & S3, KoNLPy, Word2Vec, Streamlit\n    - 학력 및 경력: 고려대학교 컴퓨터학과 졸업, 신입\n    - 희망 지역: 서울특별시 강남구\n\n    ### 출력 형식 예시\n    1. **직무명**: AI 분석가 (신입)\n    - **산업 분야**: IT 서비스 / 빅데이터 분석\n    - **필요 기술**: Python, TensorFlow, SQL, Pandas\n    - **공고 링크**: https://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=50139999\n    - **추천 사유**: 사용자의 AI 모델링 및 분석 역량과 유사한 프로젝트 경험이 있고, 기술 스택이 직무 요건과 높은 일치율을 보입니다. 서울 강남 지역에 위치해 있어 위치 조건도 부합합니다.\n\n    사용자 정보에 가장 적합한 채용 공고 20개를 추천해주세요.\n    출력 형식과 동일한 형식으로 출력해주세요.\n', 'docs': [Document(metadata={}, page_content="공고ID: 50197577, 공고내용: \n채용공고 상세\nㅡ\n㈜경동도시가스\n 데이터 분석 및 관련\n사업개발 전문가 채용\n데이터 분석 및 관련사업 전문가 (정규직)\n\xa0\n담당업무 \n\nㆍ데이터 관련 시장동향 분석\nㆍ신규 사업기회 발굴 및 \nㆍ관련 투자사 사업지원\nㆍ빅데이터, AI분석, 서비스 알고리즘 개발 및 활용 전략 수립\nㆍ데이터 분석 및 결합, 전처리, 탐색 등 기술 지원\n자격요건\n\nㆍ학력 : 경영,통계,회계 및 데이터 관련 분야 석사이상 학위 소지자\n\xa0\xa0\xa0* 데이터 관련분야(전산학, 응용소프트웨어, 정보통신 공학 등)\nㆍ해당전공 석사 학위 취득 후, 해당분야 최소 4년이상 경력자\n우대사항\nㆍ빅데이터 분석 및 AI 서비스 개발 10년차 이상 선호\nㆍ공공, 국책과제 수행 및 사업화 경험 필수\nㆍ기타 데이터 신규 서비스 개발, 사업기회 발굴 등 사업화 경험 우대\n필요역량\nㆍPython, R, JAVA 등 1개이상 프로그래밍 능력(필수)\nㆍ상업용 DB 분석 관련 자격/경력 보유 우대\nㆍ데이터 전처리,탐색, 분석기반 기술\n모집인원\nㆍ1명 (정규직)\n근무조건\nㆍ근무형태 : 정규직\nㆍ급여 : 연봉 8,000만원 수준 (최종 합격자와 별도 협의)\nㆍ근무시간 : 주 5일 근무, 09:00 ~ 18:00\nㆍ근무지역 : 경동도시가스 본사 (울산광역시 북구 진장동 939)\nㆍ데이터 사업 관련, 출장이 잦을 수 있음.\nㆍ투자사 관리 및 대외 협력업무 출장 필수(출장비 지원)\n전형절차\nSTEP1\n서류전형\n(4월 중)\n\xa0\nSTEP2\n온라인\n인적성검사(4월 중)\n\xa0\nSTEP3\n실무면접\n(5월 초)\n\xa0\nSTEP4\n임원면접\n(5월 중순)\n\xa0\nSTEP5\n최종합격자\n발표\n 서류전형 제출서류\nㆍ입사지원서 및 자기소개서(당사 양식)\nㆍ최종학교 졸업(예정) 증명서 및 성적 증명서, 기타 자격증 증빙 자료\n입사지원서 양식\n자기소개서 양식\n개인정보 이용 동의서\n 접수기간 및 방법 \n ㆍ접수기간 : \n \n2025년 03월 17일(월) ~ 03월 30일(일), 2주 \n\nㆍ접수방법 : 사람인 온라인 입사지원\n문의처\nㆍ경동도시가스 인사담당자 김종훈 과장(052-219-5317, kjh3253@kdgas.co.kr)\n\n※ 채용 서류 반환에 관한 고지\n\xa0\xa01. 이 고지는 ｢채용절차의 공정화에 관한 법률｣ 제11조 제5항에 따른 것으로, \n\xa0\xa0\xa0\xa0최종합격자를 제외한 구직자를 대상으로 기 제출한 채용 서류를 반환 받을 수 있습니다.\n\xa0\xa02. 당사 채용에 응시한 구직자 중 최종 합격이 되지 못한 구직자는 채용 여부가 확정된 날로부터 \n\xa0\xa0\xa0\xa014일에서 180일 사이의 기간 동안 제출한 채용 서류의 반환을 청구할 수 있음을 알려드립니다. \n\xa0\xa0\xa0 \xa0다만, 홈페이지 또는 전자우편으로 제출된 경우나 구직자가 당사의 요구 없이 자발적으로 제출한 경우에는 \n\xa0\xa0 \xa0\xa0그러하지 아니하며, 천재지변이나 그 밖에 당사에게 책임 없는 사유로 채용 서류가 멸실된 경우에는 \n\xa0\xa0\xa0\xa0 반환한 것으로 봅니다.\n\xa0\xa03. 채용 서류 반환 청구를 하려는 구직자는 채용 서류 반환청구서\n\xa0\xa0\xa0\xa0 [채용절차의 공정화에 관한 법률 시행규칙 별지 제3호 서식]를 작성하여 당사 \n\xa0\xa0\xa0\xa0 이메일(kjh3253@kdgas.co.kr)로 제출하면, \n\xa0\xa0\xa0\xa0 제출이 확인된 날로부터 14일 이내에 지정한 주소지로 등기우편을 통하여 발송해 드립니다.\n\xa0\xa04. 당사는 구직자의 반환 청구에 대비하여 구인자 반환의 청구기간까지 채용 서류를 보관하게 되며, \n\xa0\xa0\xa0\xa0 그때까지 채용 서류의 반환을 청구하지 아니할 경우에는 ｢개인정보 보호법｣에 따라 지체 없이 채용 서류 일체를\n\xa0\xa0\xa0\xa0 파기할 예정입니다.\n, 공고제목: 경동도시가스 데이터 분석 및 관련 사업개발 전문가 채용, 직무구분: ['데이터분석가', '데이터엔지니어', 'DBA', 'IT컨설팅', 'ICT컨설팅'], 지역: 울산 북구, 경력구분: 신입 · 경력 · 정규직, 학력: 석사↑"), Document(metadata={}, page_content="공고ID: 50139999, 공고내용: \n채용공고 상세\n[코스닥기업] 업무시스템 개발자 채용2005년 04월 02일에 설립된 응용 소프트웨어 개발 및 공급업업종의 AI기반데이터 분석,로우코드솔루션 개발,공급사업을 하는 코스닥,중소기업,주식회사기업 입니다.모집부문 및 상세내용모집부문상세내용업무시스템 개발자2명ㆍ솔루션 기반 업무시스템 개발ㆍ솔루션 개발 리더자격요건주요업무담당업무ㆍ자격요건ㆍ관련 경력 5년 이상ㆍ DB, SQL 및 데이터 지식 보유자ㆍjavascript 사용 가능자우대사항ㆍ동종업계 관련 업무 경험자ㆍ솔루션을 활용한 포털 및 업무시스템 구축 경험자ㆍ고객사 사용자 관점의 우수한 커뮤니케이션 스킬 보유자\nㆍ기타 필수 사항\n우대사항근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:ㆍ근무지역:(135-080) 서울 강남구 역삼동 708-8 세방빌딩 신관17층 -\xa0서울 2호선 선릉역에서 1분 이내전형절차 서류전형(※서류합격자에 한하여간단한 전화인터뷰 진행) 1차면접 2차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 3월 4일 (화) 17시~ 2025년 3월 31일 (월) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:이력서\xa0및 자기소개서(사진, 연락처, 희망연봉 반드시 기재요망)경력기술서 (프로젝트별 Skill inventory 포함 우대)ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.\n, 공고제목: [코스닥기업] 업무시스템 개발자 채용, 직무구분: ['웹개발', '데이터시각화', '솔루션', '컨설턴트', 'BI 엔지니어'], 지역: 서울 강남구, 경력구분: 경력 5년↑ · 정규직, 학력: 대학(2,3년)↑"), Document(metadata={}, page_content="공고ID: 50235054, 공고내용: \n채용공고 상세\n  ...

# %%
response
# Out:
# {'question': '\n    사용자 정보는 다음과 같습니다:\n    - 지원 직무: 데이터 분석, AI 모델링, 감성 분석, 영화 추천 시스템 개발\n    - 관심 산업/도메인: IT, 빅데이터\n    - 기술/스킬: Python, SQL, R, Scikit-learn, TensorFlow, PyTorch, Pandas, NumPy, Jupyter, Git, Docker, Tableau, MySQL, MongoDB, Hadoop(HDFS), Spark, Google Colab, AWS EC2 & S3, KoNLPy, Word2Vec, Streamlit\n    - 학력 및 경력: 고려대학교 컴퓨터학과 졸업, 신입\n    - 희망 지역: 서울특별시 강남구\n\n    ### 출력 형식 예시\n    1. **직무명**: AI 분석가 (신입)\n    - **산업 분야**: IT 서비스 / 빅데이터 분석\n    - **필요 기술**: Python, TensorFlow, SQL, Pandas\n    - **공고 링크**: https://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=50139999\n    - **추천 사유**: 사용자의 AI 모델링 및 분석 역량과 유사한 프로젝트 경험이 있고, 기술 스택이 직무 요건과 높은 일치율을 보입니다. 서울 강남 지역에 위치해 있어 위치 조건도 부합합니다.\n\n    사용자 정보에 가장 적합한 채용 공고 20개를 추천해주세요.\n    출력 형식과 동일한 형식으로 출력해주세요.\n',
#  'docs': [Document(metadata={}, page_content="공고ID: 50197577, 공고내용: \n채용공고 상세\nㅡ\n㈜경동도시가스\n 데이터 분석 및 관련\n사업개발 전문가 채용\n데이터 분석 및 관련사업 전문가 (정규직)\n\xa0\n담당업무 \n\nㆍ데이터 관련 시장동향 분석\nㆍ신규 사업기회 발굴 및 \nㆍ관련 투자사 사업지원\nㆍ빅데이터, AI분석, 서비스 알고리즘 개발 및 활용 전략 수립\nㆍ데이터 분석 및 결합, 전처리, 탐색 등 기술 지원\n자격요건\n\nㆍ학력 : 경영,통계,회계 및 데이터 관련 분야 석사이상 학위 소지자\n\xa0\xa0\xa0* 데이터 관련분야(전산학, 응용소프트웨어, 정보통신 공학 등)\nㆍ해당전공 석사 학위 취득 후, 해당분야 최소 4년이상 경력자\n우대사항\nㆍ빅데이터 분석 및 AI 서비스 개발 10년차 이상 선호\nㆍ공공, 국책과제 수행 및 사업화 경험 필수\nㆍ기타 데이터 신규 서비스 개발, 사업기회 발굴 등 사업화 경험 우대\n필요역량\nㆍPython, R, JAVA 등 1개이상 프로그래밍 능력(필수)\nㆍ상업용 DB 분석 관련 자격/경력 보유 우대\nㆍ데이터 전처리,탐색, 분석기반 기술\n모집인원\nㆍ1명 (정규직)\n근무조건\nㆍ근무형태 : 정규직\nㆍ급여 : 연봉 8,000만원 수준 (최종 합격자와 별도 협의)\nㆍ근무시간 : 주 5일 근무, 09:00 ~ 18:00\nㆍ근무지역 : 경동도시가스 본사 (울산광역시 북구 진장동 939)\nㆍ데이터 사업 관련, 출장이 잦을 수 있음.\nㆍ투자사 관리 및 대외 협력업무 출장 필수(출장비 지원)\n전형절차\nSTEP1\n서류전형\n(4월 중)\n\xa0\nSTEP2\n온라인\n인적성검사(4월 중)\n\xa0\nSTEP3\n실무면접\n(5월 초)\n\xa0\nSTEP4\n임원면접\n(5월 중순)\n\xa0\nSTEP5\n최종합격자\n발표\n 서류전형 제출서류\nㆍ입사지원서 및 자기소개서(당사 양식)\nㆍ최종학교 졸업(예정) 증명서 및 성적 증명서, 기타 자격증 증빙 자료\n입사지원서 양식\n자기소개서 양식\n개인정보 이용 동의서\n 접수기간 및 방법 \n ㆍ접수기간 : \n \n2025년 03월 17일(월) ~ 03월 30일(일), 2주 \n\nㆍ접수방법 : 사람인 온라인 입사지원\n문의처\nㆍ경동도시가스 인사담당자 김종훈 과장(052-219-5317, kjh3253@kdgas.co.kr)\n\n※ 채용 서류 반환에 관한 고지\n\xa0\xa01. 이 고지는 ｢채용절차의 공정화에 관한 법률｣ 제11조 제5항에 따른 것으로, \n\xa0\xa0\xa0\xa0최종합격자를 제외한 구직자를 대상으로 기 제출한 채용 서류를 반환 받을 수 있습니다.\n\xa0\xa02. 당사 채용에 응시한 구직자 중 최종 합격이 되지 못한 구직자는 채용 여부가 확정된 날로부터 \n\xa0\xa0\xa0\xa014일에서 180일 사이의 기간 동안 제출한 채용 서류의 반환을 청구할 수 있음을 알려드립니다. \n\xa0\xa0\xa0 \xa0다만, 홈페이지 또는 전자우편으로 제출된 경우나 구직자가 당사의 요구 없이 자발적으로 제출한 경우에는 \n\xa0\xa0 \xa0\xa0그러하지 아니하며, 천재지변이나 그 밖에 당사에게 책임 없는 사유로 채용 서류가 멸실된 경우에는 \n\xa0\xa0\xa0\xa0 반환한 것으로 봅니다.\n\xa0\xa03. 채용 서류 반환 청구를 하려는 구직자는 채용 서류 반환청구서\n\xa0\xa0\xa0\xa0 [채용절차의 공정화에 관한 법률 시행규칙 별지 제3호 서식]를 작성하여 당사 \n\xa0\xa0\xa0\xa0 이메일(kjh3253@kdgas.co.kr)로 제출하면, \n\xa0\xa0\xa0\xa0 제출이 확인된 날로부터 14일 이내에 지정한 주소지로 등기우편을 통하여 발송해 드립니다.\n\xa0\xa04. 당사는 구직자의 반환 청구에 대비하여 구인자 반환의 청구기간까지 채용 서류를 보관하게 되며, \n\xa0\xa0\xa0\xa0 그때까지 채용 서류의 반환을 청구하지 아니할 경우에는 ｢개인정보 보호법｣에 따라 지체 없이 채용 서류 일체를\n\xa0\xa0\xa0\xa0 파기할 예정입니다.\n, 공고제목: 경동도시가스 데이터 분석 및 관련 사업개발 전문가 채용, 직무구분: ['데이터분석가', '데이터엔지니어', 'DBA', 'IT컨설팅', 'ICT컨설팅'], 지역: 울산 북구, 경력구분: 신입 · 경력 · 정규직, 학력: 석사↑"),
#   Document(metadata={}, page_content="공고ID: 50139999, 공고내용: \n채용공고 상세\n[코스닥기업] 업무시스템 개발자 채용2005년 04월 02일에 설립된 응용 소프트웨어 개발 및 공급업업종의 AI기반데이터 분석,로우코드솔루션 개발,공급사업을 하는 코스닥,중소기업,주식회사기업 입니다.모집부문 및 상세내용모집부문상세내용업무시스템 개발자2명ㆍ솔루션 기반 업무시스템 개발ㆍ솔루션 개발 리더자격요건주요업무담당업무ㆍ자격요건ㆍ관련 경력 5년 이상ㆍ DB, SQL 및 데이터 지식 보유자ㆍjavascript 사용 가능자우대사항ㆍ동종업계 관련 업무 경험자ㆍ솔루션을 활용한 포털 및 업무시스템 구축 경험자ㆍ고객사 사용자 관점의 우수한 커뮤니케이션 스킬 보유자\nㆍ기타 필수 사항\n우대사항근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:ㆍ근무지역:(135-080) 서울 강남구 역삼동 708-8 세방빌딩 신관17층 -\xa0서울 2호선 선릉역에서 1분 이내전형절차 서류전형(※서류합격자에 한하여간단한 전화인터뷰 진행) 1차면접 2차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 3월 4일 (화) 17시~ 2025년 3월 31일 (월) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:이력서\xa0및 자기소개서(사진, 연락처, 희망연봉 반드시 기재요망)경력기술서 (프로젝트별 Skill inventory 포함 우대)ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.\n, 공고제목: [코스닥기업] 업무시스템 개발자 채용, 직무구분: ['웹개발', '데이터시각화', '솔루션', '컨설턴트', 'BI 엔지니어'], 지역: 서울 강남구, 경력구분: 경력 5년↑ · 정규직, 학력: 대학(2,3년)↑"),
#   Document(metadata={}, page_content="공고ID: 50235054, 공고내용: \n채용공고 상세\n \n, 공고제목: [미래아이엔씨] 마케팅 개발기획자 모집(경력직), 직무구분: ['기술지원', '백엔드/서버개발', '웹개발', '머신러닝', '마케팅기획'], 지역: 서울 금천구 외, 경력구분: 경력 3년↑ · 정규직, 학력: 대학교(4년)↑"),
#   Document(metadata={}, page_content="공고ID: 50102550, 공고내용: \n채용공고 상세\nJOIN US\n(주)유엔에이엔지니어링\n신입 및 경력직원 채용공고\n\xa0\n모집부문\n 부서\n 모집분야\n 담당업무\n 자격요건 및 우대사항\n 근무지\n전력기술팀\n사업지원\n- 전국 현장 정밀 점검, 현장 기술 지원, \n\xa0\xa0 고객사 행정 지원\n자격요건\n- 학력 : 무관\n- 경력 : 무관\n- 운전 가능자, 전기산업기사 \n\xa0\xa0 이상 소지자\n군포 본사\nDX사업팀\n네트워크\n엔지니어\n- 네트웍크 구축/운용 및 기술지원\n자격요건\n- 학력 : 초대졸 이상 (2,3년)\n- 지원경력 : 신입/경력\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 (동종업계 2년 이상)\n- 전공 : 정보통신, 컴퓨터 관련 학과\n\n우대사항\n- CCNA, CCNP, 정보통신 등 \n\xa0\xa0 관련 자격증 보유자\n- 네트워크 설계 및 제안 관련 경력자\n- 네트워크 또는 구내통신 운용 관련\n\xa0\xa0\n경력자\n- 네트워크 구축 또는 \n\xa0\xa0 정보통신공사 관련 경력자\n서울 및 수도권\nDX\n영업지원팀\nBM\n- SK브로드밴드 B2B Sales\n자격요건\n- 학력 : 무관\n- 경력 : 무관\n\n우대사항 \n- 운전면허 보유자\n서울 금천구 \n가산디지털1로 146\n대륭테크노타운 \n22차 1108호\nDC운영팀\n서초센터\n(네트워크\n운용)\n - IDC 네트워크 백본\n\xa0\xa0(Cisco, Juniper, Huawei-core급) 운용\n- IDC 입주 고객사 서비스 / \n\xa0\xa0\xa0모니터링 및 지원\n자격요건\n- 학력 : 초대졸 이상\n- 경력 : 신입/경력 (3년 이하)\n- 관련 학과 졸업 또는 교육이수\n\n우대사항\n- Cisco, Juniper,Huawei Core급\n\xa0 운용 가능 \n- 네트워크 관리사, CCNA 등\n\xa0 관련 자격증 보유자\n\n근무시간\n- 주/야 교대 근무\n\xa0\xa0(5조 3교대-3주 주간, 2주 야간)\n- 주간 : 9시~18시 or 12시~21시\n- 야간 : 21시~익일 9시\n\n서울 서초구\n법원로 1길 6, \nSKB IDC\n일산센터\n경기 고양시\n일산동구 중앙로\n1333,\nSKB IDC\n가산센터\n서울 금천구\n가산로9길 80,\nSKB IDC 가산센터\n분당센터\n경기도 성남시\n분당구\n성남대로2번길 12, SKB IDC분당센터 \n전력기술팀 \n기술지원\n- SK브로드밴드 전기설비\n\xa0\xa0\xa0(수전/발전설비 유지관리 및 기술지원)\n- SK브로드밴드 전력설비 기술지원\n자격요건\n- 학력 : 고졸(전기 관련학과)\n- 경력 : 무관\n- 전기산업기사 이상, 운전가능자\n군포 본사\n공통설비\n(천안국사) \n- 충청권 SK브로드밴드 국사 \n\xa0\xa0\xa0수전/발전설비 유지 관리\n- 천안국사 전기안전관리자 선임\n자격요건\n- 학력 : 무관\n- 경력 : 전기기사 + 경력 2년 이상 or \n\xa0\xa0\xa0전기산업기사 + 경력 4년 이상\n- 전기안전관리자 선임 가능자\n\xa0\xa0\xa0(전기산업기사 이상) \n충남 천안시 \n성정동 1018 \nSK브로드밴드\nDC운영팀 \n서초센터\n-IDC 시스템(Linux, Windows) \n\xa0\xa0\xa0운용 및 관리\n- DNS (Bind), WEB (Nginx,Apache,\n\xa0\xa0\xa0Tomcat), Database(MriaDB) 등 \n\xa0\xa0\xa0소프트웨어 운용 및 관리\n- 시스템 보안진단 및 조치, \n\xa0\xa0\xa0보안 인증심사 응대 및 지원\n자격요건\n- 학력 : 초대졸 이상\n- 경력 : 신입 및 경력(3년 이하)\n- 관련 학과 졸업 또는 교육 이수\n\n우대사항\n- 서버, 네트워크 등 \n\n\xa0 \xa0IT 인프라에 대한 지식 보유자\n- 관련 자격증 소유자 우대\n- 개발 관련 유경험자\n\xa0 \xa0(shell script, java, spring 등)\n\n근무시간\n- 주간 근무\n\xa0 \xa0(주간 : 09시 ~ 18시 / 명절/공휴일 휴무)\n SKB IDC 서초센터 (서울특별시 서초구\n법원로 1길 6,\nSK브로드밴드 )\n기획법무팀 \n법무\n- 사업관련 법률 자문 및 관계 법령 검토\n- 계약서 검토 및 계약서 관리\n- 송무 업무\n- 내부 통제 및 컴플라이언스 등\n자격요건\n- 학력 : 대졸이상(법학과 전공)\n- 경력 : 3년 이상(대리/과장 급)\n- 영문계약, 해외 법무 관리 경험자 \n 군포 본사\n구축사업팀\n/구축수도권\n지사 \nSKT\n전송장비\n시설공사\nPM\n- SKT 전송장비 구축 공사관리\n- SKT 전송장비 전원설비\n\xa0\xa0(정류기, IPD, UPS 등 설계)\n- 전송구축 전원설비 구축 공정관리\n자격요건\n- 학력 : 전문대졸 이상(전기 관련 학과)\n- 경력 : 신입 또는 전기설비분야 경력\n\xa0\xa0\xa02년이상\n- 자격 :운전면허 소지자\n\n우대사항\n- 통신관련 전원설비 공사 유경험자\n- 전기기사/전기산업기사자격증 보유자\n 군포 본사\nDC전력1팀 \n기계설비\n(IDC\n양주센터)\n- SKB IDC센터 기계설비 운용 및 유지보수\n- 기계설비(냉동기, 냉방기, 냉각탑 등) \n\xa0\xa0운용 및 유지보수\n자격요건\n- 학력 : 고졸 이상\n- 경력 : 기계설비유지관리자 법정선임\n\xa0\xa0가능자\n- 기계설비관련 자격증 소지자\n\n우대사항\n- 기계설비(냉동기, 냉방기, 냉각탑,\n\xa0\xa0각종 펌프류 등) 운용/유지보수 등 \n\xa0\xa0관련분야 경력자\n- 해당업무 관련 전공자(기계 관련학과)\n 경기도 양주시\n광적면 가납리\n440-2,\nSK Broadband\nIDC UNA\nDC전력2팀 \n기계설비\n(IDC\n분당센터)\n- SKB IDC센터 기계설비 운용 및 유지보수\n- 기계설비(냉동기, 냉방기, 냉각탑,\n\xa0\xa0각종 펌프류 등) 운용 및 유지보수\n자격요건\n- 학력 : 무관\n- 경력 : 기계설비유지관리자 법정선임\n\xa0\xa0가능자\n- 자격 : 기계설비관련 자격증 소지자\n\n우대사항\n- 기계설비(냉동기, 냉방기, 냉각탑 등) \n\xa0\xa0운용/유지보수 등 관련분야 경력자\n- 해당업무 관련 전공자(기계설비 관련학과)\n- IDC 시설관리 경력자\n경기도 성남시\n분당구 성남대로\n2번길 12\nSK Broadband\nIDC UNA\n(주)유엔에이엔지니어링 채용절차\n[주간&교대 근무자]\n * 직무별 채용전형 상이할 수 있음\n 제출서류\n - 사람인 지원\n 근무조건\n - 연봉은 회사 내규에 따름(신입일 경우 3개월간 수습급여 80%적용)\n 복리후생\n- 자녀학자금 지원(대학교)\n- 종합 건강검진\n\n- 단체상해보험\n- 복지포인트 제도\n- 출퇴근지원비 \n- 경조사 지원\n- 퇴직연금제도\n\n- 통신비 지원(SKT)\n- 설/추석 명절 상여금 지급\n 접수기간 및 방법 \n - 접수기간 :\n2025년 03월 29일 마감 \n\n- 접수방법 : 사람인 온라인 입사지원\n유의사항\n-입사지원 서류에 허위사실이 발견될 경우, 채용 확정 이후라도 채용이 취소될 수 있습니다\n, 공고제목: 신입 및 경력직원 채용공고, 직무구분: ['기술지원', '백엔드/서버개발', '웹마스터', '유지보수', '정보보안'], 지역: 경기 군포시 외, 경력구분: 신입 · 경력 · 정규직 외, 학력: 학력무관")],
#  'text': '1. **직무명**: 데이터 분석 및 관련사업 전문가 (정규직)\n    - **산업 분야**: 도시가스 / 빅데이터 분석\n    - **필요 기술**: Python, R, 데이터 분석, 빅데이터, AI분석\n    - **공고 링크**: https://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=50197577\n    - **추천 사유**: 사용자의 데이터 분석 및 AI 모델링 역량과 유사한 직무를 수행하며, Python과 R 등 사용자가 보유한 기술 스택을 요구하고 있습니다. 또한, 신규 사업기회 발굴 및 관련 투자사 사업지원 등의 업무가 포함되어 있어, 사용자의 감성 분석 및 영화 추천 시스템 개발 경험을 활용할 수 있을 것으로 보입니다.\n\n2. **직무명**: 업무시스템 개발자\n    - **산업 분야**: IT 서비스 / 솔루션 개발\n    - **필요 기술**: DB, SQL, javascript\n    - **공고 링크**: https://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=50139999\n    - **추천 사유**: 사용자가 보유한 SQL 및 데이터 지식을 활용할 수 있는 직무입니다. 또한, 서울 강남구에 위치해 있어 사용자의 희망 지역과 일치합니다.\n\n3. **직무명**: 마케팅 개발기획자\n    - **산업 분야**: IT 서비스 / 마케팅 기획\n    - **필요 기술**: 기술지원, 백엔드/서버개발, 웹개발, 머신러닝\n    - **공고 링크**: https://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=50235054\n    - **추천 사유**: 사용자의 머신러닝 및 백엔드/서버개발 역량을 활용할 수 있는 직무입니다. 또한, 마케팅 기획 직무가 포함되어 있어, 사용자의 감성 분석 및 영화 추천 시스템 개발 경험을 활용할 수 있을 것으로 보입니다.\n\n4. **직무명**: 신입 및 경력직원 채용공고\n    - **산업 분야**: IT 서비스 / 기술지원\n    - **필요 기술**: 기술지원, 백엔드/서버개발, 웹마스터, 유지보수, 정보보안\n    - **공고 링크**: https://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=50102550\n    - **추천 사유**: 사용자의 백엔드/서버개발 및 정보보안 역량을 활용할 수 있는 직무입니다. 또한, 신입으로 지원 가능하며, 다양한 직무를 경험할 수 있는 기회를 제공하고 있습니다.\n\n위 4개의 채용 공고 외에도 사용자의 역량과 일치하는 다양한 채용 공고가 있을 것으로 예상됩니다. 사용자의 세부적인 직무 희망 및 기술 스택, 희망 근무 지역 등을 고려하여 추가적인 채용 공고를 찾아보시는 것을 권장드립니다.'}

# %%
response['docs'][0].page_content.split(", ")[0].split(": ")[1]
# Out:
# '50197577'

# %%
rec_idx = [ res.page_content.split(", ")[0].split(": ")[1] for res in response['docs'] ]

# %%
rec_idx
# Out:
# ['50197577', '50139999', '50235054', '50102550']

# %%
chroma_client = chromadb.HttpClient(
    host="43.202.186.183",
    port=8000,
    settings=Settings(allow_reset=True, anonymized_telemetry=False)
)
collection = chroma_client.get_collection(name="job_position")

results = collection.get()
print("총 문서 수:", len(results['documents']))
print("예시 문서:", results['documents'][0])
# Out:
# 총 문서 수: 13853
# 예시 문서: 공고내용: [3500/중식제공]식품 쇼핑몰 MD 경력직 채용
#
# 채용공고 상세, 회사명: (주)다온미트, 직무: ['온라인MD'], 지역: 경기 하남시, 경력: 경력(년수무관) · 정규직, 학력: 학력무관
