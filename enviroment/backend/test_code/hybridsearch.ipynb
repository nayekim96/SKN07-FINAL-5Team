# %%
import os
import langchain_chroma
import openai
from openai import OpenAI
import chromadb
import fitz  # PDF에서 텍스트 추출
from dotenv import load_dotenv
from fastapi import FastAPI, UploadFile, File
from sqlalchemy import create_engine, text
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd
import psycopg2
import torch
from sklearn.metrics.pairwise import cosine_similarity
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.schema import Document
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from getpass import getpass

# .env 파일 로드
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
POST_DB_HOST = os.getenv("POST_DB_HOST")
POST_DB_NAME = os.getenv("POST_DB_NAME")
POST_DB_USER = os.getenv("POST_DB_USER")
POST_DB_PASSWD = os.getenv("POST_DB_PASSWD")
POST_DB_PORT = os.getenv("POST_DB_PORT")
# PostgreSQL 연결 엔진 생성
post_engine = create_engine(f'postgresql://{POST_DB_USER}:{POST_DB_PASSWD}@{POST_DB_HOST}:{POST_DB_PORT}/{POST_DB_NAME}')
db = psycopg2.connect(host=POST_DB_HOST, dbname=POST_DB_NAME,user=POST_DB_USER,password=POST_DB_PASSWD,port=POST_DB_PORT)
cursor = db.cursor()
db.autocommit = False

# 데이터 불러오기
# 이력서 불러오기
path = "./data/빅데이터AI_이력서.pdf"
doc = fitz.open(path)
for page in doc:
    resume_text = page.get_text()
    print(resume_text)
# Out:
# 📄 이력서 (Resume)
# [기본 정보]
# 이름: 홍길동
# 연락처: 010-1234-5678
# 이메일: honggildong.ai@gmail.com
# 주소: 서울특별시 강남구 테헤란로 123
# [학력]
# 고려대학교 컴퓨터학과 졸업 (2018.03 ~ 2024.02)
# GPA: 3.85 / 4.5
# 관련 과목: 머신러닝, 데이터마이닝, 통계학, 빅데이터처리, 딥러닝 이론과 실습
# [기술 스택]
# Programming: Python, SQL, R
# Frameworks/Libraries: Scikit-learn, TensorFlow, PyTorch, Pandas, NumPy
# Tools: Jupyter, Git, Docker, Tableau
# DBMS: MySQL, MongoDB, Hadoop(HDFS), Spark
# Cloud: Google Colab, AWS EC2 & S3 (기초 수준)
# [프로젝트 경험]
# 1. 신문 기사 기반 감성 분석 모델 개발 (2023.03 ~ 2023.06)
# 자연어처리(NLP) 기반 감성 분류 모델 개발
# KoNLPy와 Scikit-learn을 이용한 전처리 및 모델 학습
# 정확도 86% 달성
# 2. 머신러닝 기반 개인 맞춤형 영화 추천 시스템 (2023.09 ~ 2023.12)
# 📄 이력서 (Resume)
# 1
#
# Content-based Filtering 및 Collaborative Filtering 기법 적용
# Streamlit으로 웹 인터페이스 구현
# kaggle 데이터셋 기반, Precision@10: 0.73
# [자격증]
# ADsP (데이터분석 준전문가) – 2023.08
# SQLD (SQL 개발자) – 2024.01
# 📄 이력서 (Resume)
# 2

# %%
df = pd.read_csv("../data_backup/rec_data.csv")

# %%
from langchain.vectorstores import ElasticVectorSearch
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.retrievers import BM25Retriever, EnsembleRetriever
from langchain.storage import InMemoryStore

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk

# %%
index_name = "jd_index"
es = Elasticsearch(
    "https://localhost:9200",
    basic_auth=("elastic", "elastic7276"),  # 👈 설치 시 발급된 비번
    verify_certs=False
)
# Out:
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/elasticsearch/_sync/client/__init__.py:403: SecurityWarning: Connecting to 'https://localhost:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %%
def index_documents_to_es(index_name, documents):
    if not es.indices.exists(index=index_name):
        es.indices.create(index=index_name)

    actions = [
        {
            "_index": index_name,
            "_id": i,
            "_source": {
                "content": doc.page_content,
                **doc.metadata
            }
        }
        for i, doc in enumerate(documents)
    ]

    bulk(es, actions)

# %%
class ElasticsearchRetriever:
    def __init__(self, es, index_name, k=5):
        self.es = es
        self.index_name = index_name
        self.k = k

    def get_relevant_documents(self, query):
        response = self.es.search(
            index=self.index_name,
            query={
                "match": {
                    "content": {
                        "query": query,
                        "operator": "and"
                    }
                }
            },
            size=self.k
        )
        hits = response["hits"]["hits"]
        return [
            Document(
                page_content=hit["_source"]["content"],
                metadata={k: v for k, v in hit["_source"].items() if k != "content"}
            )
            for hit in hits
        ]

# %%
df
# Out:
#        Unnamed: 0   rec_idx  \
# 0               0  46254462
# 1               1  46552267
# 2               2  46809948
# 3               3  46858808
# 4               4  47037243
# ...           ...       ...
# 13848       13848  50283723
# 13849       13849  50283724
# 13850       13850  50283728
# 13851       13851  50283729
# 13852       13852  50283731
#
#                                                    chunk    company_nm  \
# 0                 [3500/중식제공]식품 쇼핑몰 MD 경력직 채용\n\n채용공고 상세       (주)다온미트
# 1      iOS 개발자 경력 모집\n\n채용공고 상세\nIOS 개발자 모집모집부문 및 상세내...       한국전자인증㈜
# 2      인하우스 디자인 / 시각 제품 그래픽 산업 3D UX UI 웹\n\n채용공고 상세\...   (주)아트앤매니지먼트
# 3      제주 드림타워 복합리조트 [카지노&호텔] 대규모 신입 공개 채용 채용공고 상세\n ...   (주)엘티엔터테인먼트
# 4      경영지원팀-경영지원(신입-경력)사원 구인 공고\n\n채용공고 상세\n빠르게 성장하는...     엑사옵토닉스(주)
# ...                                                  ...           ...
# 13848  [동인광학] 부설연구소 전자 FW/HW 개발자 모집\n\n채용공고 상세\n[동인광학...       (주)동인광학
# 13849  생산직 직원 모집합니다\n\n채용공고 상세\n안녕하세요 \n당사는 내화채움재등을 제...    주식회사더원에프에스
# 13850  광주 에이치원 호텔 프론트 데스크/업무 직원\n\n채용공고 상세\n광주 에이치원 호...     (주)에이치원호텔
# 13851  경북어울림)포항시발달장애인주간활동센터 제공인력 채용\n\n채용공고 상세\n경북어울림...  경북어울림사회적협동조합
# 13852  CATIA 부품설계 설계자 채용\n\n채용공고 상세\nCATIA 부품설계 설계자 채...      아피아엔지니어링
#
#                                       recruit_kewdcdnm company_place  \
# 0                                            ['온라인MD']        경기 하남시
# 1                                      ['Objective-C']        서울 서초구
# 2      ['크리에이터', '광고디자인', '그래픽디자인', '디지털디자인', '산업디자인']      서울 강남구 외
# 3                ['출납', '사무직', '문서작성', '비품관리', '사무보조']      제주 제주시 외
# 4                           ['경리', '총무', '경영지원', '회계']        경기 화성시
# ...                                                ...           ...
# 13848                                   ['연구원', 'R&D']    경기 부천시 오정구
# 13849                            ['생산관리', 'MES', '생산']        경기 양주시
# 13850          ['호텔리어', '객실관리', '고객안내', '고객응대', '프론트']         광주 북구
# 13851                      ['사회복지사', '생활복지사', '장애인복지']     경북 포항시 북구
# 13852      ['설계엔지니어', '기계설계', '부품설계', '시스템설계', '2D설계']      경남 진주시 외
#
#                career  education
# 0      경력(년수무관) · 정규직       학력무관
# 1       1 ~ 10년 · 정규직       학력무관
# 2       신입 · 경력 · 정규직       학력무관
# 3          신입 · 정규직 외       학력무관
# 4          경력무관 · 정규직       학력무관
# ...               ...        ...
# 13848    경력 3년↑ · 정규직  대학(2,3년)↑
# 13849      경력무관 · 정규직       학력무관
# 13850      경력무관 · 정규직        고졸↑
# 13851    경력무관 · 정규직 외       학력무관
# 13852    경력무관 · 정규직 외  대학(2,3년)↑
#
# [13853 rows x 8 columns]

# %%
from langchain.schema import Document

documents = []
for _, row in df.iterrows():
    doc = Document(
        page_content=row["chunk"],
        metadata={
            "rec_idx": row["rec_idx"],
            "company_nm": row["company_nm"],
            "recruit_kewdcdnm": row["recruit_kewdcdnm"],
            "company_place": row["company_place"],
            "career": row["career"],
            "education": row["education"],
        }
    )
    documents.append(doc)

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.retrievers import BM25Retriever, EnsembleRetriever
from langchain.schema.document import Document
import os

# 1. OpenAI 임베딩 모델
embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

# 2. Chroma에서 벡터 리트리버 로딩 (이미 구축된 벡터 DB)
vectordb = Chroma(
    persist_directory="./chroma_data",
    embedding_function=embedding_model,
    collection_name="chroma_test"
)
vector_retriever = vectordb.as_retriever(search_kwargs={"k": 5})

# 3. BM25Retriever (chunk 리스트 그대로 사용)
# 👉 'chunk' 컬럼과 metadata로 Document 객체 생성
from langchain.schema import Document

bm25_docs = [
    Document(page_content=row["chunk"], metadata=row.drop("chunk").to_dict())
    for _, row in df.iterrows()
]
bm25_retriever = BM25Retriever.from_documents(bm25_docs)
bm25_retriever.k = 20

# 4. 하이브리드 리트리버 조합
hybrid_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, vector_retriever],
    weights=[0.2, 0.8]  # → 가중치 조정 가능 (BM25 강화하려면 [0.7, 0.3]처럼)
)

# %%
from langchain.prompts import PromptTemplate
from langchain.schema.runnable import RunnablePassthrough
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# 프롬프트 정의
template = """
당신은 인재매칭 AI 어시스턴트입니다. 사용자 이력서에 기반하여 채용공고를 추천해주세요.

그리고 사용자 정보는 다음과 같습니다:
- 지원 직무: 데이터 분석, AI 모델링, 감성 분석, 영화 추천 시스템 개발
- 관심 산업/도메인: IT, 빅데이터
- 기술/스킬: Python, SQL, R, Scikit-learn, TensorFlow, PyTorch, Pandas, NumPy, Jupyter, Git, Docker, Tableau, MySQL, MongoDB, Hadoop(HDFS), Spark, Google Colab, AWS EC2 & S3, KoNLPy, Word2Vec, Streamlit
- 학력 및 경력: 고려대학교 컴퓨터학과 졸업, 신입
- 희망 지역: 서울특별시 강남구

- 반드시 이력서에 기반할 것.
- 채용공고 상세는 반드시 모두 출력할 것.
- 출력 시 채용공고의 양식을 사용할 것.
- 채용공고 추천 이유를 한줄로 설명할 것.         
- 같은 공고 번호가 중복될 경우 단 1개만 추천할 것.                  
- 채용공고 전체 내용을 기반하여 분석할 것. 제목만 보고 판단하지 말 것.
- page_content의 전체 텍스트를 기준으로 판단할 것.

### 출력 형식 예시
1.
- 직무명 : 
- 공고 번호 :                         
- 산업 분야 : 
- 필요 기술 : 
- 채용공고 상세 :
- 추천 사유 :

이 정보를 바탕으로 사용자 정보에 가장 적합한 채용 공고 20개를 추천해주세요.
출력 형식과 동일한 형식으로 출력해주세요.                                          

채용공고:
{context}

이력서:
{question}
"""

prompt = PromptTemplate.from_template(template)

# LLM 세팅
llm = ChatOpenAI(model="gpt-4o", temperature=0.3)

# 전체 체인 정의
rag_chain = (
     {
        "context": hybrid_retriever | (lambda docs: "\n\n".join(
            f"{doc.metadata.get('rec_idx')}\n{doc.page_content.strip()}"
            for doc in docs
        )),
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
)

# %%
# 사용 예시
question = resume_text
answer = rag_chain.invoke(question)
print(answer)
# Out:
# 1.
# - 직무명 : 데이터 분석가
# - 공고 번호 : 50226095
# - 산업 분야 : IT개발·데이터
# - 필요 기술 : 데이터분석, 머신러닝, 딥러닝, 빅데이터
# - 채용공고 상세 : LG CNS에서 데이터 분석가를 포함한 다양한 IT 직무를 모집하며, 머신러닝, 딥러닝, 빅데이터 관련 업무를 수행할 인재를 찾고 있습니다.
# - 추천 사유 : 사용자의 데이터 분석 및 AI 모델링 기술이 LG CNS의 데이터 분석가 직무와 잘 맞습니다.
#
# 2.
# - 직무명 : 소프트웨어 개발자
# - 공고 번호 : 50275838
# - 산업 분야 : 소프트웨어 개발
# - 필요 기술 : Python, SQL, RESTful API, Git
# - 채용공고 상세 : 소프트웨어 개발자를 모집하며, Python과 SQL을 사용한 데이터 처리 및 RESTful API 설계 경험이 요구됩니다.
# - 추천 사유 : 사용자의 Python 및 SQL 기술이 이 직무에 적합합니다.
#
# 3.
# - 직무명 : 데이터 취득 관리자
# - 공고 번호 : 50282644
# - 산업 분야 : 데이터 관리
# - 필요 기술 : Python, AWS, 데이터 전처리
# - 채용공고 상세 : 데이터 취득 및 관리 업무를 담당하며, AWS를 통한 데이터 관리 및 Python을 사용한 데이터 전처리 경험이 필요합니다.
# - 추천 사유 : 사용자의 AWS 및 Python 기술이 데이터 취득 관리 업무에 적합합니다.
#
# 4.
# - 직무명 : 글로벌 세일즈 매니저
# - 공고 번호 : 50281662
# - 산업 분야 : 글로벌 세일즈
# - 필요 기술 : 데이터 분석, 시장 조사
# - 채용공고 상세 : 글로벌 세일즈 매니저로서 시장 조사 및 데이터 분석을 통해 전략을 개발하고, 해외 바이어와의 관계를 구축합니다.
# - 추천 사유 : 사용자의 데이터 분석 능력이 글로벌 세일즈 전략 개발에 유용할 것입니다.
#
# 5.
# - 직무명 : 웹 프론트엔드 개발자
# - 공고 번호 : 49948486
# - 산업 분야 : 웹 개발
# - 필요 기술 : JavaScript, Node.js, RESTful API
# - 채용공고 상세 : 웹 프론트엔드 개발자로서 JavaScript와 Node.js를 사용한 웹 애플리케이션 개발 및 RESTful API 연동을 담당합니다.
# - 추천 사유 : 사용자의 JavaScript 및 Node.js 경험이 웹 프론트엔드 개발에 적합합니다.
#
# 6.
# - 직무명 : 데이터 분석 및 AI 모델링
# - 공고 번호 : 50224035
# - 산업 분야 : 환경 기술
# - 필요 기술 : 데이터 분석, 머신러닝
# - 채용공고 상세 : 뉴보텍에서 데이터 분석 및 AI 모델링을 통해 환경 기술 혁신을 선도할 인재를 모집합니다.
# - 추천 사유 : 사용자의 데이터 분석 및 AI 모델링 기술이 환경 기술 혁신에 기여할 수 있습니다.
#
# 7.
# - 직무명 : 데이터 엔지니어
# - 공고 번호 : 50263204
# - 산업 분야 : 소프트웨어 개발
# - 필요 기술 : Python, C++, 데이터베이스 관리
# - 채용공고 상세 : 리눅스 환경에서 데이터 엔지니어로서 Python과 C++을 사용한 데이터 처리 및 데이터베이스 관리 업무를 수행합니다.
# - 추천 사유 : 사용자의 Python 및 데이터베이스 관리 경험이 데이터 엔지니어 직무에 적합합니다.
#
# 8.
# - 직무명 : AI 데이터 분석가
# - 공고 번호 : 50280378
# - 산업 분야 : 데이터 분석
# - 필요 기술 : 데이터 분석, AI 모델링, 머신러닝
# - 채용공고 상세 : 트릿지에서 AI 데이터 분석가로서 글로벌 식품 공급망 데이터를 분석하고, 데이터 기반 솔루션을 제공합니다.
# - 추천 사유 : 사용자의 AI 모델링 및 데이터 분석 기술이 글로벌 데이터 분석에 유용할 것입니다.
#
# 9.
# - 직무명 : 데이터 사이언티스트
# - 공고 번호 : 50271007
# - 산업 분야 : 의료 데이터 분석
# - 필요 기술 : 유전체 분석, 데이터 모델링
# - 채용공고 상세 : 국립암센터에서 유전체 데이터 분석 및 모델링을 통해 암 연구를 지원할 데이터 사이언티스트를 모집합니다.
# - 추천 사유 : 사용자의 데이터 모델링 경험이 유전체 데이터 분석에 적합합니다.
#
# 10.
# - 직무명 : 빅데이터 분석가
# - 공고 번호 : 50063436
# - 산업 분야 : IT 교육
# - 필요 기술 : 빅데이터 분석, Hadoop, Spark
# - 채용공고 상세 : 빅데이터 기반 IoT 클라우드 응용SW 개발자를 양성하는 교육 과정으로, 빅데이터 분석 및 플랫폼 설계 능력을 배양합니다.
# - 추천 사유 : 사용자의 빅데이터 분석 기술이 교육 과정에 적합합니다.
#
# 11.
# - 직무명 : 데이터 엔지니어
# - 공고 번호 : 50254455
# - 산업 분야 : 물류 데이터 관리
# - 필요 기술 : 데이터 관리, Python, SQL
# - 채용공고 상세 : 물류 데이터 관리 및 배차 관리 업무를 담당하며, Python과 SQL을 사용한 데이터 처리 경험이 필요합니다.
# - 추천 사유 : 사용자의 Python 및 SQL 기술이 물류 데이터 관리에 적합합니다.
#
# 12.
# - 직무명 : 데이터 분석가
# - 공고 번호 : 50244761
# - 산업 분야 : 데이터 시각화
# - 필요 기술 : 데이터 시각화, Python, Tableau
# - 채용공고 상세 : 데이터 시각화 및 인터랙티브 웹 디자인을 담당하며, Python과 Tableau를 사용한 데이터 시각화 경험이 필요합니다.
# - 추천 사유 : 사용자의 데이터 시각화 기술이 인터랙티브 웹 디자인에 적합합니다.
#
# 13.
# - 직무명 : 데이터 분석가
# - 공고 번호 : 50269217
# - 산업 분야 : 마케팅 데이터 분석
# - 필요 기술 : 데이터 분석, 마케팅 전략
# - 채용공고 상세 : 마케팅 디자이너로서 데이터 분석을 통해 마케팅 전략을 개발하고, SNS 및 인쇄물 관리를 담당합니다.
# - 추천 사유 : 사용자의 데이터 분석 능력이 마케팅 전략 개발에 유용할 것입니다.
#
# 14.
# - 직무명 : 데이터 엔지니어
# - 공고 번호 : 50268230
# - 산업 분야 : 의료 데이터 관리
# - 필요 기술 : 데이터 관리, Python, SQL
# - 채용공고 상세 : 의료 기기 데이터 관리 및 품질 보증 업무를 담당하며, Python과 SQL을 사용한 데이터 관리 경험이 필요합니다.
# - 추천 사유 : 사용자의 Python 및 SQL 기술이 의료 데이터 관리에 적합합니다.
#
# 15.
# - 직무명 : 데이터 분석가
# - 공고 번호 : 50275704
# - 산업 분야 : 상품 기획
# - 필요 기술 : 데이터 분석, 상품 기획
# - 채용공고 상세 : K-POP MD 상품 기획 및 개발을 담당하며, 데이터 분석을 통해 상품 기획 전략을 수립합니다.
# - 추천 사유 : 사용자의 데이터 분석 능력이 상품 기획에 유용할 것입니다.
#
# 16.
# - 직무명 : 데이터 엔지니어
# - 공고 번호 : 50275512
# - 산업 분야 : 해외 영업 데이터 관리
# - 필요 기술 : 데이터 관리, Python, SQL
# - 채용공고 상세 : 해외 영업 데이터 관리 및 분석 업무를 담당하며, Python과 SQL을 사용한 데이터 처리 경험이 필요합니다.
# - 추천 사유 : 사용자의 Python 및 SQL 기술이 해외 영업 데이터 관리에 적합합니다.
#
# 17.
# - 직무명 : 데이터 분석가
# - 공고 번호 : 50273596
# - 산업 분야 : 교육 데이터 분석
# - 필요 기술 : 데이터 분석, 교육 전략
# - 채용공고 상세 : 교육 기업에서 데이터 분석을 통해 교육 전략을 개발하고, 교육 콘텐츠를 기획합니다.
# - 추천 사유 : 사용자의 데이터 분석 능력이 교육 전략 개발에 유용할 것입니다.
#
# 18.
# - 직무명 : 데이터 엔지니어
# - 공고 번호 : 50283279
# - 산업 분야 : 학원 데이터 관리
# - 필요 기술 : 데이터 관리, Python, SQL
# - 채용공고 상세 : 학원 데이터 관리 및 분석 업무를 담당하며, Python과 SQL을 사용한 데이터 처리 경험이 필요합니다.
# - 추천 사유 : 사용자의 Python 및 SQL 기술이 학원 데이터 관리에 적합합니다.
#
# 19.
# - 직무명 : 데이터 분석가
# - 공고 번호 : 50280660
# - 산업 분야 : 의료 데이터 분석
# - 필요 기술 : 데이터 분석, 의료 전략
# - 채용공고 상세 : 의료 기업에서 데이터 분석을 통해 의료 전략을 개발하고, 의료 콘텐츠를 기획합니다.
# - 추천 사유 : 사용자의 데이터 분석 능력이 의료 전략 개발에 유용할 것입니다.
#
# 20.
# - 직무명 : 데이터 엔지니어
# - 공고 번호 : 50273596
# - 산업 분야 : 교육 데이터 관리
# - 필요 기술 : 데이터 관리, Python, SQL
# - 채용공고 상세 : 교육 기업에서 데이터 관리 및 분석 업무를 담당하며, Python과 SQL을 사용한 데이터 처리 경험이 필요합니다.
# - 추천 사유 : 사용자의 Python 및 SQL 기술이 교육 데이터 관리에 적합합니다.

# %% [markdown]
# ---

# %%
class HybridRetriever:
    def __init__(self, es_retriever, vector_retriever, alpha=0.5):
        self.es_retriever = es_retriever
        self.vector_retriever = vector_retriever
        self.alpha = alpha  # 0~1 벡터 중요도

    def get_relevant_documents(self, query):
        es_docs = self.es_retriever.get_relevant_documents(query)
        vec_docs = self.vector_retriever.get_relevant_documents(query)

        combined = es_docs[:int((1 - self.alpha) * 10)] + vec_docs[:int(self.alpha * 10)]
        # 중복 제거
        seen = set()
        final = []
        for doc in combined:
            key = doc.page_content
            if key not in seen:
                final.append(doc)
                seen.add(key)
        return final

# %%
documents
# Out:
# [Document(metadata={'rec_idx': 46254462, 'company_nm': '(주)다온미트', 'recruit_kewdcdnm': "['온라인MD']", 'company_place': '경기 하남시', 'career': '경력(년수무관) · 정규직', 'education': '학력무관'}, page_content='[3500/중식제공]식품 쇼핑몰 MD 경력직 채용\n\n채용공고 상세'),
#  Document(metadata={'rec_idx': 46552267, 'company_nm': '한국전자인증㈜', 'recruit_kewdcdnm': "['Objective-C']", 'company_place': '서울 서초구', 'career': '1 ~ 10년 · 정규직', 'education': '학력무관'}, page_content='iOS 개발자 경력 모집\n\n채용공고 상세\nIOS 개발자 모집모집부문 및 상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년) IOS 개발자 모집AI Security 연구본부 0명지원자격ㆍ경력 : 경력 2년 이상 우대사항ㆍ컴퓨터/시스템공학근무조건ㆍ근무형태:정규직(수습기간)-6개월ㆍ근무일시:주 5일(월~금)ㆍ근무지역: 서울 서초구 서초동 전형절차서류전형- 코딩테스트-1차면접 -2차면접-영어면접(필요시)-임원면접- 최종합격접수기간 및 방법ㆍ접수기간:2023년 9월 11일 (월) 10시 ~ 2023년 10월 11일 (수) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서유의사항ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용 확정 이후라도 채용이 취소될 수 있습니다.'),
#  Document(metadata={'rec_idx': 46809948, 'company_nm': '(주)아트앤매니지먼트', 'recruit_kewdcdnm': "['크리에이터', '광고디자인', '그래픽디자인', '디지털디자인', '산업디자인']", 'company_place': '서울 강남구 외', 'career': '신입 · 경력 · 정규직', 'education': '학력무관'}, page_content='인하우스 디자인 / 시각 제품 그래픽 산업 3D UX UI 웹\n\n채용공고 상세\n ㈜아트앤매니지먼트 인하우스 디자인 / 시각 제품 그래픽 산업 3D 모션 UX UI 웹\n기타제조업 > 제조업 회사본사\n종\t기타제조업 > 제조업 회사본사\n직종\t선택 : 디자인 > 직무·직업 > 광고디자인\n선택 : 디자인 > 직무·직업 > 그래픽디자인\n선택 : 디자인 > 직무·직업 > 디지털디자인\n선택 : 디자인 > 직무·직업 > 산업디자인\n선택 : 디자인 > 직무·직업 > 섬유디자인\n선택 : 디자인 > 직무·직업 > 시각디자인\n선택 : 디자인 > 직무·직업 > 영상디자인\n선택 : 디자인 > 직무·직업 > 패키지디자인\n선택 : 디자인 > 전문분야 > 3D디자인\n선택 : 디자인 > 작업Tool > Maya\n선택 : 디자인 > 작업Tool > PhotoShop\n선택 : 디자인 > 작업Tool > 3DMax\n선택 : 미디어·문화·스포츠 > 직무·직업 > 크리에이터\n근무지 주소\t(06236) 서울 강남구 테헤란로 142(역삼동)\n노출지역\t 서울 > 서울전체, 서울 > 강남구, 서울 > 서초구, 서울 > 송파구, 서울 > 종로구, 경기 > 경기전체, 경기 > 성남시, 경기 > 성남시 분당구, 경기 > 안양시, 경기 > 하남시'),
#  Document(metadata={'rec_idx': 46858808, 'company_nm': '(주)엘티엔터테인먼트', 'recruit_kewdcdnm': "['출납', '사무직', '문서작성', '비품관리', '사무보조']", 'company_place': '제주 제주시 외', 'career': '신입 · 정규직 외', 'education': '학력무관'}, page_content='제주 드림타워 복합리조트 [카지노&호텔] 대규모 신입 공개 채용 채용공고 상세\n \n경력직 공고 바로가기 \n\t\t\xa0\xa0\n\t\n㈜엘티엔터테인먼트\n제주 드림타워 복합리조트 [카지노&호텔] 대규모 공개 채용\n\t 호텔·여행·항공 > 카지노\n레저·스포츠·여가 > 레저\n직종\t선택 : 회계·세무·재무 > 전문분야 > 출납\n선택 : 총무·법무·사무 > 직무·직업 > 사무직\n선택 : 총무·법무·사무 > 전문분야 > 경영지원\n선택 : 총무·법무·사무 > 전문분야 > 문서작성\n선택 : 총무·법무·사무 > 전문분야 > 비품관리\n선택 : 총무·법무·사무 > 전문분야 > 사무보조\n선택 : 총무·법무·사무 > 전문분야 > 사무행정\n선택 : 영업·판매·무역 > 직무·직업 > 영업\n선택 : 영업·판매·무역 > 직무·직업 > 영업지원\n선택 : 영업·판매·무역 > 직무·직업 > 영업직\n선택 : 영업·판매·무역 > 직무·직업 > 캐셔\n선택 : 영업·판매·무역 > 담당분야 > 거래처관리\n선택 : 영업·판매·무역 > 담당분야 > 거래처납품\n선택 : 영업·판매·무역 > 담당분야 > 해외영업지원\n선택 : 영업·판매·무역 > 담당분야 > B2C\n선택 : 고객상담·TM > 직무·직업 > CS\n선택 : 고객상담·TM > 담당분야 > 고객관리\n선택 : 고객상담·TM > 담당분야 > 단순안내\n선택 : 상품기획·MD > 직무·직업 > 슈퍼바이저\n선택 : 서비스 > 직무·직업 > 경비원\n선택 : 서비스 > 직무·직업 > 경호원\n선택 : 서비스 > 직무·직업 > 관광가이드\n선택 : 서비스 > 직무·직업 > 관광통역안내사\n선택 : 서비스 > 직무·직업 > 매장매니저\n선택 : 서비스 > 직무·직업 > 매표/검표\n선택 : 서비스 > 직무·직업 > 벨멘/도어맨\n선택 : 서비스 > 직무·직업 > 보안요원\n선택 : 서비스 > 직무·직업 > 안내데스크\n선택 : 서비스 > 직무·직업 > 안전요원\n선택 : 서비스 > 직무·직업 > 지배인\n선택 : 서비스 > 직무·직업 > 캐셔\n선택 : 서비스 > 직무·직업 > 호텔리어\n선택 : 서비스 > 직무·직업 > 홀매니저 선택 : 서비스 > 직무·직업 > 벨멘/도어맨\n선택 : 서비스 > 직무·직업 > 보안요원\n선택 : 서비스 > 직무·직업 > 안내데스크\n선택 : 서비스 > 직무·직업 > 안전요원\n선택 : 서비스 > 직무·직업 > 지배인\n선택 : 서비스 > 직무·직업 > 캐셔\n선택 : 서비스 > 직무·직업 > 호텔리어\n선택 : 서비스 > 직무·직업 > 홀매니저\n선택 : 서비스 > 직무·직업 > 홀서빙\n선택 : 서비스 > 직무·직업 > A/S기사\n선택 : 서비스 > 전문분야 > 고객안내\n선택 : 서비스 > 전문분야 > 고객응대\n선택 : 서비스 > 전문분야 > 매장관리\n선택 : 서비스 > 전문분야 > 방범\n선택 : 서비스 > 전문분야 > 설비점검\n선택 : 서비스 > 전문분야 > 시설관리\n선택 : 서비스 > 전문분야 > 접수/예약\n선택 : 서비스 > 전문분야 > 프론트\n선택 : 서비스 > 근무장소 > 카지노\n선택 : 서비스 > 근무장소 > 콘도\n선택 : 서비스 > 근무장소 > 호텔\n선택 : 미디어·문화·스포츠 > 직무·직업 > 통/번역\n선택 : 미디어·문화·스포츠 > 전문분야 > 레저\n선택 : 미디어·문화·스포츠 > 전문분야 > 영어\n선택 : 미디어·문화·스포츠 > 전문분야 > 일본어\n선택 : 미디어·문화·스포츠 > 전문분야 > 제2외국어\n선택 : 미디어·문화·스포츠 > 전문분야 > 중국어\n선택 : 금융·보험 > 전문분야 > 환전'),
#  Document(metadata={'rec_idx': 47037243, 'company_nm': '엑사옵토닉스(주)', 'recruit_kewdcdnm': "['경리', '총무', '경영지원', '회계']", 'company_place': '경기 화성시', 'career': '경력무관 · 정규직', 'education': '학력무관'}, page_content='경영지원팀-경영지원(신입-경력)사원 구인 공고\n\n채용공고 상세\n빠르게 성장하는 엑사옵토닉스(주)에서 총무업무 및 경리담당 신입.경력 사원을 찾습니다 엑사옵토닉스(주)의 경영지원팀에서 총무업무 및 경리업무를 담당할 인재를 찾고 있습니다. 주요업무"우리와 함께 할 업무에요." · 총무관리(주요업무)\xa0\xa0 - 사내 시설 및 설비 유지 관리, 비품 및 소모품 관리 등 \xa0\xa0- 교육 체계 수립 및 기록 관리\xa0\xa0- 대관업무 · 경리업무(회계) - (보조업무)\xa0\xa0 - 자금일보, 전표입력, 원천세 및 부가세 신고, 가결산 보조\xa0\xa0 - 연말정산 및 4대보험 관리자격요건"이런 분과 함께 하고 싶어요." · 논리적이고 원활한 커뮤니케이션 능력이 있는 분 · 매사에 열정적이고 적극적인 의지를 지니신 분 · 차량보유자(운전면허 보유자) · 해당업무 경력 : 1년~3년 이하Benefits”이런 혜택 및 복지를 지원해드려요.”1. 최고의 업무 효율을 위한 환경 · 사내 식당 · 자유로운 연차 사용 · 각종 경조사 지원 · 사내 기숙사 운영 · 근무복 지급[전형 절차] · 서류전형 → 면접전형 (실무진) → 최종합격[제출 서류] · 채용 공고 사이트 양식의 이력서 및 자기소개서(경력자의 경우 세부사항 포함)'),
#  Document(metadata={'rec_idx': 47037684, 'company_nm': '엑사옵토닉스(주)', 'recruit_kewdcdnm': "['영업관리', '영업지원', '원가관리']", 'company_place': '경기 화성시', 'career': '신입 · 정규직', 'education': '학력무관'}, page_content='프로젝트팀(영업)-PJT관리&원가관리(신입)사원 구인\n\n채용공고 상세\n빠르게 성장하는 엑사옵토닉스(주)에서 프로젝트 개발 대응 업무, 양산 및 원가 관리 업무를담당할 신입사원을 찾습니다 엑사옵토닉스(주)의 프로젝트팀에서 영업업무를 담당할 인재를 찾고 있습니다. 주요업무"우리와 함께 할 업무에요." · PJT관리/영업 : 신입(1명)- 개발 대응Follow up(양산 개발, 선행 개발) · 원가/영업 : 신입(1명)- 양산 대응 Follow up- 원가 관리 Follow up자격요건"이런 분과 함께 하고 싶어요." · 논리적이고 원활한 커뮤니케이션 능력이 있는 분 · 매사에 열정적이고 적극적인 의지를 지니신 분 · 차량보유자(운전면허 보유자) · (국내)출장 업무 가능자 · 문서 작성 우수자(PPT, Excel)Benefits”이런 혜택 및 복지를 지원해드려요.”1. 최고의 업무 효율을 위한 환경 · 사내 식당 · 자유로운 연차 사용 · 각종 경조사 지원 · 사내 기숙사 운영 · 근무복 지급[전형 절차] · 서류전형 → 면접전형 (실무진) → 최종합격[제출 서류] · 채용 공고 사이트 양식의 이력서 및 자기소개서(경력자의 경우 세부사항 포함)'),
#  Document(metadata={'rec_idx': 47037808, 'company_nm': '엑사옵토닉스(주)', 'recruit_kewdcdnm': "['지게차', '물류관리', '자재관리', '재고관리', '상하차']", 'company_place': '경기 화성시', 'career': '5 ~ 10년 · 정규직', 'education': '학력무관'}, page_content='구매물류팀-출하파트 및 창고관리 담당(과.차장급)구인\n\n채용공고 상세\n빠르게 성장하는 엑사옵토닉스(주)에서 구매물류팀 출하업무 및 완제품 출고 담당 경력 사원을 찾습니다 엑사옵토닉스(주)의 구매물류팀에서 출하 업무를 담당할 인재를 찾고 있습니다. 주요업무"우리와 함께 할 업무에요." · 출하관리- 생산 제품 제품 창고 입고 관리- 제품 출하 관리(고객사 발주 대응/출하 창고 입.출고 관리/물류 관리)조건 및 직책 · 물류 업무 5년 이상 근무하신 분(과.차장급 구인)자격요건"이런 분과 함께 하고 싶어요." · 논리적이고 원활한 커뮤니케이션 능력이 있는 분 · 매사에 열정적이고 적극적인 의지를 지니신 분 · 업무에 꼼꼼하고 디테일을 챙기시는 분 · 동종업계 근무 경력 보유하신 분Benefits”이런 혜택 및 복지를 지원해드려요.”1. 최고의 업무 효율을 위한 환경 · 사내 식당 · 자유로운 연차 사용 · 각종 경조사 지원 · 사내 기숙사 운영 · 근무복 지급[전형 절차] · 서류전형 → 면접전형 (실무진) → 최종합격[제출 서류] · 채용 공고 사이트 양식의 이력서 및 자기소개서(경력자의 경우 세부사항 포함)'),
#  Document(metadata={'rec_idx': 47037861, 'company_nm': '엑사옵토닉스(주)', 'recruit_kewdcdnm': "['품질분석', '품질관리', '품질보증']", 'company_place': '경기 화성시', 'career': '경력(년수무관) · 정규직', 'education': '학력무관'}, page_content='품질팀-개발품질, 공정품질 담당(과장급) 구인 공고\n\n채용공고 상세\n빠르게 성장하는 엑사옵토닉스(주)에서 품질 신차 품질 및 공정 품질 업무담당 경력(과장) 사원을 찾습니다 엑사옵토닉스(주)의 품질팀에서 신차 및 공정 품질 업무를 담당할 인재를 찾고 있습니다. 주요업무"우리와 함께 할 업무에요." · 신차(개발)품질- 신차 개발 품질 보증- 개발/정기 신뢰성- 품질 계측기 관리 · 공정품질- 고객 불량 대응- 변경점 관리- 공정품질 개선- 고객점검 대응조건 및 직책 · 품질 업무 7년 이상 근무하신 분(과장급 구인)자격요건"이런 분과 함께 하고 싶어요." · 논리적이고 원활한 커뮤니케이션 능력이 있는 분 · 매사에 열정적이고 적극적인 의지를 지니신 분 · 업무에 꼼꼼하고 디테일을 챙기시는 분 · 동종업계 근무 경력 보유하신 분Benefits”이런 혜택 및 복지를 지원해드려요.”1. 최고의 업무 효율을 위한 환경 · 사내 식당 · 자유로운 연차 사용 · 각종 경조사 지원 · 사내 기숙사 운영 · 근무복 지급[전형 절차] · 서류전형 → 면접전형 (실무진) → 최종합격[제출 서류] · 채용 공고 사이트 양식의 이력서 및 자기소개서(경력자의 경우 세부사항 포함)'),
#  Document(metadata={'rec_idx': 47342557, 'company_nm': '(주)짐스컴퍼니', 'recruit_kewdcdnm': "['스포츠강사', '수영']", 'company_place': '대구 수성구', 'career': '경력무관 · 정규직', 'education': '학력무관'}, page_content='짐스컴퍼니 대구(침산/연경/두산)직영점 수영교사 모집\n\n채용공고 상세'),
#  Document(metadata={'rec_idx': 47609360, 'company_nm': '(주)코딧', 'recruit_kewdcdnm': "['QA/테스터']", 'company_place': '서울 영등포구', 'career': '경력무관 · 인턴직', 'education': '학력무관'}, page_content='QA 인턴 채용 채용공고 상세 빠르게 성장하는 코딧에서 QA 인턴을 찾습니다 코딧(CODIT)은 AI와 빅데이터 기술로 방대한 양의 의안.법령.정책 정보를 분석, 기업에게 맞춤형 정보를 제공하는 플랫폼 기업입니다. 코딧의 서비스는 기업이 지속적인 규제.정책 변화에 선제적으로 대응하고 전략적으로 문제를 해결할 수 있도록 지원합니다.코딧 QA팀은요코딧 플랫폼의 Frontend/Backend QA를 진행하여 고객사가 제품을 성공적으로 활용할 수 있도록 지원합니다.웹, 앱, 모바일 페이지, 국영문 페이지 등 다양한 코딧 서비스에 대한 품질검증을 진행합니다. 이런 일을 하게 되실 예정이에요코딧이 운영하는 주요 서비스에 대한 Frontend/Backend QA제품에 대한 Ownership에 기반한 품질 기준 정립 및 지속적인 품질 개선요구사항 분석 및 테스트 계획 수립, 테스트 케이스 작성 및 진행Jira 등의 협업 도구를 활용한 결함 리포트 및 관리개발, 기획, 디자인 등 구성원과의 원활한 협업을 통한 품질 개선 프로세스 정립이런 분을 찾고 있어요모바일 또는 웹서비스의 사용성 테스트에 흥미가 있으신 분반복적인 테스트 활동에서 높은 집중력과 끈기 있는 성격을 가지신 분유연한 문제해결 능력과 투명한 커뮤니케이션 역량을 보유한 분담당 업무에 몰입할 수 있고, 그 과정에서 얻게 되는 성취와 성장에 가치를 두는 분서비스 품질에 대한 책임감과 개선에 대한 의지가 있으신 분이런 분이면 더 좋아요어려운 문제를 주도적으로 해결한 경험이 있거나 즐기는 분긍정적이고 능동적인 마인드를 보유한 분변하는 상황에 맞춰 다양한 업무를 경험하고 싶은 분성장하는 스타트업을 경험하고 싶으신 분참고해 주세요해당 포지션은 체험형 인턴 포지션이에요(6개월 / 협의 가능)인턴 기간 종료 후 정규직 전환도 가능해요이렇게 합류해요서류 접수 → 온라인 면접 → 테스트 및 대면 면접 → 최종 합격이런 혜택과 복지를 드려요업무에 필요한 최신 기기 및 환경 제공여의도역 근처 쾌적한 사무공간(네이버 지도에서 보기)자율 복장 / 직급없이 "님"으로 싶으신 분참고해 주세요해당 포지션은 체험형 인턴 포지션이에요(6개월 / 협의 가능)인턴 기간 종료 후 정규직 전환도 가능해요이렇게 합류해요서류 접수 → 온라인 면접 → 테스트 및 대면 면접 → 최종 합격이런 혜택과 복지를 드려요업무에 필요한 최신 기기 및 환경 제공여의도역 근처 쾌적한 사무공간(네이버 지도에서 보기)자율 복장 / 직급없이 "님"으로 소통식사 및 다양한 간식 제공최고급 안마의자'),
#  Document(metadata={'rec_idx': 47740100, 'company_nm': '(주)큐피스트', 'recruit_kewdcdnm': "['PM(프로젝트매니저)', 'PMO']", 'company_place': '서울 강남구', 'career': '3 ~ 10년 · 정규직', 'education': '대학교(4년)↑'}, page_content="프로덕트 매니저 (Product Manager) 채용공고 상세 ? 언젠가는 누구나 사랑할 날이 오지 않을까요?큐피스트는 글로벌 러브테크 브랜드를 비전으로 사람 대 사람의 데이팅 앱 브랜드, 사람 대 AI의 2가지 방향으로 비즈니스를 성장시키고 있습니다.사람 대 사람은 연애를 위한 데이팅 브랜드 ‘글램(glam)’를 시작으로 엔프피 등의 브랜드 확장을 하고 있으며, 사람 대 AI는 인플루언서의 AI 분신과 연애와 사랑할 수 있는 서비스를 만들고 있습니다. 우리는 만남과 사랑을 위한 여러 브랜드들을 마치 아이돌처럼 키워가며 사랑의 브랜드 포트폴리오를 구성합니다.큐피스트는 외로움을 상상할 수 없는 압도적으로 행복할 미래를, 사랑의 생산성을 극대화시켜 혁신을 만든 미래를, 누구나 쉽게 사랑할 수 있는 미래를 꿈꿉니다.만남의 가치를 믿고, 큐피스트가 만드는 브랜드들을 자식처럼 함께 키워갈 소중한 분을 모시고 있습니다.주요 업무큐피스트 Product Group은 서비스 비전 하에 분기마다 OKR에 기반한 전략 설정-가설 수립-실행-회고의 주기를 갖습니다. 프로덕트 매니저, 디자이너, 데이터 분석가, 엔지니어로 구성되어 있으며, 각 팀은 기획부터 배포까지의 2주 내외의 스프린트를 통해 주도적으로 서비스를 개선하고 배움을 얻습니다.Product Manager는 큐피스트의 주요 프로덕트인 데이팅앱을 포함하여, 사람 대 AI 분신과의 연애와 사랑을 할 수 있는 서비스가 고객에게 더욱 사랑받는 제품으로 거듭나기 위한 방안을 고민하고 실행합니다. 서비스 비전과 이해관계자 및 고객의 요구사항을 반영하여 목표 달성을 위한 우선순위를 설정하고 프로덕트를 발전시킵니다.디자이너와 함께 문제를 정의하고 기획하며, 엔지니어가 기능을 구현할 수 있도록 요구사항과 설계를 논의하고, 데이터 분석가와 결과를 분석하여 향후 방향을 고민하는 등 프로덕트 개선에 대한 일련의 과정을 리드하며, 다양한 이해관계자들과 협업 하며 최고의 프로덕트를 만듭니다.저희와 함께 세상에 없던 프로덕트를 기획하고 발전 시켜 나갈 소중한 분을 찾습니다.목표 달성을 위한 프로덕트 팀의 기획하며, 엔지니어가 기능을 구현할 수 있도록 요구사항과 설계를 논의하고, 데이터 분석가와 결과를 분석하여 향후 방향을 고민하는 등 프로덕트 개선에 대한 일련의 과정을 리드하며, 다양한 이해관계자들과 협업 하며 최고의 프로덕트를 만듭니다.저희와 함께 세상에 없던 프로덕트를 기획하고 발전 시켜 나갈 소중한 분을 찾습니다.목표 달성을 위한 프로덕트 팀의 로드맵과 주요 지표를 설정하고 관리합니다.VOC, 유저 인터뷰, 유저 데이터 등 정량/정성 분석을 통해 과업 및 우선순위를 도출합니다.프로덕트 개선과 운영에 필요한 기능 요구사항, 서비스 로직과 정책을 설계합니다.기능 배포 이후 데이터를 통한 배움을 통해 후속 방향을 설정합니다.디자이너, 데이터 분석가, 엔지니어와의 협업을 통해 이루어지는 기획-개발-배포-회고의 애자일 프로덕트 개발 프로세스 전 과정을 주도합니다.자격 요건'사랑의 욕망을 충족시킨다'는 큐피스트 사명에 공감하시는 분3년 이상의 프로덕트/프로젝트 매니징 혹은 유관 경험이 있는 분AARRR, A/B Test 등 모바일 서비스의 데이터 분석과 그로스 해킹에 대한 이해가 있는 분논리적 사고에 기반하여 문제를 정의하고 가설을 수립할 수 있는 분소프트웨어에 대한 기술적 이해를 바탕으로 복잡도 높은 제품 구조를 파악하고, 요구사항을 꼼꼼하게 정의할 수 있는 분디자이너, 데이터 분석가, 엔지니어 등의 협업 구성원과 원활한 실무 커뮤니케이션이 가능하신 분우대 사항데이팅, 소셜 서비스에 대한 높은 이해도와 경험이 있는 분디자인, 데이터 분석, 엔지니어링 중 한 가지에 전문성을 보유하고 계신 분신규 서비스 런칭, 버전업, 레거시 개편, 글로벌 진출 등 프로덕트의 다양한 성장 변곡점을 경험해보신 분 혜택 및 복지유연한 근무 환경을 제공 합니다.전 구성원 자율출퇴근 (9~11시)휴가는 자동승인, 30분 단위의 자유로운 연차 사용여름휴가용 3일 휴가 지급구성원의 성장을 돕습니다.연간 최대 100만원 교육훈련비 지원Free 무제한 도서구매 지원탈잉 VOD 수강 지원다양한 버전업, 레거시 개편, 글로벌 진출 등 프로덕트의 다양한 성장 변곡점을 경험해보신 분 혜택 및 복지유연한 근무 환경을 제공 합니다.전 구성원 자율출퇴근 (9~11시)휴가는 자동승인, 30분 단위의 자유로운 연차 사용여름휴가용 3일 휴가 지급구성원의 성장을 돕습니다.연간 최대 100만원 교육훈련비 지원Free 무제한 도서구매 지원탈잉 VOD 수강 지원다양한 복지를 제공합니다.전직원 개인 법인카드 제공 (식사비용, 야간교통비 지원)명절 상여 지급 & 경조사 지원건강검진 비용 지원 및 필수 대상자 유급 휴가 지원N주년 리프레시 휴가 & 지원금 지원직급,직책을 붙이지 않아요. 전직원 영어 닉네임 사용채용 절차서류 전형 → 1차 직무 인터뷰 → 2차 문화 인터뷰 → 레퍼런스 체크 → 최종합격"),
#  Document(metadata={'rec_idx': 47849094, 'company_nm': '(주)코딧', 'recruit_kewdcdnm': "['마케팅기획', '마케팅전략', 'B2B마케팅', '마케팅']", 'company_place': '서울 영등포구', 'career': '2 ~ 10년 · 정규직', 'education': '대학교(4년)↑'}, page_content='마케팅 매니저 채용공고 상세 코딧(CODIT)은 AI와 빅데이터 기술로 방대한 양의 의안.법령.정책 정보를 분석, 기업에게 맞춤형 정보를 제공하는 플랫폼 기업입니다. 코딧의 서비스는 기업이 지속적인 규제·정책 변화에 선제적으로 대응하고 전략적으로 문제를 해결할 수 있도록 지원합니다.[코딧이 달성한 성과] 시리즈 Pre-A 펀딩 완료(50억), 국내외 글로벌 기업 다수를 고객사로 유치, 국내 최초 및 1등B2B 규제 리스크 모니터링 플랫폼, 12개의 특허, 전문성 있는 탄탄함 팀빠르게 성장하는 코딧에서 마케팅 매니저를 찾습니다 주요업무"우리와 함께 할 업무에요."- 단기/중장기 그로스 및 퍼포먼스 마케팅 전략 수립 및 실행- 디지털 광고 캠페인 (Google Ads 등) 기획, 집행, 성과 분석 및 최적화- 마케팅 퍼널 전환율 개선을 위한 데이터 기반 분석 및 실험 설계 (A/B 테스트 등)- CRM 및 리타게팅 전략 수립 및 실행을 통한 리드 발굴 및 고객 전환 증대- 온드 미디어 (블로그, 링크드인 등) 콘텐츠 기획 및 관리- SEO 기반 블로그 아티클 및 타겟 고객 니즈에 맞춘 유입 콘텐츠 제작- 잠재고객/기존고객을 대상으로 한 데이터 기반 리드 생성 캠페인 기획 및 실행- 관련 부서(세일즈/정책)와 협업하여 성과 중심 콘텐츠 제작 및 활용- 주요 성과 지표 (CPL, CAC, ROAS 등) 관리 및 데이터 기반 인사이트 도출 및 실행자격요건"이런 분과 함께 하고 싶어요."- 2년 이상의 B2B 마케팅 경력을 보유하신 분- B2B 콘텐츠 기획/제작 관련 업무 경험이 있으신 분- B2B 비즈니스의 특성을 이해하며, 잠재고객사를 대상으로 한 카피라이팅이 가능하신 분- 코딧의 [Core Value]를 가지신 분우대사항"이런 경험이 있으시면 더 좋아요."- 어려운 문제를 주도적으로 해결한 경험이 있거나 즐기는 분- 긍정적이고 능동적인 마인드를 보유한 분- 원활한 커뮤니케이션 역량으로 소통하시는 분- 변하는 상황에 맞춰 다양한 업무를 경험하고 싶은 분- 성장하는 스타트업을 경험하고 싶으신 한 카피라이팅이 가능하신 분- 코딧의 [Core Value]를 가지신 분우대사항"이런 경험이 있으시면 더 좋아요."- 어려운 문제를 주도적으로 해결한 경험이 있거나 즐기는 분- 긍정적이고 능동적인 마인드를 보유한 분- 원활한 커뮤니케이션 역량으로 소통하시는 분- 변하는 상황에 맞춰 다양한 업무를 경험하고 싶은 분- 성장하는 스타트업을 경험하고 싶으신 분Benefits- 업무에 필요한 최신 기기 및 환경 제공- 여의도역/여의나루역 근처 쾌적한 사무공간- 점심 및 저녁비/다양한 간식 및 음료 제공- 자율 복장 / 직급 없이 "님"으로 소통- 연차, 반차, 반반차 사용/ 경조휴가 / 근속 연차별 선물 및 휴가- 업무 성과에 따른 상여금- 명절 및 생일 선물- 안마의자 (4D)[전형 절차] · 서류전형 → 전화 인터뷰 → 화상 면접→ 대면면접 → 처우 협의 → 최종 합격 · 포지션에 따라 추가 면접 또는 커피챗이 진행될 수 있습니다. · 필요 시, 레퍼런스 체크가 진행될 수 있습니다.[제출 서류] · 자유 양식의 이력서 (경력 세부사항 포함) · 자유 양식의 포트폴리오 또는 자기소개서(필수아님)'),
#  Document(metadata={'rec_idx': 47893642, 'company_nm': '(주)코딧', 'recruit_kewdcdnm': "['R&D기획', '경영기획']", 'company_place': '서울 영등포구', 'career': '3 ~ 10년 · 정규직', 'education': '대학교(4년)↑'}, page_content='정부사업(국책과제) 담당자 채용공고 상세 빠르게 성장하는 코딧에서 정부지원 및 국책과제 담당자를 찾습니다 코딧(CODIT)은 AI와 빅데이터 기술로 방대한 양의 의안·법령·정책 정보를 분석, 기업에게 맞춤형 정보를 제공하는 플랫폼 기업입니다. 코딧의 서비스는 기업이 지속적인 규제·정책 변화에 선제적으로 대응하고 전략적으로 문제를 해결할 수 있도록 지원합니다. [코딧이 달성한 성과] 시리즈 Pre-A 펀딩 완료(50억), 국내외 글로벌 기업 다수를 고객사로 유치, 국내 최초 및 1등 B2B 규제 리스크 모니터링 플랫폼, 12개의 특허, 전문성 있는 탄탄함 팀이런 일을 하게 되실 예정이에요 · 신규 정부지원과제 발굴 및 매니징 · 정부지원과제(유니콘/R&D/창업지원/해외진출 프로그램 등) 신청/협약/수행/정산/평가 업무 전반 지원 · 컨소시엄 구성 및 제안 방향 리드 · 정부 포상 및 특허 관리이런 분을 찾고 있어요 · 정보통신, AI 등 IT 기술분야에 대한 이해도나 관심이 높으신 분 · 3년 이상 정부과제 관리 경험(PM)이 있으신 분 · 제안서 등 정부 제출 문서 작성과 프리젠테이션 능력이 뛰어나신 분 · 한글/PPT/엑셀 등 사용이 능숙하신 분 · 평소 꼼꼼하고 책임감이 강하신 분 · 내외부 커뮤니케이션 역량이 뛰어나신 분 · 코딧의 Core Value를 가지신 분이런 분이면 더 좋아요 · 정부지원과제 신규 기획 및 운영 경험이 있으신 분 · 어려운 문제를 주도적으로 해결한 경험이 있거나 즐기시는 분 · 긍정적이고 능동적인 마인드를 보유한 분 · 변하는 상황에 맞춰 다양한 업무를 경험하고 싶으신 분 · 성장하는 스타트업을 경험하고 싶으신 분지원자분을 더 잘 이해하기 위해 아래 서류를 제출해주세요 · (필수) 이력서 및 자기소개서(성장 배경보다 경험했던 업무에 대해 작성해주세요) · (선택) 포트폴리오이런 혜택과 복지를 지원해드려요 · 업무에 필요한 최신 기기 및 환경 제공 · 여의도역/여의나루역 근처 쾌적한 사무공간 · 점심 및 저녁비 / 다양한 간식 및 음료 제공 · 자율 복장 / 직급 없이 더 잘 이해하기 위해 아래 서류를 제출해주세요 · (필수) 이력서 및 자기소개서(성장 배경보다 경험했던 업무에 대해 작성해주세요) · (선택) 포트폴리오이런 혜택과 복지를 지원해드려요 · 업무에 필요한 최신 기기 및 환경 제공 · 여의도역/여의나루역 근처 쾌적한 사무공간 · 점심 및 저녁비 / 다양한 간식 및 음료 제공 · 자율 복장 / 직급 없이 "님"으로 소통 · 연차, 반차 사용 / 경조휴가 / 근속 연차별 선물 및 휴가 · 업무 성과에 따른 상여금 · 몇절 및 생일 선물 · 안마의자(4D)[전형 절차] · 서류전형 → 전화 인터뷰 → 1차 면접 → 2차 면접 → 처우협의 → 최종합격 · 포지션에 따라 과제가 주어질 수 있습니다. · 필요 시, 레퍼런스 체크가 진행될 수 있습니다.'),
#  Document(metadata={'rec_idx': 47906939, 'company_nm': '(주)코딧', 'recruit_kewdcdnm': "['서비스기획']", 'company_place': '서울 영등포구', 'career': '3 ~ 10년 · 정규직', 'education': '대학교(4년)↑'}, page_content='서비스 기획(PO) 채용공고 상세 서비스 기획(PO)빠르게 성장하는 코딧에서 서비스 기획(PO)를 찾습니다 코딧(CODIT)은 AI와 빅데이터 기술로 방대한 양의 의안·법령·정책 정보를 분석, 기업에게 맞춤형 정보를 제공하는 플랫폼 기업입니다. 코딧의 서비스는 기업이 지속적인 규제·정책 변화에 선제적으로 대응하고 전략적으로 문제를 해결할 수 있도록 지원합니다. [코딧이 달성한 성과] 시리즈 Pre-A 펀딩 완료(50억), 국내외 글로벌 기업 다수를 고객사로 유치, 국내 최초 및 1등 B2B 규제 리스크 모니터링 플랫폼, 12개의 특허, 전문성 있는 탄탄함 팀이런 일을 하게 되실 예정이에요 · 코딧 B2B SaaS 플랫폼의 전체적인 기획 및 프로덕트 매니징 · 고객의 VoC를 인터뷰 및 설문을 통해 듣고 문제를 정의하여 해결 방안을 다양하게 도출 · 제안된 솔루션이 고객의 문제를 실제로 해결하는지 지표를 정의하고, 이를 검증해 지속적으로 더 나은 개선 방안을 제안 · 사업의 방향 및 매출을 고려하여 전반적인 프로덕트의 생애 전체 주기에 영향을 미치는 결정 및 기능을 기획이런 분을 찾고 있어요 · SaaS 또는 IT 솔루션 서비스 기획을 3년 이상한 경험이 있으신 분 · 디자이너, 개발팀, 사업개발팀 등과의 협업을 통해 고객의 페인포인트를 해결해 본 경험을 다양하게 가지고 계신 분 · 애자일한 프로세스를 경험해 성공 경험이 있으신 분 · 고객의 입장으로 문제를 정의하고 해결해 본 경험을 하신 분 · 비즈니스 임팩트까지 고려하여 논리적으로 문제해결 과정과 임팩트를 파악할 수 있는 지표를 설계해보신 분 · 데이터 기반으로 분석해 의사결정을 내릴 수 있는 분 · 코딧의 Core Value를 가지신 분이런 분이면 더 좋아요 · 어려운 문제를 주도적으로 해결한 경험이 있거나 즐기는 분 · 협업 마인드를 가지고, 적극적이고 열린 태도로 업무에 참여하실 수 있는 분 · 긍정적이고 능동적인 마인드를 보유한 분 · 변하는 상황에 맞춰 다양한 업무를 경험하고 싶은 분 · 성장하는 스타트업을 경험하고 싶으신 수 있는 분 · 코딧의 Core Value를 가지신 분이런 분이면 더 좋아요 · 어려운 문제를 주도적으로 해결한 경험이 있거나 즐기는 분 · 협업 마인드를 가지고, 적극적이고 열린 태도로 업무에 참여하실 수 있는 분 · 긍정적이고 능동적인 마인드를 보유한 분 · 변하는 상황에 맞춰 다양한 업무를 경험하고 싶은 분 · 성장하는 스타트업을 경험하고 싶으신 분지원자분을 더 잘 이해하기 위해 아래 서류를 제출해주세요 · (필수) 이력서 및 자기소개서(성장 배경보다 경험했던 업무에 대해 작성해주세요) · (선택) 포트폴리오이런 혜택과 복지를 지원해드려요 · 업무에 필요한 최신 기기 및 환경 제공 · 여의도역/여의나루역 근처 쾌적한 사무공간 · 점심 및 저녁비 / 다양한 간식 및 음료 제공 · 자율 복장 / 직급 없이 "님"으로 소통 · 연차, 반차 사용 / 경조휴가 / 근속 연차별 선물 및 휴가 · 업무 성과에 따른 상여금 · 몇절 및 생일 선물 · 안마의자(4D)[전형 절차] · 서류전형 → 전화 인터뷰 → 1차 면접 → 2차 면접 → 처우협의 → 최종합격 · 포지션에 따라 과제가 주어질 수 있습니다. · 필요 시, 레퍼런스 체크가 진행될 수 있습니다.'),
#  Document(metadata={'rec_idx': 47944456, 'company_nm': '(주)코딧', 'recruit_kewdcdnm': "['R&D기획', '경영기획']", 'company_place': '서울 영등포구', 'career': '신입 · 인턴직', 'education': '대학교(4년)↑'}, page_content='정부지원 및 국책과제 담당 인턴 채용공고 상세 빠르게 성장하는 코딧에서 정부지원 및 국책과제 담당 인턴을 찾습니다 코딧(CODIT)은 AI와 빅데이터 기술로 방대한 양의 의안·법령·정책 정보를 분석, 기업에게 맞춤형 정보를 제공하는 플랫폼 기업입니다. 코딧의 서비스는 기업이 지속적인 규제·정책 변화에 선제적으로 대응하고 전략적으로 문제를 해결할 수 있도록 지원합니다. [코딧이 달성한 성과] 시리즈 Pre-A 펀딩 완료(50억), 국내외 글로벌 기업 다수를 고객사로 유치, 국내 최초 및 1등 B2B 규제 리스크 모니터링 플랫폼, 12개의 특허, 전문성 있는 탄탄함 팀이런 일을 하게 되실 예정이에요 · 신규 정부지원과제 발굴 및 관리 · 정부지원과제(유니콘/R&D/창업지원/해외진출 프로그램 등) 신청/협약/수행/정산/평가 업무 전반 지원 · 컨소시엄 구성 및 제안 방향 지원 · 정부 포상 및 특허 관리이런 분을 찾고 있어요 · 정보통신, AI 등 IT 기술분야에 대한 이해도나 관심이 높으신 분 · 문서 작성과 프리젠테이션 능력이 뛰어나신 분 · 한글/PPT/엑셀 등 사용이 능숙하신 분 · 평소 꼼꼼하고 책임감이 강하신 분 · 내/외부 커뮤니케이션 역량이 뛰어나신 분 · 코딧의 Core Value를 가지신 분이런 분이면 더 좋아요 · 업무를 꼼꼼하게 수행하시는 분 · 어려운 문제를 주도적으로 해결한 경험이 있거나 즐기시는 분 · 긍정적이고 능동적인 마인드를 보유한 분 · 변하는 상황에 맞춰 다양한 업무를 경험하고 싶으신 분 · 성장하는 스타트업을 경험하고 싶으신 분참고해 주세요 · 해당 포지션은 체험형 인턴 포지션이에요(3개월~1년 / 협의 가능) · 인턴 기간 종료 후 정규직 전환도 가능해요지원자분을 더 잘 이해하기 위해 아래 서류를 제출해주세요 · (필수) 이력서 및 자기소개서(성장 배경보다 업무와 관련된 경험에 대해 작성해주세요) · (선택) 포트폴리오이런 혜택과 복지를 지원해드려요 · 업무에 필요한 최신 기기 및 환경 제공 · 삼성중앙역 근처 쾌적한 사무공간 · 점심 및 저녁비 / 다양한 간식 및 음료 종료 후 정규직 전환도 가능해요지원자분을 더 잘 이해하기 위해 아래 서류를 제출해주세요 · (필수) 이력서 및 자기소개서(성장 배경보다 업무와 관련된 경험에 대해 작성해주세요) · (선택) 포트폴리오이런 혜택과 복지를 지원해드려요 · 업무에 필요한 최신 기기 및 환경 제공 · 삼성중앙역 근처 쾌적한 사무공간 · 점심 및 저녁비 / 다양한 간식 및 음료 제공 · 자율 복장 / 직급 없이 "님"으로 소통 · 연차, 반차 사용 / 경조휴가 / 근속 연차별 선물 및 휴가 · 업무 성과에 따른 상여금 · 몇절 및 생일 선물 · 안마의자(4D)[전형 절차] · 서류전형 → 전화 인터뷰 → 1차 면접 → 2차 면접 → 처우협의 → 최종합격 · 포지션에 따라 과제가 주어질 수 있습니다. · 필요 시, 레퍼런스 체크가 진행될 수 있습니다.'),
#  Document(metadata={'rec_idx': 47996860, 'company_nm': 'N&F벤처파트너스', 'recruit_kewdcdnm': "['사무직', '문서작성', '사무보조', '자료조사', 'Excel']", 'company_place': '대구 북구 외', 'career': '경력무관 · 정규직 외', 'education': '고졸↑'}, page_content='중소기업경영지원 섭외팀 공채\n\n채용공고 상세\n\xa0\n\xa0\n중소기업경영지원 섭외팀 공채\n안녕하세요\n당사는 중소기업 성장과 생산성 향상을 지원하기 위해 중소기업경영애로를 접수하고, \n투자와 정부지원이 필요한 중소기업들을 섭외하고 있습니다. \n당사와 함께 중소기업지원업무를 오랫동안 함께할 열정가득한 상담원을 채용중에 있으니 많은 관심바랍니다.\n모집부문\n 모집\n부문\n담당업무\n 근무시간\n급여\n 우대요건\n섭외\n마케팅부\nㆍ중소기업경영애로 상담접수\nㆍ중소기업자금 상담접수\nㆍ그 외 각종 기업 지원시책안내\nㆍ전문상담사, 플래너로 육성\n\xa0\xa0\xa0\n(온 · 오프라인, 아웃바운드\n\xa0\xa0\xa0\n상담포함)\n9:00~18:00\n\n(주5일 )\n\n※수습기간엔 \n7시간 미만\n법인카드포함 기본급\n(신입 월250만원 )\n+성과급 별도\n+장려금 별도\n바이럴 마케팅 경력자\nTM파트 \n교육실장,팀장급\n금융회사 경력자\n 근무조건\nㆍ근무형태 : 정규직 (외부교육15일, 수습 3개월있음)\nㆍ근무일시 : 주5일\nㆍ인근전철 : 대구1호선대구역에서300m이내\nㆍ근무지역 : (41587) 대구북구 중앙대로 507 현운빌딜 4층\n 제출서류 \nㆍ이력서, 자기소개서 \n 접수기간 및 방법 \n ㆍ접수기간 : 2025년 03월 31일 24시 마감\nㆍ접수방법 : 사람인 온라인 입사지원\n 문의사항 \nㆍ담당자 : 임영경 실장\nㆍ연락처 : 053-243-3805\n 기타사항 \nㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.'),
#  Document(metadata={'rec_idx': 48339934, 'company_nm': '(주)코딧', 'recruit_kewdcdnm': "['정책연구']", 'company_place': '서울 영등포구', 'career': '경력무관 · 인턴직', 'education': '학력무관'}, page_content='정책팀 인턴 채용\n\n채용공고 상세\n코딧을 소개해요코딧(CODIT)은 AI와 빅데이터 기술로 방대한 양의 의안.법령.정책 정보를 분석, 기업에게 맞춤형 정보를 제공하는 플랫폼 기업입니다. 코딧의 서비스는 기업이 지속적인 규제.정책 변화에 선제적으로 대응하고 전략적으로 문제를 해결할 수 있도록 지원합니다.더 자세한 소개는 코딧의 채용 페이지를 확인하세요. 코딧 정책팀은요오랜 국회.정부 경험을 가진 전문가들로 구성되어 있으며, 고객이 기업 활동에만 집중할 수 있도록 정책.규제 업무 전반을 지원합니다. 또한 고객사의 니즈에 맞춘 코딧 플랫폼의 전반적인 개발 방향을 기획합니다.이런 일을 정책팀과 함께 하시게 될 예정이에요다양한 분야(의료, 플랫폼, 환경 등)에서의 정책자료 리서치각종 정책토론회&세미나 자료 분석 정리코딧 플랫폼 테스트 및 기획 관련 리서치각종 이벤트 준비 지원그 외 다양한 정책팀 업무 지원이런 분을 찾고 있어요정책팀의 업무를 전반적으로 지원해주실 수 있는 분유연한 문제해결 능력과 투명한 커뮤니케이션 역량을 보유한 분담당 업무에 몰입할 수 있고, 그 과정에서 얻게 되는 성취와 성장에 가치를 두는 분다양한 사회 이슈와 의회에 대해 관심과 이해가 있는 분이런 분이면 더 좋아요어려운 문제를 주도적으로 해결한 경험이 있거나 즐기는 분긍정적이고 능동적인 마인드를 보유한 분변하는 상황에 맞춰 다양한 업무를 경험하고 싶은 분성장하는 스타트업을 경험하고 싶으신 분참고해 주세요해당 포지션은 인턴 포지션이에요(6개월 / 협의 가능)2024년 졸업자 및 졸업 예정자인턴 기간 종료 후 정규직 전환도 가능해요이렇게 합류해요서류 접수 → 화상면접 (1차) → 대면면접 (2차)\xa0→\xa0최종 합격*전형 일정은 변경될 수 있습니다이런 혜택과 복지를 드려요업무에 필요한 최신 기기 및 환경 제공여의도역/여의나루역 더 현대 근처 쾌적한 사무공간자율 복장 / 직급없이 "님"으로 소통식사 및 다양한 간식 제공최고급 안마의자'),
#  Document(metadata={'rec_idx': 48383234, 'company_nm': '(주)컬리', 'recruit_kewdcdnm': "['물류자동화', '출고/출하']", 'company_place': '경기 김포시', 'career': '경력무관 · 정규직', 'education': '학력무관'}, page_content='[컬리] 김포 클러스터 출고 운영 관리 스탭 채용공고 상세 우리와 꼭 맞는 마음을 가진 푸드마켓, 직접 만들어보면 어떨까?2015년 컬리는 그렇게 시작되었습니다.환경과 상품, 그리고 사람이 선순환을 이루는컬리의 유통구조는 E-Commerce의 표준이 되었습니다.이제 컬리는 또 다른 새로움에 도전합니다.컬리만의 신뢰와 데이터가 일상의 경험을 변화시킬 수 있도록모두를 연결하는 플랫폼, 모두에게 사랑 받는 라이프스타일 파트너가 되고자 합니다. 이 여정에는 당신이 필요합니다.최고의 동료들과 함께 사랑과 신뢰를 받는 브랜드 컬리를 만들어 나갈 여러분을 기다립니다. Better Food, Better Product, Better Life for All.조직 소개컬리 운영(Operations) 조직은 최고의 상품을 파트너사로부터 제공받아, 최적의 상태로 고객들에게 전해드리는 Value Chain 프로세스 운영을 담당하고 있으며, 고객 및 구성원 경험 극대화를 위해 물류프로세스 개선 및 KPI 관리를 통한 운영 최적화 활동을 수행하고 있습니다.주요 업무ㆍ 출고 현장 및 전산 운영 관리ㆍ 각 공정 운영 및 진척도 관리ㆍ 약 40명 인력관리 운영ㆍ 생산성 향상 및 현장 운영 개선자격 요건ㆍ 신입 또는 관련 업무 경험(5년 이하)을 보유하신 분ㆍ Excel, Google Spreadsheet 사용 경험이 있으신 분ㆍ 구성원들과 함께 일하며 효율적 업무 환경 조성의 경험을 갖추신 분ㆍ Kurly Way 및 Kurly 윤리강령 실현의 모범이 되어주실 분우대 사항ㆍ E-commerce기반의 물류센터에서 업무 경험이 있으신 분ㆍ 물류프로세스에 대한 문제점 파악 및 개선의 경험이 있으신 분ㆍ WMS 사용 경험이 있으신 분ㆍ 관련 학과를 졸업하신 분 (물류·유통·산업공학 등)ㆍ 관련 자격증을 소지하신 분 (물류관리사·유통관리사 등)합류 여정ㆍ 서류 검토 > 직무 적합성 인터뷰 > 인성검사 > 종합 인터뷰 > 처우 제안 > 최종 합격ㆍ 지원서 제출 시 이력서(자유 양식)를 꼭 첨부해 주세요. (필수)ㆍ 세부 절차는 서류 합격자 분들께 개별 안내드릴 사용 경험이 있으신 분ㆍ 관련 학과를 졸업하신 분 (물류·유통·산업공학 등)ㆍ 관련 자격증을 소지하신 분 (물류관리사·유통관리사 등)합류 여정ㆍ 서류 검토 > 직무 적합성 인터뷰 > 인성검사 > 종합 인터뷰 > 처우 제안 > 최종 합격ㆍ 지원서 제출 시 이력서(자유 양식)를 꼭 첨부해 주세요. (필수)ㆍ 세부 절차는 서류 합격자 분들께 개별 안내드릴 예정입니다.ㆍ 프로세스는 일정과 상황에 따라 사전 안내 후 일부 변경될 수 있으며, 각 전형의 결과는 개별 안내드립니다.혜택 및 복지ㆍ 임직원이 가장 소중한 고객이니까, 컬리 적립금 지급 *입사 100일 축하 및 분기별 정기ㆍ 태어난 날은 누구보다 행복해야 하니까, 축하적립금지급 *생일당일 2시간 조기 퇴근ㆍ 지칠 때 위로가 되는 다과, 간식 지원ㆍ 일상의 리프레시도 필요하죠, 월 퍼플데이 제도 운영 *법적 연차 외 별도 유급반차(0.5일) 제공ㆍ 컬리의 성장에 기여한 감사의 의미를 담아, 장기근속 유급 휴가(휴가비) 지원ㆍ 지친 당신의 멘탈 케어를 위해, 프라이빗 심리 상담 지원ㆍ 당신과의 첫인상 정말 중요하니까, 웰컴키트 선물ㆍ 건강한 신체만큼 중요한 건 없으니까, 의료비&건강검진 지원 *단체상해보험지원ㆍ 기쁨은 축복하고 슬픔은 위로해요, 경조사 지원 *축하금(결혼, 돌, 생일, 출산) 및 조의금(본인/배우자 사망 등) *유급휴가 적용ㆍ 임직원을 위한 또 다른 선물, 다양한 제휴 혜택 운영 *호텔, 쇼핑몰 등 다양한 임직원 제휴 혜택ㆍ 부모와 아이가 함께 행복하도록, 위탁보육 지원 제도 운영*위탁보육비 지원(재직 3개월 이상, 만 0~5세 자녀 대상)ㆍ 안전한 출퇴근길 컬리가 도와드려요, 셔틀버스 운행 *노선도(Link)기타 안내사항ㆍ 고용형태 : 정규직 (수습 3개월) 또는 계약직 (1년)ㆍ 소속(예정) 부서 : FC 출고파트 ㆍ 근무시간 : 16:00 ~ 01:00, 팀 내 근무계획에 따른 주 5일 스케줄 근무(월~일 중, 5일 근무)ㆍ 근무지 : 경기도 김포시 고촌읍 아라육로 75, 컬리 김포 안전한 출퇴근길 컬리가 도와드려요, 셔틀버스 운행 *노선도(Link)기타 안내사항ㆍ 고용형태 : 정규직 (수습 3개월) 또는 계약직 (1년)ㆍ 소속(예정) 부서 : FC 출고파트 ㆍ 근무시간 : 16:00 ~ 01:00, 팀 내 근무계획에 따른 주 5일 스케줄 근무(월~일 중, 5일 근무)ㆍ 근무지 : 경기도 김포시 고촌읍 아라육로 75, 컬리 김포 물류센터지원 시 유의사항ㆍ 국가 유공자, 장애인 등 취업보호대상자는 관계 법령에 따라 우대합니다.ㆍ 해외여행에 결격 사유가 없어야 하며, 남성은 군필 혹은 면제자여야 합니다.ㆍ 지원서에 기재된 내용 중 허위 사실이 발견될 경우 채용이 취소될 수 있습니다.[채용 서류 반환에 관한 안내]ㆍ 채용 절차 공정화에 관한 법률에 따른 당사의 채용 서류 반환 절차에 대해 아래와 같이 안내해 드립니다.1. (주) 컬리 채용에 지원하여 최종 합격이 되지 못한 구직자는 제출한 서류의 반환을 청구할 수 있음을 알려 드립니다. (이메일, 온라인 지원 등 지원자가 자발적으로 제출한 서류는 반환 대상 서류에 해당하지 않으며, 천재지변이나 그 밖에 회사에 책임이 없는 사유로 채용 서류가 멸실되거나 관련 법에 따라 서류를 파기한 경우 반환한 것으로 봅니다.)2. 채용 서류 반환 청구는 이메일(Fc_Recruiting@Kurlycorp.com)으로 접수받고 있습니다.(채용 서류 반환 청구 시 본인 확인 및 정확한 서류 반환을 위하여, ‘성명, 이메일, 주소, 생년월일, 서류의 종류, 지원 공고 명’을 기재해 주셔야 합니다.)3. 채용 서류 반환 청구에 드는 비용은 원칙적으로 회사에서 부담하지만, 대통령령으로 정하는 범위에서 채용 서류의 반환에 드는 비용은 지원자가 부담할 수 있습니다.[임산부 지원 주의 안내]1. 임산부는 임신 중인 여성, 산후 1년 이내인 분을 포함합니다.2. 임산부는 법에서 금지하는 직종(고열/한랭 작업, 중량물을 취급하는 업무 등)에 근로가 불가합니다. (근로기준법 제65조)3. 임산부는 연장근로가 금지되며, 법에서 정한 대통령령으로 정하는 범위에서 채용 서류의 반환에 드는 비용은 지원자가 부담할 수 있습니다.[임산부 지원 주의 안내]1. 임산부는 임신 중인 여성, 산후 1년 이내인 분을 포함합니다.2. 임산부는 법에서 금지하는 직종(고열/한랭 작업, 중량물을 취급하는 업무 등)에 근로가 불가합니다. (근로기준법 제65조)3. 임산부는 연장근로가 금지되며, 법에서 정한 예외 조건을 제외 야간/휴일 근로가 금지됩니다. (근로기준법 제74조, 근로기준법 제70조)4. 건강과 안전을 위해 임산부는 다음\xa0근무시간 대/부서 근무가 불가능하오니(지원이 불가하며 채용 취소가 될 수 있습니다.)\xa0근무시간 대/장소를 반드시 확인 후\xa0지원해 주시기를 바랍니다.(문의처 –\xa0FC채용팀\xa0Fc_Recruiting@Kurlycorp.com)ㆍ 야간/심야시간 근무ㆍ 냉장/냉동FC 업무ㆍ HUB 등 관련 법령에서 금지된 업무해당 채용에 관한 문의는Fc_Recruiting@Kurlycorp.com 으로 부탁드립니다.'),
#  Document(metadata={'rec_idx': 48389016, 'company_nm': '메디앙스(주)', 'recruit_kewdcdnm': "['그래픽디자인', '배너디자인', '웹디자인']", 'company_place': '서울 강남구', 'career': '3 ~ 10년 · 계약직', 'education': '대학교(4년)↑'}, page_content='[메디앙스] 디자인팀 웹디자이너 계약직 채용 (경력)\n\n채용공고 상세\n메디앙스와 함께 산업을 움직일 인재를 찾습니다.모집분야디자인팀 웹디자이너 경력 채용주요업무 · 온라인 웹, 컨텐츠 전반의 그래픽 디자인 · 신규 상세페이지 디자인 · 온라인 배너, 프로모션 디자인 · SNS 광고 소재 제작 · 작업물 리터칭 및 보정작업, 제품 시뮬레이션 작업 · POP 및 포스터 제작 작업자격요건 · 학력 : 대졸 이상 (4년) · 일러스트레이터, 포토샵 활용 가능자 우대사항 · 웹디자인 경력 3년 이상 · 생활용품, 화장품, 유아용품 업계 업무 경험자 · 패키지디자인 업무 경험자Benefits1. 성장지원 · 업무 관련 도서비 지원 · 직무 / 어학 이러닝 교육 지원 · 사내 동아리 운영 및 활동비 지원2. 리프레쉬 · 자유로운 연차 및 샌드위치 연차 사용 권장 · 불필요한 야근 지양 · 연장 근로 시 보상휴가 제공 [전형 절차] · 서류전형 → 1차 면접 (실무진) → 2차 면접 →최종합격[제출 서류] · 이력서, 경력기술서, 포트폴리오 등 · 채용 사이트 양식 또는 자유 양식 첨부 가능'),
#  Document(metadata={'rec_idx': 48465017, 'company_nm': '서울기업교육협회', 'recruit_kewdcdnm': "['ER(노무관리)', 'HR컨설팅', 'HRD', 'HRM', '법정의무교육']", 'company_place': '서울 영등포구 외', 'career': '신입 · 정규직 외', 'education': '학력무관'}, page_content='2025년 법정의무교육 CS강사 신입 모집 채용공고 상세\n \n 서울기업교육협회ㅣ2025년 법정의무교육 CS강사 신입 모집\n업종\t교재·학습지 > 기업교육\n직종\t선택 : 기획·전략 > 전문분야 > 금융컨설팅\n선택 : 회계·세무·재무 > 직무·직업 > 재무\n선택 : 인사·노무·HRD > 직무·직업 > 인사\n선택 : 인사·노무·HRD > 직무·직업 > ER(노무관리)\n선택 : 인사·노무·HRD > 직무·직업 > HRD\n선택 : 인사·노무·HRD > 직무·직업 > HRM\n선택 : 인사·노무·HRD > 직무·직업 > HR컨설팅\n선택 : 인사·노무·HRD > 담당분야 > 법정의무교육\n선택 : 인사·노무·HRD > 담당분야 > 인사교육\n선택 : 인사·노무·HRD > 담당분야 > 직업훈련\n선택 : 영업·판매·무역 > 직무·직업 > 영업\n선택 : 영업·판매·무역 > 직무·직업 > 영업관리\n선택 : 영업·판매·무역 > 담당분야 > 기업영업\n선택 : 고객상담·TM > 직무·직업 > 상담원\n선택 : 고객상담·TM > 직무·직업 > 섭외TM\n선택 : 고객상담·TM > 담당분야 > 고객관리\n선택 : 고객상담·TM > 담당분야 > 교육상담\n선택 : 교육 > 직무·직업 > 교육운영\n선택 : 교육 > 직무·직업 > 교직원\n선택 : 교육 > 직무·직업 > 보조강사\n선택 : 교육 > 직무·직업 > 직업훈련\n선택 : 교육 > 직무·직업 > 학습매니저\n선택 : 교육 > 직무·직업 > 학원강사\n선택 : 교육 > 직무·직업 > CS강사\n선택 : 교육 > 전문분야 > 기업교육\n선택 : 교육 > 전문분야 > 인성교육\n선택 : 교육 > 전문분야 > 학생지도\n선택 : 교육 > 전문분야 > 학원생관리\n선택 : 교육 > 근무장소 > 직업전문학교\n선택 : 교육 > 교육과목 > 경제\n선택 : 미디어·문화·스포츠 > 직무·직업 > 쇼호스트\n선택 : 금융·보험 > 전문분야 > 기업금융\n선택 : 금융·보험 > 전문분야 > 재무분석\n근무지 주소\t(07281) 서울 영등포구 선유로 59 문래 아카데미 선택 : 교육 > 전문분야 > 학원생관리\n선택 : 교육 > 근무장소 > 직업전문학교\n선택 : 교육 > 교육과목 > 경제\n선택 : 미디어·문화·스포츠 > 직무·직업 > 쇼호스트\n선택 : 금융·보험 > 전문분야 > 기업금융\n선택 : 금융·보험 > 전문분야 > 재무분석\n근무지 주소\t(07281) 서울 영등포구 선유로 59 문래 아카데미\n노출지역\t 서울 > 관악구, 서울 > 광진구, 서울 > 구로구, 서울 > 금천구, 서울 > 마포구, 서울 > 송파구, 서울 > 영등포구, 경기 > 고양시, 경기 > 김포시, 인천 > 인천전체'),
#  Document(metadata={'rec_idx': 48493816, 'company_nm': '(주)심슨교육', 'recruit_kewdcdnm': "['더존', '법인결산', '부가세신고', '회계결산', '사무직']", 'company_place': '서울 광진구 외', 'career': '신입 · 경력 · 정규직 외', 'education': '대학(2,3년)↑'}, page_content='2024 심슨어학원 부문별 인재채용\n\n채용공고 상세\n 모집부문\n자격요건 및 우대사항\n 근무시간\n근무지역\n영어 전임강사\n[초/중/고]\n [자격요건]\nㆍ4년제 대학 졸업(예정 포함) 이상\n\n[우대사항]\nㆍ초등 : 이중언어 수업 가능자\nㆍ중·고등 : 수능독해와 내신 유경험자\n[초.중등]\nㆍ주5일 [월~금 14-22시]\nㆍ주3일 [월수금 14-22시]\nㆍ주3일 [화목토 14-22시]\nㆍ주3일 [화목일 14-22시]\n\n[고등]\nㆍ주4일/주5일/주6일\n\xa0\xa0\n[평일 14-22시, 주말 10-16시]\n\xa0\xa0\n(경력직은 비율제 협의 가능)\nㆍ서울특별시\n강남구 대치동,\n광진구 광장동,\n자양동,\n노원구 중계동,\n성동구 왕십리,\n강동구 고덕동\n\nㆍ경기도\n위례신도시,\n미사신도시,\n구리 수택동\n이중언어\n강사\n [자격요건]\nㆍ4년제 대학 졸업(예정 포함) 이상\nㆍ영어로 수업 가능한 자\nㆍ주 5일 월~금\n\xa0\xa0\xa0 (14:00~22:00)\n관리자\n(상담직,\n학원관리)\n [자격요건]\nㆍ2, 3년제 대학 졸업(예정 포함) 이상\n\xa0\xa0\xa0cf) 신입 적극환영(교육 후 캠퍼스발령)\n\n[우대사항]\nㆍ상담과 홍보관련 우수자\nㆍ컴퓨터 OA 능력 우수자\nㆍ주 5일 + 토요일 격주근무\nㆍ월~금(13:30~22:30),\n\xa0\xa0\xa0\n토(10:00~15:00)\n유치부\n(부원장/\n교수부장/\n한국인 담임)\n [자격요건]\nㆍ2, 3년제 대학 졸업 이상\nㆍ부원장/교수부장 : 3년이상 직책경험자\n\xa0\xa0\xa0cf) 한국인 담임 신입 환경(교육 후 발령)\n\n[우대사항]\nㆍ유아교육, 교육, 영어전공자\nㆍ주 5일 월~금\n\xa0\xa0\xa0 (08:30~17:30)\n광진구 광장동\n성동구 왕십리\n유치부 원장\n [자격요건]\nㆍ2, 3년제 대학 졸업 이상\nㆍ부원장/교수부장 : 3년이상 직책경험자 [우대사항]\nㆍ유아교육, 교육, 영어전공자\nㆍ주 5일 월~금\n\xa0\xa0\xa0 (08:30~17:30)\n광진구 광장동\n성동구 왕십리\n유치부 원장\n [자격요건]\nㆍ2, 3년제 대학 졸업 이상\nㆍ부원장/교수부장 : 3년이상 직책경험자\n\n[우대사항]\nㆍ유아교육, 교육, 영어전공자\nㆍ주 5일 월~금\n\xa0\xa0\xa0 (08:30~17:30)\n광진구 광장동\n성동구 왕십리\n복리후생(모집부분 공통 사항) ㆍ4대 보험 ㆍ퇴직연금 제도 ㆍ법정연차휴가 제공, 법정 공휴일 휴무\nㆍ상조 휴가 / 상조회 규정에 따른 경조사비 지급 ㆍ재직자 가족 심슨어학원 재원시 수강료 할인\n출판\n [자격요건]\nㆍ4년제 대학 졸업(예정 포함) 이상\nㆍ컨텐츠 작업 경력 1년 이상\n\n[우대사항]\nㆍ해외 대학 출신으로 토플 교재 저술 경험자\nㆍ수업(강의) 가능하신 분\nㆍ주 5일 월~금 (09:30~18:30)\n광진구 광장동\n경영지원\n(인사/\n마케팅/회계)\n [자격요건]\nㆍ4년제 대학 졸업(예정 포함) 이상\n\n[우대사항]\nㆍ관련분야 자격증 소지자\nㆍ학원 경력자\nㆍ주 5일+토요 격주근무\nㆍ월~금(13:30-22:30),\n\xa0\xa0\xa0\n토(10:00-15:00)\n\xa0\xa0\xa0\n근무시간 협의가능\nDebate\n강사\n [자격요건]\nㆍ4년제 대학 졸업(예정포함) 이상\nㆍ강의 경력 1년 이상\n\n[우대사항]\nㆍ영어토론대회 경험이 있으신 선생님\nㆍ주 5일 월~금 (14:00~22:00)\n\xa0\xa0\xa0\n근무시간 협의가능\n원어민\n관리담당\n [자격요건]\nㆍ4년제 대학 졸업(예정) 이상\nㆍ이중언어 가능자\n\n[우대사항]\nㆍ관련 직무 유경험자\nㆍ주 5일 월~금 (13:00~22:00)\n\xa0\xa0\xa0\n근무시간 협의가능\n경영지원\n셔틀관리\n담당자\n(관리팀장)\n [자격요건]\nㆍ컴퓨터 활용능력(중 이상)\n\xa0\xa0\n(Excel, Word 활용 필수)\nㆍ1종 대형 면허 및 경력 [우대사항]\nㆍ관련 직무 유경험자\nㆍ주 5일 월~금 (13:00~22:00)\n\xa0\xa0\xa0\n근무시간 협의가능\n경영지원\n셔틀관리\n담당자\n(관리팀장)\n [자격요건]\nㆍ컴퓨터 활용능력(중 이상)\n\xa0\xa0\n(Excel, Word 활용 필수)\nㆍ1종 대형 면허 및 경력\n\n[우대사항]\nㆍ인사노무관리 경력자 우대\n\xa0\xa0\n(채용, 평가, 교육, 급여 등)\nㆍ차량 행정업무 경력자 우대\n\xa0\xa0(구청, 교육청 등 관공서 업무 및 \n\xa0\xa0\n통학버스운용시스템 관리 등)\nㆍ주 5일 월~금 (09:00~19:00)\n급여\n 모집부문\n급여\n영어 전임강사\n[초/중/고]\n★ 업계 최고대우 ★\n[급여구성]기본급+인센티브+수당+상여\n1. 기본급 : 강사평가시스템에 의한 능력반영\n2. 인센티브 : 수업과 학생관리에 따라 동기부여\n3. 수당 : 특강비는 따로 지급, 직책수당 등 \n4. 상여 : 강의평가 우수자 및 공로가 있는 경우\n이중언어\n강사\n관리자\n(상담직,\n학원관리)\n★ 업계 최고대우 ★\n[급여구성]기본급+인센티브+수당+상여\n1. 기본급 : 경력과 능력에 따른 연봉평가\n2. 인센티브 : 신입생 유입 월별 인센티브\n3. 수당 : 직책, 특강모집 등\n4. 상여 : 성과 우수자 포상\n유치부\n(부원장/교수부장/한국인 담임)\n★ 업계 최고대우 ★\n[급여구성]기본급+인센티브+수당+상여\n1. 기본급 : 경력과 능력에 따른 연봉평가\n2. 수당 : 추가근무 수당\n3. 상여 : 성과 우수자 포상\n유치부 원장\n★ 업계 최고대우 ★\n[급여구성]기본급+인센티브+수당+상여\n1. 기본급 : 경력과 능력에 따른 연봉평가\n2. 수당 : 추가근무 수당\n3. 상여 : 성과 우수자 포상\n출판\n★ 업계 최고대우 ★\n경영지원\n(인사/마케팅/회계)\n★ 업계 최고대우 ★\nDebate\n강사\n★ 업계 최고대우 ★\n원어민 관리담당\n★ 업계 최고대우 ★\n경영지원\n셔틀관리\n담당자\n(관리팀장)\n★ 업계 최고대우 ★'),
#  Document(metadata={'rec_idx': 48494926, 'company_nm': '이에이트(주)', 'recruit_kewdcdnm': "['기술지원', '데이터분석가', '데이터엔지니어', '백엔드/서버개발', '보안컨설팅']", 'company_place': '서울 송파구', 'career': '신입 · 경력 · 정규직 외', 'education': '학력무관'}, page_content="[코스닥 상장사] 이에이트 신입 및 경력 채용\n\n채용공고 상세\n\xa0\n \n \n이에이트는 국내 No.1 시뮬레이션 기반 디지털 트윈 솔루션 기업입니다.\n국내 최초 순수 국내 기술로 개발된 입자기반 시뮬레이션 소프트웨어 NFLOW 및 디지털 트윈 플랫폼 NDX PRO를 통해 \n시뮬레이션과 디지털 트윈 융합이 필요한 모든 산업분야에서 최고의 파트너가 되고자 국내 최고수준의 인재들과 함께\n연구개발에 매진하고 있습니다. 이에이트의 모든 구성원들은 서로를 '존중'하고,업무와 관련한 다양한 정보들을 '공유'하며, \n각자의 생각을 자유롭게 '소통'하면서함께 회사를 발전시켜 나가고 있습니다.\n\xa0\n \n 모집부문\n솔루션사업본부\n 모집부문\n 담당업무\n 자격요건 및 우대사항\nLBM\n알고리즘 개발\nㆍLBM (Lattice Boltzmann Method)\n\xa0\xa0알고리즘 모델 개발\nㆍ자동차, 항공, 전자, 화학 등 다양한 \n\xa0\xa0산업분야 시뮬레이션의 수치해석적 연구 \nㆍ수치해석용 격자 생성, 형상 처리를 \n\xa0\xa0\xa0위한 전처리 연구 \n자격요건\nㆍ경력 (3~15년) \nㆍ공학계열(기계, 항공, 토목, 조선, 화학) 또는 \n\xa0\xa0자연과학계열(응용수학, 물리) 전공 \n\n우대사항 \nㆍLBM 소프트웨어 (PowerFLOW, XFLOW, \n\xa0\xa0OpenLB, Palabos 등) 사용 경력 \nㆍ상용/오픈소스 CFD 제품(Fluent, STAR-CCM+, \n\xa0\xa0OpenFOAM 등) 사용 경력 \nㆍIn-house 전산수치기법(FVM, FEM, FDM) \n\xa0\xa0코드 연구개발/모델링 경력 \nㆍC++, CUDA 코드 작성 경력 \nSPH\n알고리즘 개발\nㆍSPH (Smoothed Particle \n\xa0\xa0Hydrodynamics) 알고리즘 개발\nㆍ토목, 조선, 자동차 등 다양한 산업분야 \n\xa0\xa0시뮬레이션의 수치해석적 연구 \nㆍ입자기반 CFD 전처리 개발 \n자격요건\nㆍ경력 (3~15년)\nㆍ공학계열(기계, 항공, 토목, 조선, 화학) 또는 \n\xa0\xa0자연과학계열(응용수학, 물리) 전공 우대사항 \nㆍSPH 소프트웨어(ParticleWorks, \n\xa0\xa0DualSPHysics, SPHFlow 등) 사용 경력 \nㆍ상용/오픈소스 CFD 제품(Fluent, STAR-CCM+, \n\xa0\xa0OpenFOAM 등) 사용 경력 \nㆍIn-house 전산수치기법(FVM, FEM, FDM, \n\xa0\xa0DEM) 코드 연구개발 혹은 사용 경력 \nㆍC/C++, CUDA 코드 작성 경력 \n솔루션기획/지원\n솔루션 기획\nㆍCFD 소프트웨어 기획\nㆍ신기술/사업 기획\nㆍ정부 R&D 기획\n\n솔루션 지원\nㆍ사용자 교육\nㆍ기술지원 및 영업관리\nㆍ정부 R&D 과제관리\n자격요건\nㆍ대졸(4년제) 이상 공학계열(기계, 자동차, \n\xa0\xa0\xa0항공우주, 조선, 토목, 산업/시스템) 전공자\nㆍ신입 또는 경력 10년 미만자/전문연구요원\n\xa0\xa0(병역특례)\nㆍ경력자의 경우, 경력기술서 필수 제출\n우대사항 \nㆍ석사 학위 이상 소유자\nㆍ소프트웨어 기획 또는 관련 업무 경험자\nㆍ상용/오픈소스 CFD 프로그램 사용 경력자\nㆍ정부지원사업 및 R&D 과제 기획/수행 경험자\nㆍMS-Office, 한글 문서 작성 우수자\nApplication Engineer\nㆍCFD 솔루션 기반 용역\nㆍ자사 프로그램 검증\n\xa0\xa0 (솔버, 전처리기, 소스코드)\nㆍ산업 활용 기술사례 확보\n자격요건\nㆍ학사 이상\nㆍ신입, 경력(10년 이하), 전문연구요원(병역특례)\nㆍ경력자의 경우, 경력기술서 또는 포트폴리오\n\xa0\xa0\xa0필수 제출\n우대사항 \nㆍ석사 학위 이상 소유자\nㆍ상용/오픈소스 CFD 프로그램 사용 경력자\nㆍ구조/동역학 해석 프로그램 사용 경력자\nㆍIn-house code 사용 및 개발 경험자\nㆍ기계, 자동차, 항공우주, 조선, 토목 등 공학계열\nㆍ응용수학, 물리 전공자 등\n플랫폼사업본부\n 모집부문\n 담당업무\n 자격요건 및 우대사항\n유니티 개발\nㆍ디지털트윈어플리케이션/컨텐츠 개발\nㆍUnity 기반 통합 시스템 개발\n자격요건\nㆍ경력 5년이상,팀장급\nㆍ학력 무관\nㆍUnity Engine 활용 경험\nㆍ3D 그래픽스에 대한 이해 우대사항 \nㆍ디지털트윈어플리케이션/컨텐츠 개발 경험\nㆍC#, 자료구조, 알고리즘 이해 및 N/W 프로그래밍\nㆍ성능 최적화 및 버그 수정\nㆍ컴퓨터 공학 등 IT 관련 학과 전공자\n디지털트윈\n플랫폼 \n백엔드 개발\nㆍ디지털트윈플랫폼 기반 백엔드 기술 개발\nㆍSpring Boot 기반 마이크로 서비스 개발\nㆍ백엔드 플랫폼 관리\n자격요건\nㆍ경력5년이상, 팀장급\nㆍ학력 무관\nㆍSpring Boot 기반 서비스 개발\n\n우대사항 \nㆍ디지털트윈컨텐츠 개발 경험\nㆍ원만한 커뮤니케이션 및 협업 능력 보유\nㆍMSA 기반 개발 경험\nㆍCloud Infra 활용 경험\nㆍnGrinder, Jmeter등을 활용하여\xa0API\xa0성능 \n\xa0\xa0\xa0 측정을 즐기는 분\nㆍDocker 활용 가능\nㆍGit 등의 SCM을 통한 협업 경험 보유\n디지털트윈\n응용서비스\n개발 이행\nㆍ디지털트윈응용서비스 구축 프로젝트 \n\xa0\xa0\xa0\n수행(사업관리)\n자격요건\nㆍ경력10년 이상\n\xa0\xa0\xa0\n(경력기술서 필수, SI사업 수행경력 필수)\nㆍ학사 이상\nㆍ한 가지 이상 프로그래밍 언어 유 경험자\n\xa0\xa0\xa0 (Java, C/C++, 닷넷)\n\n우대사항 \nㆍ능동적인자세와 활발한 커뮤니케이션 역량 보유자\nㆍ개발 프로젝트 리딩 경험 (경력)\nㆍ공공사업 수행 경험 우대(PM/PL 또는\n\xa0\xa0\xa0 Archtect 경력자 우대)\nㆍMSA 클라우드, RestAPI 경험 우대\nㆍJAVA 개발경력\n언리얼 개발\nㆍ디지털트윈어플리케이션/컨텐츠 개발\nㆍ언리얼 기반 통합 시스템 개발\n자격요건\nㆍ경력3년~10년\nㆍ학력 무관\nㆍUnreal Engine 활용 경험\nㆍ3D 그래픽스에 대한 이해 우대사항 \nㆍ디지털트윈어플리케이션/컨텐츠 개발 경험\nㆍC++, 자료구조, 알고리즘 이해 및 \n\xa0\xa0\xa0 N/W 프로그래밍\nㆍ성능 최적화 및 버그 수정\nㆍ컴퓨터공학 등 IT 관련 학과 전공자\n3D \nGeneralist\nㆍ실감, 몰입형 3D 컨텐츠 리소스 제작\nㆍ레벨디자인 및 프리비즈 작업 진행\nㆍ각종 에셋을 활용한 디자인 작업\nㆍ라이팅 및 룩뎁 작업\nㆍ3D 엔진에서 활용 가능한 메쉬 최적화 및\n\xa0\xa0\xa0 머트리얼 업무\n자격요건\nㆍ어도비 프로그램(포토샵, 일러스트,\n\xa0\xa0\xa0 프리미어프로, 에프터이펙트) 디자인 기본 \n\xa0\xa0\xa0 툴 활용 경력 2년 이상\nㆍ3ds Max, Maya 등 3D 모델링 프로그램 \n\xa0\xa0\xa0활용 경력 2년 이상\n\n우대사항 \nㆍ산업 디자인 및 유관 디자인 전공자\nㆍ디자인 관련 수상 경력 보유자\nㆍ디자인 관련 전문 자격증 보유자\nㆍ게임 개발 엔진 툴 사용 경험\n개발본부\n 모집부문\n 담당업무\n 자격요건 및 우대사항\nApplication\nDeveloper\nㆍWindows 기반 Desktop Application 개발\n자격요건\nㆍ신입/경력 3년 이상\nㆍ학력 무관\nㆍC/C++, 자료구조, 알고리즘 이해\nㆍ포트폴리오(경력기술서) 필수 제출\nㆍ새로운 기술 습득에 대해 열정이 있으신 분\nㆍ동료에게 지식을 공유하기 좋아하는 분 ...
#  Document(metadata={'rec_idx': 48517562, 'company_nm': '주식회사다원코퍼레이션', 'recruit_kewdcdnm': "['영업지원', '영업직', '판매직', 'B2C', '거래처관리']", 'company_place': '경기 부천시 외', 'career': '경력무관 · 프리랜서', 'education': '학력무관'}, page_content='상품 견적 컨설팅/전문직양성\n\n채용공고 상세\n \nRECRUIT\n\xa0\n~ 채용시 마감\n\xa0\n주식회사다원코퍼레이션\n상품 견적 컨설팅/전문직양성\n다음과 같이 유능하고 역량있는 인재를 채용합니다.\n진취적으로 미래를 함께 이끌어가실 분들의 많은 지원 바랍니다.\n근무조건\nㆍ근무형태 : 프리랜서\nㆍ근무지 : 경기도 부천시 부일로199번길 21, 5층\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0인천광역시 남동구 선수촌공원로17번길1 , 구월테크노밸리A동 6층\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0인천광역시 부평구충선로203번길 24, 삼산빌딩 6층 \nㆍ인근전철 : 서울 1호선 송내 에서 300m 이내\n 전형절차\n 접수기간 및 방법\nㆍ접수기간 : 채용시 마감\nㆍ접수방법 : 사람인 온라인 입사지원\nㆍ이력서양식 : 사람인 온라인 이력서\n유의사항 \nㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.'),
#  Document(metadata={'rec_idx': 48594542, 'company_nm': '(주)코딧', 'recruit_kewdcdnm': "['채용담당자', '채용공고관리', '채용설명회']", 'company_place': '서울 영등포구', 'career': '신입 · 인턴직', 'education': '학력무관'}, page_content='채용 매니저 인턴\n\n채용공고 상세\n빠르게 성장하는 코딧에서 채용 매니저를 찾습니다 코딧의 채용 매니저는 인재 채용 절차의 A to Z를 관리하고 개선합니다. 특히, 각 팀에서 채용하는 인재에 대한 깊은 이해를 바탕으로 인재를 소싱하고 검증합니다. 주요업무"우리와 함께 할 업무에요."- 채용 프로세스 Full Cycle 운영 및 개선- 채용 채널 운영 / 다양한 채널을 통한 채용 브랜딩(언론 포함)- 전체 채용 프로세스 코디네이션 및 채용 데이터 관리- 아웃바운드 채용 소싱- 각 팀과 긴밀하게 협의하여 필요한 인재상을 도출- 온보딩 프로세스 기획 및 운영- 채용 행사 등 기획 및 운영자격요건"이런 분과 함께 하고 싶어요."- 스크리닝부터 최종 면접 및 온보딩 안내까지 전 과정을 운영에 관심이 있으신 분- 내/외부 커뮤니케이션 역량이 뛰어나신 분- 채용과 관련한 트렌드와 브랜딩 활동에 관심이 있으신 분우대사항"이런 경험이 있으시면 더 좋아요."- 어려운 문제를 주도적으로 해결한 경험이 있거나 즐기는 분- 긍정적이고 능동적인 마인드를 보유한 분- 변하는 상황에 맞춰 다양한 업무를 경험하고 싶은 분- 성장하는 스타트업을 경험하고 싶으신 분Benefits- 업무에 필요한 최신 기기 및 환경 제공- 여의도역/여의나루역 근처 쾌적한 사무공간- 점심 및 저녁비/다양한 간식 및 음료 제공- 자율 복장 / 직급 없이 "님"으로 소통- 연차, 반차, 반반차 사용/ 경조휴가 / 근속 연차별 선물 및 휴가- 업무 성과에 따른 상여금- 명절 및 생일 선물- 안마의자 (4D)[전형 절차] · 서류전형 → 과제 전형 → 화상 면접→ 대면면접 → 처우 협의 → 최종 합격 · 포지션에 따라 추가 면접 또는 커피챗이 진행될 수 있습니다. · 필요 시, 레퍼런스 체크가 진행될 수 있습니다.[제출 서류] · 자유 양식의 이력서 (경력 세부사항 포함) · 자유 양식의 포트폴리오 또는 자기소개서(필수아님)'),
#  Document(metadata={'rec_idx': 48756041, 'company_nm': '(주)아트앤매니지먼트', 'recruit_kewdcdnm': "['기획MD', '브랜드MD', '온라인MD', 'AMD', '브랜드관리']", 'company_place': '서울 강남구 외', 'career': '신입 · 경력 · 정규직', 'education': '대학교(4년)↑'}, page_content='인하우스 제품 브랜드 기획 마케팅 # 온라인 광고 퍼포먼스 채용공고 상세\n\t\n㈜아트앤매니지먼트 | 인하우스 제품 브랜드 기획 마케팅 # 온라인 광고 퍼포먼스\n업종\t기타제조업 > 제조업 회사본사\n직종\t선택 : 기획·전략 > 전문분야 > 리서치\n선택 : 기획·전략 > 전문분야 > 시장조사\n선택 : 기획·전략 > 전문분야 > 신사업기획\n선택 : 기획·전략 > 전문분야 > 트렌드분석\n선택 : 마케팅·홍보·조사 > 직무·직업 > 광고마케팅\n선택 : 마케팅·홍보·조사 > 직무·직업 > 글로벌마케팅\n선택 : 마케팅·홍보·조사 > 직무·직업 > 디지털마케팅\n선택 : 마케팅·홍보·조사 > 직무·직업 > 마케팅기획\n선택 : 마케팅·홍보·조사 > 직무·직업 > 마케팅전략\n선택 : 마케팅·홍보·조사 > 직무·직업 > 브랜드마케팅\n선택 : 마케팅·홍보·조사 > 직무·직업 > 온라인마케팅\n선택 : 마케팅·홍보·조사 > 직무·직업 > 퍼포먼스마케팅\n선택 : 마케팅·홍보·조사 > 직무·직업 > BM(브랜드매니저)\n선택 : 마케팅·홍보·조사 > 전문분야 > 검색광고\n선택 : 마케팅·홍보·조사 > 전문분야 > 키워드광고\n선택 : 상품기획·MD > 직무·직업 > 기획MD\n선택 : 상품기획·MD > 직무·직업 > 브랜드MD\n선택 : 상품기획·MD > 직무·직업 > 온라인MD\n선택 : 상품기획·MD > 직무·직업 > AMD\n선택 : 상품기획·MD > 담당분야 > 브랜드관리\n선택 : 상품기획·MD > 담당분야 > 브랜드기획\n선택 : 상품기획·MD > 담당분야 > 브랜드런칭\n선택 : 상품기획·MD > 담당분야 > 브랜드확장\n선택 : 상품기획·MD > 담당분야 > 브랜딩\n선택 : 상품기획·MD > 담당분야 > 상품관리\n선택 : 상품기획·MD > 담당분야 > 상품분석\n선택 : 상품기획·MD > 담당분야 > 시장조사\n선택 : 상품기획·MD > 담당분야 > 채널관리\n선택 : 상품기획·MD > 담당분야 > 트렌드분석\n선택 : 상품기획·MD > 담당분야 > 판매전략\n근무지 주소\t(06236) 서울 강남구 테헤란로 142, 3층 100호(역삼동,아크플레이스 위워크) 선택 : 상품기획·MD > 담당분야 > 상품분석\n선택 : 상품기획·MD > 담당분야 > 시장조사\n선택 : 상품기획·MD > 담당분야 > 채널관리\n선택 : 상품기획·MD > 담당분야 > 트렌드분석\n선택 : 상품기획·MD > 담당분야 > 판매전략\n근무지 주소\t(06236) 서울 강남구 테헤란로 142, 3층 100호(역삼동,아크플레이스 위워크)\n노출지역\t 서울 > 강남구, 서울 > 강서구, 서울 > 구로구, 서울 > 금천구, 서울 > 영등포구, 경기 > 경기전체, 경기 > 광명시, 경기 > 김포시, 경기 > 부천시, 경기 > 부천시 원미구'),
#  Document(metadata={'rec_idx': 48780005, 'company_nm': '에이치티씨솔루션(주)', 'recruit_kewdcdnm': "['생산관리', '장비제어', '장비/공구', '조립', '반도체']", 'company_place': '경기 화성시 외', 'career': '경력무관 · 정규직', 'education': '고졸↑'}, page_content='반도체 장비 조립 채용\n\n채용공고 상세\n\xa0\nW E \u3000A R E \u3000H I R I N G\n[에이치티씨솔루션(주)]\n반도체 장비 조립 채용\n에이치티씨솔루션(주)는 2020년 09월에 설립된 반도체 장비 조립 및 조정하는 기업 입니다.\n\xa0\n 모집부문 및 자격요건 \n 모집부문\n 담당업무\n 지원자격\n 모집인원\n반도체 장비 조립\n(신입/경력)\n ㆍ반도체 장비 조립\nㆍ학력 : 고졸 이상\nㆍ경력 : 무관 (경력자 연봉 협의)\n 00명 \n근무조건\nㆍ근무형태\t:\t정규직(수습기간)-3개월\nㆍ근무일시\t:\t주 5일(월~금) 08:30~17:30\nㆍ근무지역\t:\t경기 화성시 양감면 신왕리 1000-28\n 복리후생 \n4대보험\n건강보험, 고용보험,\n국민연금, 산재보험\n\n의료/건강\n임/직원 건강검진\n사무환경\n자유복장,\n자유로운 분위기\n\n복지\n중식제공, 석식제공\n지원금\n주거지원(15만원/月),\n경조사, 차량운행비\n\n조교육/훈련\n신입사원 교육(OTJ),\n직무능력향상교육,\n도서구입비 지급\n기업 인증서\n2021. 04 벤처기업 선정\n2022. 10 ISO22301\n2022. 10 ISO45001\n2022. 10 ISO14001\n2022. 10 ISO9001 \n\xa0\n\xa0\n전형절차\n접수기간 및 방법\nㆍ접수기간 : 채용시 마감\nㆍ접수방법 : 사람인 온라인 입사지원\nㆍ이력서양식 : 사람인 온라인 이력서 \nㆍ이력서양식\t:\t사람인 온라인 이력서\nㆍ제출서류\t:\t합격 시 필요 서류\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0- 졸업/ 성적증명서\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0- 주민등록등본\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0- 건강검진 진단서 / 영수증(비용처리)\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0- 자격증 사본(보유 시)\n기타사항\n ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.'),
#  Document(metadata={'rec_idx': 48859665, 'company_nm': '킨도프(주)', 'recruit_kewdcdnm': "['SNS', '콘텐츠마케팅', '퍼포먼스마케팅', 'CRM마케팅', '그로스해킹']", 'company_place': '서울 중구', 'career': '경력 3년↑ · 정규직', 'education': '대학교(4년)↑'}, page_content='그로스 매니저(Growth Manager) 채용공고 상세 빠르게 성장하는 2000아카이브스,더 빠르게 페달을 밟아주실 Growth Manager를 찾습니다 ?2000아카이브스는 매출 성장을 주도하고, 소셜미디어(특히 인스타그램) 성장을 병행하며, 브랜드의 모든 지표 성과를 실무적으로 관리/개선할 수 있는 Growth Manager를 찾고 있습니다. 패션 시장과 디자이너 브랜드에 대한 이해를 바탕으로, 정량적 분석 능력과 창의적인 감각을 발휘해 전략을 실행할 수 있는 인재를 대상으로 합니다. 다양한 콘텐츠 크리에이터와의 협업을 통해 프리랜서 조직을 관리하고, 고객 경험(CX) 개선 및 CRM 마케팅을 도입하여 브랜드의 성장을 촉진하는 역할을 맡게 됩니다.참고해 주세요• 직책: Growth Manager• CEO에게 직접 보고합니다.• 근무 형태: 정규직어떤 기회가 있나요?• 매출 성장 전략의 주도: 매출 성장 목표를 달성하기 위한 구체적인 실행 계획을 수립하고 추진할 기회가 있습니다.• 소셜미디어 성장을 이끌기: 인스타그램과 같은 소셜미디어 채널의 운영과 성장을 위한 전략을 실행하며, 브랜드 인지도를 확장할 수 있습니다.• CX 개선 프로젝트 주도: 고객 경험 개선 프로젝트를 주도하여 구매율과 고객 만족도를 크게 향상시키는 기회를 가질 수 있습니다.• CRM 마케팅 도입 및 운영: 고객 관계 관리 시스템(CRM)을 도입하고 운영하며, 고객 생애 가치를 극대화하는 마케팅 활동을 진행할 수 있습니다.• 프리랜서 팀 운영: 다양한 콘텐츠 크리에이터와의 협업을 통해 프리랜서 조직을 효과적으로 관리하고 성과를 최적화할 수 있는 기회가 주어집니다.• 추후 2000아카아브스 이외의 멀티 브랜드의 그로스를 관리하는 역할로 성장 가능성이 있습니다.어떤 역량과 경력이 필요한가요?• 패션 시장 및 디자이너 브랜드에 대한 이해: 패션 트렌드와 브랜드 감도에 대한 높은 이해도 필수.• 퍼널 개선 능력: 이커머스 시장에서 고객 여정에서의 각 퍼널 단계를 개선한 경험.• 정량적 분석 능력: 데이터 기반의 의사결정 능력, KPI 분석 및 보고 멀티 브랜드의 그로스를 관리하는 역할로 성장 가능성이 있습니다.어떤 역량과 경력이 필요한가요?• 패션 시장 및 디자이너 브랜드에 대한 이해: 패션 트렌드와 브랜드 감도에 대한 높은 이해도 필수.• 퍼널 개선 능력: 이커머스 시장에서 고객 여정에서의 각 퍼널 단계를 개선한 경험.• 정량적 분석 능력: 데이터 기반의 의사결정 능력, KPI 분석 및 보고 경험.• 소셜미디어 전략 경험: 인스타그램 운영 및 성장을 위한 실무 경험.• CX 및 CRM 경험: 고객 경험 개선 및 CRM 마케팅 활동 경험.이런 점이 있으면 더 좋아요• 패션 브랜드에서의 실무 경험.• 스타트업 또는 중소기업에서의 성장 주도 경험.• 프리랜서 관리 경험: 프리랜서 또는 외부 인력과 협업한 경험, 신속한 구인/유연한 조직 운영 능력.• 성공적인 CRM 프로젝트 경험.• 비즈니스 수준의 영어/중국어 능력이런 혜택 및 복지를 지원해드려요.1. 최고의 업무 효율을 위한 환경· 유연근무제 운영(8-10시 출근)· 집중근무를 위한 리모트 근무 지원· 반반반반차 제도(30분 단위 연차 사용)· 최고급 안마 의자, 커피머신2. 가족과 문화를 위한 지원· 자사 제품 할인· 어버이날 카네이션 배송· 설날/추석 직접 고르는 명절 선물·생일 당일 반차3. 성장을 위한 지원· Anna Wintour, Marc Jacobs 등에게 배울 수 있는 Masterclass 수강 지원· 업무에 필요한 온오프라인 강의 및 도서 지원[전형 절차]서류전형 → 온라인테스트 -> 1차 면접 (실무진) → 2차 면접 → 레퍼런스 체크 -> 처우협의 → 최종합격· 포지션에 따라 추가 면접 또는 커피챗이 진행될 수 있습니다.· 필요 시, 레퍼런스 체크가 진행될 수 있습니다.[제출 서류]· 자유 양식의 이력서 (경력 세부사항 포함)· 포트폴리오'),
#  Document(metadata={'rec_idx': 48859689, 'company_nm': '킨도프(주)', 'recruit_kewdcdnm': "['콘텐츠기획', '콘텐츠마케팅', '콘텐츠에디터']", 'company_place': '서울 중구', 'career': '경력 1년↑ · 프리랜서', 'education': '고졸↑'}, page_content='Visual Contents Creator(비주얼 콘텐츠 크리에이터) 채용공고 상세 높은 감도의 2000아카이브스,더 널리 확산시켜주실 Visual Contents Creator를 찾습니다 ?2000아카이브스는 브랜드의 감성을 시각적으로 표현하며, 고객과의 모든 접점에서 일관된 경험을 제공할 비주얼 콘텐츠 크리에이터를 찾고 있습니다. 이 역할은 단순히 콘텐츠를 제작하는 것에 그치지 않고, 브랜드의 스토리를 시각적으로 풀어내어 고객에게 전달하는 핵심적인 역할을 맡습니다. 패션과 디자인에 대한 이해와 안목을 바탕으로, 독창적인 비주얼 콘텐츠를 통해 브랜드를 성장시키고 팬층을 확장해 나갈 수 있는 분을 모십니다.참고해 주세요• 직책: 비주얼 콘텐츠 크리에이터• Creative Driector/Growth Manager에게 보고합니다.• 근무 형태: 프리랜서 혹은 계약직어떤 기회가 있나요?•\t브랜드 스토리텔링의 주도권: 브랜드의 핵심 가치를 시각적 콘텐츠로 풀어내고, 고객과의 모든 접점에서 일관된 경험을 제공하는 역할을 해나갑니다.•\t소셜미디어 콘텐츠 제작: 인스타그램, 유튜브, 틱톡 등 다양한 소셜미디어 플랫폼에 맞는 독창적이고 감도 높은 콘텐츠를 기획하고 제작할 수 있습니다.•\t크리에이티브 실현:창의적 아이디어를 현실로 만들어내고, 브랜드의 시각적 표현을 주도적으로 이끌어갈 수 있습니다.•\t포트폴리오 빌딩: 다양한 패션 관련 프로젝트를 통해 자신의 포트폴리오를 강화할 수 있는 기회를 제공합니다.어떤 역량과 경력이 필요한가요?•\t패션과 트랜드에 대한 깊은 이해와 감각: 패션 트렌드와 브랜드 감도에 대한 높은 이해도가 필수적입니다.•\t비주얼 콘텐츠 제작 경험: 이미지, 영상, 그래픽 디자인 등 시각 콘텐츠 제작 경험이 필수입니다.•\t소셜미디어에 대한 이해: 인스타그램을 비롯한 소셜미디어 플랫폼에 적합한 콘텐츠 제작 경험이 필요합니다.•\t창의적 사고 및 독창성: 새로운 아이디어를 도출하고 이를 시각적으로 구현할 수 있는 능력이 요구됩니다.•\t협업 능력: 팀과의 원활한 커뮤니케이션과 협업을 통해 목표를 달성할 수 있는 능력이 중요합니다.이런 점이 시각 콘텐츠 제작 경험이 필수입니다.•\t소셜미디어에 대한 이해: 인스타그램을 비롯한 소셜미디어 플랫폼에 적합한 콘텐츠 제작 경험이 필요합니다.•\t창의적 사고 및 독창성: 새로운 아이디어를 도출하고 이를 시각적으로 구현할 수 있는 능력이 요구됩니다.•\t협업 능력: 팀과의 원활한 커뮤니케이션과 협업을 통해 목표를 달성할 수 있는 능력이 중요합니다.이런 점이 있으면 더 좋아요•\t사진 또는 영상 제작 기술: 사진 촬영이나 영상 제작 기술이 뛰어난 분을 우대합니다.•\t그래픽 디자인 소프트웨어 숙련도: Adobe Creative Suite(포토샵, 일러스트레이터 등)에 대한 높은 숙련도를 가진 분을 우대합니다.•\t패션 브랜드 경험: 패션 또는 뷰티 브랜드에서 비주얼 콘텐츠를 제작한 경험이 있다면 큰 장점이 됩니다.•\t트렌드 예측 능력: 최신 패션 및 소셜미디어 트렌드를 이해하고, 이를 콘텐츠에 반영할 수 있는 능력이 있으면 더욱 좋습니다.이런 혜택 및 복지를 지원해드려요.1. 최고의 업무 효율을 위한 환경· 유연근무제 운영(8-10시 출근)· 집중근무를 위한 리모트 근무 지원· 반반반반차 제도(30분 단위 연차 사용)· 최고급 안마 의자, 커피머신2. 가족과 문화를 위한 지원· 자사 제품 할인· 어버이날 카네이션 배송· 설날/추석 직접 고르는 명절 선물·생일 당일 반차3. 성장을 위한 지원· Anna Wintour, Marc Jacobs 등에게 배울 수 있는 Masterclass 수강 지원· 업무에 필요한 온오프라인 강의 및 도서 지원[전형 절차]서류전형 → 온라인테스트 -> 1차 면접 (실무진) → 2차 면접 → 레퍼런스 체크 -> 처우협의 → 최종합격· 포지션에 따라 추가 면접 또는 커피챗이 진행될 수 있습니다.· 필요 시, 레퍼런스 체크가 진행될 수 있습니다.[제출 서류]· 자유 양식의 이력서 (경력 세부사항 포함)· 포트폴리오'),
#  Document(metadata={'rec_idx': 48867116, 'company_nm': '킨도프(주)', 'recruit_kewdcdnm': "['고객관리', '고객안내', '고객응대', 'CS관리', 'AM(어카운트매니저)']", 'company_place': '서울 중구', 'career': '경력 5년↑ · 정규직', 'education': '대학교(4년)↑'}, page_content='CX Lead(CX 총괄 매니저) 채용공고 상세 2000아카이브스의 고객 경험을 혁신할,CX 총괄 매니저를 찾습니다 ?2000아카이브스는 고객 경험(CX)을 통해 브랜드의 가치를 한층 더 높일 수 있는 CX 총괄 매니저를 찾고 있습니다. 이 역할은 고객과의 모든 접점에서 일관된 경험을 설계하고, CRM 및 자동화 시스템을 도입하여 고객 만족도를 극대화하는 핵심적인 역할을 맡습니다. 데이터 분석 능력과 마케팅에 대한 이해를 바탕으로, 고객 경험의 전 lifecycle을 총괄하며, VIP 고객 관리와 브랜드 성과 향상에 기여할 수 있는 분을 모십니다.2000아카이브스 CX 총괄 매니저는?\t•\t2000아카이브스는 고객 경험(CX)에 진심입니다. 우리는 고객이 브랜드와 상호작용하는 모든 순간에 일관되고 매력적인 경험을 제공하는 것을 목표로 합니다.\t•\tCX 총괄 매니저는 단순한 팀원이 아닙니다. 이 역할은 2000아카이브스의 전체 고객 경험을 책임지는 핵심적인 역할로, 고객 경험의 전 lifecycle을 설계하고 개선하는 것을 총괄하게 됩니다.\t•\t목표는 명확합니다: CRM 자동화, CX 문의 응대 자동화, VIP 고객 경험 관리, 패키지 경험 등 다양한 고객 접점에서 자동화 툴을 활용해 고객 만족도를 극대화하는 것입니다.\t•\tCX 총괄 매니저는 브랜드의 성과에 직접적인 영향을 미칩니다. 이 역할은 CRM 시스템 도입 및 운영, AI를 활용한 CX 자동화, 고객 데이터를 분석해 전략적인 마케팅 인사이트를 도출하는 데 중점을 둡니다.어떤 일을 담당하나요?고객 경험을 총괄하고 개선합니다.\t•\tCX 자동화 설계 및 운영: CRM 자동화 설정, 채널톡 AI를 활용한 CX 문의 자동화, VIP 고객 경험 관리 등을 통해 고객과의 상호작용을 최적화합니다.\t•\t고객의 전체 경험 관리: 고객이 브랜드를 알게 되고 제품을 받는 순간까지의 모든 경험을 설계하고, 이를 개선하고 자동화 시스템으로 운영하여 고객 만족도를 높입니다.\t•\tCRM 시스템 도입 및 운영: 고객 데이터를 활용해 개인화된 경험을 제공하고, 고객 생애 가치를 CX 문의 자동화, VIP 고객 경험 관리 등을 통해 고객과의 상호작용을 최적화합니다.\t•\t고객의 전체 경험 관리: 고객이 브랜드를 알게 되고 제품을 받는 순간까지의 모든 경험을 설계하고, 이를 개선하고 자동화 시스템으로 운영하여 고객 만족도를 높입니다.\t•\tCRM 시스템 도입 및 운영: 고객 데이터를 활용해 개인화된 경험을 제공하고, 고객 생애 가치를 극대화하는 CRM 전략을 수립하고 실행합니다.정량적 분석을 통해 인사이트를 도출합니다.\t•\t고객 데이터 분석: 정량적 분석 능력을 활용해 고객 행동과 피드백을 분석하고, 이를 바탕으로 CX 개선 전략을 수립합니다.\t•\t마케팅 인사이트 도출: 고객 데이터를 통해 마케팅에 필요한 인사이트를 도출하고, 이를 바탕으로 캠페인과 전략을 최적화합니다.VIP 고객 경험을 관리합니다.\t•\tVIP 프로그램 운영: VIP 고객을 위한 맞춤형 경험을 설계하고 운영하여, 고객 충성도를 강화합니다.\t•\t개인화된 서비스 제공: VIP 고객을 대상으로 한 개인화된 서비스와 특화된 경험을 제공하여 브랜드의 가치를 극대화합니다.이런 역량을 갖춘 분과 함께 하고 싶어요.\t•\tCS/CX 관련 운영/리드 경력 혹은 그로스/CRM 마케팅 3년 이상의 경력을 보유한 분\t•\t정량적 분석과 전략적 사고를 갖추신 분(필수)\t•\t자동화 및 시스템 구축에 열정이 있는 분: CRM, AI 기반의 CX 자동화 등\t•\t글을 잘 쓰고, 논리적으로 말할 수 있는 분\t•\t급작스런 이슈에도 빠르게 판단하고 유연한 사고로 대처할 수 있는 분\t•\t논리적인 사고와 원활한 커뮤니케이션 소통 능력을 갖추신 분\t•\t더 효율적인 방법과 문제 개선을 위해 고민하고 과감히 시도할 수 있는 분\t•\t고객 경험 개선을 위해 사무실 바깥에서도 적극적인 네트워킹과 학습을 꾸준히 하실 수 있는 분\t•\t새로운 것을 학습하는 데 두려움이 없고, 개인의 성장을 즐기는 분이런 분이시라면 더욱 좋아요!\t•\t반복되는 일을 참지 않고 무언가를 개선하는 분\t•\t변화에 유연하게 대처할 수 있는 분\t•\t실패에 방법과 문제 개선을 위해 고민하고 과감히 시도할 수 있는 분\t•\t고객 경험 개선을 위해 사무실 바깥에서도 적극적인 네트워킹과 학습을 꾸준히 하실 수 있는 분\t•\t새로운 것을 학습하는 데 두려움이 없고, 개인의 성장을 즐기는 분이런 분이시라면 더욱 좋아요!\t•\t반복되는 일을 참지 않고 무언가를 개선하는 분\t•\t변화에 유연하게 대처할 수 있는 분\t•\t실패에 집중하지 않는 회복 탄력성이 높은 분\t•\tCX라는 업을 함께 정의하고 개선하고 싶으신 분\t•\t정성/정량적인 고객 분석을 통한 제품/서비스 개선 등에 참여해본 경험이 있는 분\t•\t주도적으로 목표를 세워 달성해 본 경험이 있는 분\t•\t비즈니스 레벨 이상의 영어를 구사하시는 분이런 혜택 및 복지를 지원해드려요.1. 최고의 업무 효율을 위한 환경· 유연근무제 운영(8-10시 출근)· 집중근무를 위한 리모트 근무 지원· 반반반반차 제도(30분 단위 연차 사용)· 최고급 안마 의자, 커피머신2. 가족과 문화를 위한 지원· 자사 제품 할인· 어버이날 카네이션 배송· 설날/추석 직접 고르는 명절 선물·생일 당일 반차3. 성장을 위한 지원· Anna Wintour, Marc Jacobs 등에게 배울 수 있는 Masterclass 수강 지원· 업무에 필요한 온오프라인 강의 및 도서 지원[전형 절차]서류전형 → 온라인테스트 -> 1차 면접 (실무진) → 2차 면접 → 레퍼런스 체크 -> 처우협의 → 최종합격· 포지션에 따라 추가 면접 또는 커피챗이 진행될 수 있습니다.· 필요 시, 레퍼런스 체크가 진행될 수 있습니다.[제출 서류]· 자유 양식의 이력서 (경력 세부사항 포함)· 포트폴리오'),
# ...
#  Document(metadata={'rec_idx': 50029082, 'company_nm': '픽스피드 주식회사', 'recruit_kewdcdnm': "['디지털마케팅', '미디어플래너', '브랜드마케팅', '온라인마케팅', '콘텐츠마케팅']", 'company_place': '서울 성동구', 'career': '경력무관 · 정규직', 'education': '학력무관'}, page_content="[마케팅] 픽스피드 주식회사 인하우스 퍼포먼스 마케터채용\n\n채용공고 상세\n[마케팅] 픽스피드 주식회사 인하우스 퍼포먼스 마케터채용기업 소개 또는 채용 안내를 작성해보세요. 불필요시 '기업 소개'를 한번더 클릭하면 소개 영역이 숨겨집니다.모집부문 및 상세내용모집부문상세내용공통 자격요건ㆍ학력 : 무관마케팅 0명주요업무ㆍ 반려동물 영양식품 브랜드 마케터ㆍ 온라인 콘텐츠 관리ㆍ 소셜 미디어 운영ㆍ 시장 분석 및 조사ㆍ 고객 데이터 분석ㆍ 프로모션 전략 수립담당업무ㆍ지원자격ㆍ경력 : 무관 (신입도 지원 가능)\nㆍ기타 필수 사항\n우대사항ㆍ광고홍보학ㆍ검색광고마케터 1급ㆍ2년 이상 관련 분야 경력자, 해당직무 근무경험근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:ㆍ근무지역:(04781) 서울 성동구 성수이로 65 협성빌딩 - 서울 2호선 성수 에서 500m 이내전형절차 서류전형 1차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 2월 18일 (화) 10시~ 2025년 3월 20일 (목) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:포토폴리오유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."),
#  Document(metadata={'rec_idx': 50029112, 'company_nm': '봄언어심리발달센터', 'recruit_kewdcdnm': "['작업치료사', '감각통합치료사', '작업치료']", 'company_place': '서울 성북구', 'career': '경력 1년↑ · 계약직 외', 'education': '대학교(4년)↑'}, page_content='(서울 성북구) 감각통합치료사(목-금)모십니다\n\n채용공고 상세\n(서울 성북구) 감각통합치료사(목-금)모십니다유사 의료업업종의 언어치료,놀이치료,인지치료,감각통합치료사업을 하는 중소기업 입니다.모집부문 및 상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년)감각통합치료사 2명주요업무담당업무ㆍ지원자격ㆍ경력 : 경력 1년 이상\nㆍ기타 필수 사항\n우대사항근무조건ㆍ근무형태:계약직-1년3개월, 프리랜서ㆍ근무일시: 10:00~19:00ㆍ근무지역:(136-110) 서울 성북구 길음동 1140 1층 - 서울 4호선 길음 에서 800m 이내전형절차 서류전형 1차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 2월 18일 (화) 10시~ 채용시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:이력서, 자격증 사본유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.'),
#  Document(metadata={'rec_idx': 50029254, 'company_nm': '성보섬유상사(유)대구공장', 'recruit_kewdcdnm': "['구매관리', '물류관리', '자재관리', '재고관리', '창고관리']", 'company_place': '대구 달성군', 'career': '경력무관 · 정규직', 'education': '학력무관'}, page_content="물류 창고 입, 출고 및  자재 관리 정규직 모집\n\n채용공고 상세\n물류 창고 입, 출고 및자재 관리 정규직 모집기업 소개 또는 채용 안내를 작성해보세요. 불필요시 '기업 소개'를 한번더 클릭하면 소개 영역이 숨겨집니다.모집부문 및 상세내용공통 자격요건ㆍ학력 : 무관자재관리자재관리 1명주요업무ㆍ 입출고 관리ㆍ 마대패킹ㆍ 창고 안전 점검 및 정리정돈담당업무ㆍ지원자격ㆍ경력 : 무관 (신입도 지원 가능)(사원급)\nㆍ기타 필수 사항\n우대사항ㆍ인근거주자, 운전가능자, 해당직무 근무경험, 문서작성 우수자근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:주 5일(월~금), 토요일\xa0 3주에 한 번 당직 (10:00-14:00)ㆍ근무지역:(711-857) 대구 달성군 논공읍 논공중앙로54길28전형절차 서류전형 1차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 2월 18일 (화) 11시~ 2025년 4월 19일 (토) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:자유양식ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."),
#  Document(metadata={'rec_idx': 50029444, 'company_nm': '(주)쿠우쿠우', 'recruit_kewdcdnm': "['버스기사', '수행기사', '사옥관리', '승강기안전관리', '전기소방관리']", 'company_place': '경기 성남시 수정구', 'career': '경력 2년↑ · 정규직', 'education': '고졸↑'}, page_content='(주)쿠우쿠우 프랜차이즈 대형버스운행,건물관리,회장님수행기사\n\n채용공고 상세\n(주)쿠우쿠우 프랜차이즈 대형버스운행,건물관리,회장님수행기사2012년 02월 20일에 설립된 경영 컨설팅업업종의 경영컨설팅사업을 하는 중소기업,주식회사기업 입니다.모집부문 및 상세내용모집부문상세내용공통 자격요건ㆍ학력 : 고등학교졸업 이상대형버스운행기사, 사옥관리,\xa0수행기사 1명담당업무ㆍ주요업무담당업무ㆍ쿠우쿠우 대형버스 운행(30인이상 버스)ㆍ사옥관리(안전관리자)ㆍ회장님 수행기사 (벤츠S 마이바흐 운행)(주 업무 : 매장오픈시 대형버스 순회\xa0그외 업무 : 대형버스 미순회시 사옥관리 / 회장님 외부 일정 있을시 수행기사)ㆍ업무 어렵지 않습니다 / 매장순회 없을시 본사 건물에서 대기하시다 퇴근필수사항ㆍ 1종대형운전면허 소지자ㆍ 벤츠s 마이바흐 운행가능자ㆍ 주5일 근무(주말근무 있음)자격요건ㆍ학력 : 학력무관ㆍ경력 : 경력2년↑우대사항ㆍ소방, 전기, 승강기 안전 관리자 업무 수행 가능자\xa0\xa0\xa0\xa0(관련 업체와 소통하고 업무처리 가능한 분)ㆍ성실하신분\nㆍ기타 필수 사항\n우대사항근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:주 5일(월~금) 오전 9시~오후 6시ㆍ근무지역:(13327) 경기 성남시 수정구 수정로 138 쿠우쿠우빌딩(수진동) - 서울 8호선 수진 에서 800m 이내전형절차 서류전형 (2021.06.11 ~ 2021.07.30)1차면접 2차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 3월 19일 (수) 10시~ 2025년 4월 19일 (토) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.'),
#  Document(metadata={'rec_idx': 50029445, 'company_nm': '(주)코리아이앤피', 'recruit_kewdcdnm': "['영업관리', '영업지원', '영업전략', '가맹점관리', '가맹점영업']", 'company_place': '서울 성북구 외', 'career': '경력 1년↑ · 정규직', 'education': '대학(2,3년)↑'}, page_content='[고려대학교영어교육프로그램EiE] FC사업본부 채용 채용공고 상세 코리아이앤피 \xa0FC 사업본부 채용\xa0\' 코리아 E&P\xa0\'는 고려대학교 학교법인 고려중앙학원과 산학협력을 체결한 1호 기업으로서본사는 고려대학교 안암캠퍼스 내에 위치하고 있습니다.\'\xa0코리아 E&P\xa0\'의 프랜차이즈 어학원 브랜드인 \'고려대학교 영어교육 프로그램 EiE\xa0\'는고려대학교 교수진들의 풍부한 교육 경험과 노하우를 바탕으로 기획, 개발 및 검수한프로그램과 콘텐츠를 기반으로 하여 "표현 영어 완성"이라는\xa0교육목표로최상의 영어학습을 제공합니다.고려대학교에서\xa0검수 받은\xa0자체 개발 교재와 온라인 학습\xa0프로그램과특허 받은 교육 스케줄링 시스템, 차별화된 성공 가이드 제공 등을 통하여현재 전국 약\xa0300여 개의\xa0가맹점을 보유하고 있습니다.2013년 06월 12일에 설립된 응용 소프트웨어 개발 및 공급업업종의 온오프라인컨텐츠,소프트웨어 개발,공급,교육지원/전자상거래/영어프랜차이즈 가맹,출판,전자출판사업을 하는 중소기업,주식회사기업 입니다.모집부문 및 상세내용FC사업본부FC사업본부 00명담당업무ㆍ담당업무\xa0 ㆍ 직영 · 가맹점 브랜드 영업기획\xa0 ㆍ 직영 · 가맹점 브랜드 운영관리\xa0 ㆍ 본사 운영지원 및 관리우대사항\xa0 ㆍ 컴퓨터 활용 능력 우수자\xa0 ㆍ 관련 근무 경력 보유자복지 및 처우ㆍ 쾌적한 근무환경 (고려대학교 캠퍼스 내 위치)\xa0ㆍ 지하철역 인접ㆍ 체력단련비 , 카페테리아 , 통신비 , 자기계발비 , 교육과정 대상자 선발 시 교육대학원 진학 지원 등우대사항근무조건\xa0ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:주 5일(월~금) 09:30~18:30ㆍ근무지역:\xa0서울 성북구 안암로 145 고려대학교 이공계캠퍼스 산학관 6층 606-1,2호전형절차 서류전형 1차면접 2차면접 최종합격접수기간 및 방법ㆍ접수기간:상시채용ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 산학관 6층 606-1,2호전형절차 서류전형 1차면접 2차면접 최종합격접수기간 및 방법ㆍ접수기간:상시채용ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.'),
#  Document(metadata={'rec_idx': 50029494, 'company_nm': '(주)보람푸드', 'recruit_kewdcdnm': "['배송기사', '출고/출하']", 'company_place': '부산 사상구', 'career': '신입 · 경력 · 정규직', 'education': '고졸↑'}, page_content='[부산 사상] 배송 영업 및 창고내근직 (격주 토 근무)\n\n채용공고 상세\n[부산 사상] 배송 영업 및 창고내근직 (격주 토 근무)모집부문 및 상세내용공통 자격요건ㆍ학력 : 고졸 이상배송영업기사(창고 내근 겸직)배송영업팀 0명담당업무ㆍ주요업무ㆍ 상품 출고 및 배송 / 거래처 관리지원자격ㆍ경력 : 신입/경력 (년수무관)\nㆍ기타 필수 사항\n- 1종보통운전면허우대사항ㆍ해당직무 근무경험, 인근거주자근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:평일 08:30~18:00 / 격주 토요일 08:30~17:00ㆍ근무지역:(47020) 부산 사상구 학감대로191번길 16(학장동) - 부산 2호선 감전 에서 800m 이내전형절차 서류전형 1차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 2월 18일 (화) 10시~ 2025년 3월 20일 (목) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.'),
#  Document(metadata={'rec_idx': 50029580, 'company_nm': '(주)동양저축은행', 'recruit_kewdcdnm': "['총무', '경영지원', '급여(Payroll)', '예산관리', '금융사무']", 'company_place': '광주 동구', 'career': '신입 · 정규직', 'education': '대학교(4년)↑'}, page_content='[광주광역시 동양저축은행] 경영지원팀 신입행원 수시 채용공고\n\n채용공고 상세\n1983년 03월 29일에 설립된 상호저축은행 및 기타 저축기관업종의 상호저축은행사업을 하는 기업 입니다.모집부문 및 상세내용모집부문상세내용공통 자격요건ㆍ학력 : 대졸 이상 (4년)ㆍ전공 : 무관ㆍ신입 : 지원가능ㆍ경력 : 경력 년수 무관경영지원팀경영전략부문 경영지원팀 1명주요업무ㆍ 경영지원업무 전반담당업무ㆍ담당업무\xa0ㆍ 총무 업무\xa0ㆍ 인사 업무\xa0ㆍ 금융 회계우대사항ㆍ국가유공자ㆍ컴퓨터활용능력 우수자ㆍ금융권 유관업무 경험자 (인턴ㆍ알바)ㆍ보훈대상자ㆍ엑셀 고급능력 보유자ㆍ문서작성 우수자ㆍ관련 자격증 보유자\nㆍ기타 필수 사항\n우대사항근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:주 5일(월~금)ㆍ근무지역:(61475) 광주 동구 중앙로 198 신동해빌딩(금남로3가) - 광주 1호선 금남로4가 에서 200m 이내전형절차 서류전형 1차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 2월 19일 (수) 10시~ 2025년 3월 26일 (수) 18시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.복리후생ㆍ4대보험 / 퇴직금(1년 이상 근무시)ㆍ경조휴가, 경조비 지원ㆍ체력단련비 지원ㆍ상여금 별도ㆍ건강검진 지원ㆍ학자금 지원'),
#  Document(metadata={'rec_idx': 50029627, 'company_nm': '성모김안과의원', 'recruit_kewdcdnm': "['간호조무사', '외래']", 'company_place': '서울 강동구', 'career': '경력무관 · 정규직', 'education': '학력무관'}, page_content="[강동구 길동] 성모김안과 간호조무사 정규직 모집 공고\n\n채용공고 상세\n[강동구 길동] 성모김안과 간호조무사 정규직 모집 공고기업 소개 또는 채용 안내를 작성해보세요. 불필요시 '기업 소개'를 한번더 클릭하면 소개 영역이 숨겨집니다.모집부문 및 상세내용공통 자격요건ㆍ학력 : 무관접수 및 수술 보조 1명주요업무ㆍ 환자 관리 및 지원ㆍ 의료진과의 협력ㆍ 진료 보조 업무 수행ㆍ 환자 기록 관리ㆍ 상담 및 안내 서비스담당업무ㆍ지원자격ㆍ경력 : 무관 (신입도 지원 가능)\nㆍ기타 필수 사항\n- 간호조무사우대사항ㆍ간호코디네이터ㆍ커뮤니케이션 우수자, 해당직무 근무경험근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시:월-금 09:00~18:30 토 09:00~13:00 중 5일 출근ㆍ근무지역:(134-010) 서울 강동구 길동 389-5 삼환빌딩 2층 성모김안과의원 - 서울 5호선 길동 에서 100m 이내전형절차 서류전형 1차면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 2월 18일 (화) 10시~ 2025년 3월 20일 (목) 24시ㆍ접수방법:사람인 입사지원ㆍ이력서양식:사람인 온라인 이력서ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다."),
#  Document(metadata={'rec_idx': 50029701, 'company_nm': '스튜디오 리코(주)', 'recruit_kewdcdnm': "['작가', '스토리텔링', '드라마', '만화/웹툰']", 'company_place': '경기 성남시 분당구', 'career': '3 ~ 13년 · 정규직', 'education': '학력무관'}, page_content='[STUDIO LICO] 웹툰 남성향 - 스토리기획 팀장 (정규직/재택) 채용공고 상세\nSTUDIO LICO 웹툰 남성향 - 스토리기획 팀장 (정규직)STUDIO LICO는 `LIFE WITH CONTENT`를 모토로,전문적인 디지털 콘텐츠 제작을 위해 2017년에 설립된 네이버웹툰의 자회사입니다.웹툰과 애니메이션을 필두로 다양한 디지털 콘텐츠를 제작하며,빠르게 변화하는 트렌드에 발맞춰 새로운 콘텐츠의 발굴과 활용을 통해글로벌 시장을 선도하는 콘텐츠 제작을 목표로 하고 있습니다.현재 웹툰 <화산귀환><내 남편과 결혼해줘><사랑하는 나의 억압자><막장 악녀><후회조차 사치인 당신들에게><황후의 짐승간택> 뿐 아니라<폭력의 왕><피부과 만렙남><천재의 신들린 게임방송> 등 다양한 장르의 웹툰 작품을 제작하며네이버웹툰 <연의 편지> 극장용 애니메이션을 프로듀싱하고 있습니다.모집부문 및 상세내용웹툰스토리기획담당업무: 스토리기획 (남성향)- 웹툰 오리지널 스토리 기획 및 제작, 관리- 노블코믹스 신작 IP 제안 및 각색, 각색작 관리-\xa0남성향 웹툰 연재작 시나리오 퀄리티 관리 및 콘티, 원고 피드백- 각 IP의 시장성 파악 및 운영 전략 설계\xa0- 남성향 기획팀 리딩 및 프로젝트 전반 관리지원자격- 관련 실무 경력(글/콘티) 및 동종 웹툰업계 종사 경력이 5년 이상 있는 분- 웹툰, 웹소설 등 최소 2개 이상의 작품을 완결한 경험이 있는 분\xa0- 조직관리 및 프로젝트 운영의 경험이 있는 분- 원활한 커뮤니케이션과 합리적인 의사결정 및 문제해결 능력을 갖추신 분\xa0- 웹툰 콘텐츠의 재미 요소를 파악하여 트렌디한 결과물로 표현 가능하신 분\xa0\nㆍ기타 필수 사항 ㆍ기타 필수 사항\n우대사항- 관련 전공학과 우대 (웹툰, 만화, 애니메이션학과 등)\xa0- 클립스튜디오, 포토샵 등을 이용한 디지털 기반의 작업이 가능한 분- 웹툰 및 만화콘텐츠에 대한 이해 및 제작 공정별 이해도가 높은 분- 외국어 능통자 우대 (일본어, 영어 등)근무조건ㆍ근무형태:정규직 (수습\xa03개월)ㆍ근무장소:경기도 성남시 분당구 분당내곡로 131 판교테크원 타워1, 7층 (우)13529ㆍ근무형태:재택/오피스 (하이브리드)전형절차 서류전형 사전과제전형 1차(실무)면접 2차(임원)면접 최종합격접수기간 및 방법ㆍ접수기간:~ 채용 시 마감ㆍ접수방법:자사 홈페이지 지원 (recruit.studiolico.com/lico/recruitMain) > 지원 부문 공고문 클릭 > 지원서 접수 (접수 시 포트폴리오 첨부 필수)유의사항ㆍ 외국인의 경우 일부 비자 종류에 한하여\xa0 취업비자 지원 가능합니다.\xa0ㆍ 외국인의 경우 비자 종류에 따라서 채용이 취소될 수 있습니다.ㆍ 본 공고는 모집 완료 시 조기 마감될 수 있습니다.ㆍ 지원서 내용 중 허위사실이 있는 경우에는 합격이 취소될 수 있습니다.ㆍ 전형일정 및 결과는 지원서에 등록하신 이메일로 개별 안내드립니다.ㆍ 문의사항은\xa0STUDIO LICO 채용 홈페이지 > 지원문의로 접수 바랍니다.복리후생BETTER WORKㆍ직군별 업무에 최적화된 업무기기 제공ㆍ도서/컨텐츠/통신비 등 개인업무비용 지원ㆍ개인 역량 향상을 위한 직무/어학 교육비 지원BETTER HEALTHㆍ매년 본인 건강검진 및 2년마다 추가 1인 건강검진 지원ㆍ임직원과 가족의 의료(상해)보험 가입 및 보험료 지원ㆍ피로회복을 위한 안마의자와 손목 건강을 위한 치료기 마련BETTER HOLIDAYㆍ회사와 제휴된 전국 휴양시설 이용ㆍ2년 근속 후 재충전을 위한 리프레시 플러스 휴가ㆍ매년 설/추석 명절선물과 경조사(비) 지원BETTER LIFEㆍ조식 제공 및 카페테리아, 음료/간식 자판기 마련ㆍ안정된 생활을 위한 대출이자 지원ㆍ서울/경기 지역에 직장 어린이집 총 6곳 운영'),
#  Document(metadata={'rec_idx': 50029781, 'company_nm': '(주)위너스해성', 'recruit_kewdcdnm': "['공정엔지니어', '공정설계', '기계설계', '기구설계', '기술설계']", 'company_place': '경기 수원시 권선구', 'career': '신입 · 경력 · 정규직', 'education': '대학(2,3년)↑'}, page_content='[시스템사업] 수/폐수처리 전계장/전장 설계 엔지니어 모집 채용공고 상세 [시스템사업]수/폐수처리 전계장/전장설계\xa0엔지니어 모집1991년 09월 09일에 설립된 배전반 및 전기 자동제어반 제조업업종의 자동제어시스템사업을 하는 중소기업,주식회사기업 입니다.모집부문 및 상세내용모집부문상세내용공통 자격요건자격요건ㆍ학력 : 대졸 이상 (2,3년)ㆍ경력 : 신입/경력 5년 이상ㆍPLC 사용 경력전계장 설계/프로젝트 관리(0명)담당업무ㆍ주요업무1. 진행할 업무와 부서에 대해 알려드려요!\xa0ㆍ업무 :\xa0전장설계, 전계장 설계, 프로젝트 관리\xa0 \xa0 \xa0-\xa0전장 설계\xa0: 판넬 설계, 제작 및 납품 관리\xa0\xa0 \xa0 \xa0-\xa0전계장 설계 및 프로젝트 총괄\xa0: 전계장 설비에 대한 설계 및 시공 감독, \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 시운전 관리 등의 업무\xa0ㆍ\xa0시스템사업팀은 자동화 솔루션 제품을 기반으로 전장 및 전계장 설계부터 시공, 시운전까지\xa0 \xa0 \xa0 총괄하는 조직입니다. 2. 이런 분과 함께하고 싶어요!ㆍ\xa0CAD 도면 및 전계장 도면에 대해 이해할 수 있는 분이 필요해요.ㆍ\xa0전장 설계\xa0: 판넬 도면 작성 및 제작 관리를 할 수 있는 분이 필요해요ㆍ\xa0전계장 설계 및 프로젝트 총괄\xa0:\xa0\xa0\xa01) PLC, Instrument, Motor 등 전계장 설비에 대해 설계 및 관리가 가능하신 분이 필요해요.\xa0 \xa02) 수처리, 폐수처리 및 일반 플랜트 전계장 분야 경력자가 필요해요.3. 입사를 희망하신다면 이력서와 자기소개서를 보내주세요!ㆍ모든 지원자들의 자료를 검토 후 면접을 진행해요.\xa0\xa0\xa0ㆍ학력보다 자신감! 나이보다 열정을 중시하며, 그 어떤 것보다 능력 중심으로 평가해요.4.\xa0 우대사항 (필수아님)ㆍPLC 프로그램 가능자\xa0\xa0\xa0ㆍ현장 PM 경력자\xa0 \xa0ㆍ전기시공 또는 전기기사 자격증 소지자근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시: 09:00~18:00ㆍ근무지역:(16642) 경기 수원시 권선구 오목천로152번길 24 - 수인분당선 고색 에서 800m 이내전형절차 서류전형면접 최종합격접수기간 및 중심으로 평가해요.4.\xa0 우대사항 (필수아님)ㆍPLC 프로그램 가능자\xa0\xa0\xa0ㆍ현장 PM 경력자\xa0 \xa0ㆍ전기시공 또는 전기기사 자격증 소지자근무조건ㆍ근무형태:정규직(수습기간)-3개월ㆍ근무일시: 09:00~18:00ㆍ근무지역:(16642) 경기 수원시 권선구 오목천로152번길 24 - 수인분당선 고색 에서 800m 이내전형절차 서류전형면접 최종합격접수기간 및 방법ㆍ접수기간:2025년 02월 18일 (화) 11시~ 2025년 03월 20일 (목) 24시ㆍ접수방법:사람인 접수ㆍ이력서양식:자사양식 (첨부파일)ㆍ제출서류:유의사항ㆍ학력, 성별, 연령을 보지않는 블라인드 채용입니다. ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.ㆍ 최종합격자는 직무에 따라 소속회사(위너스오토메이션, 위너스해성)가 결정되어 입사됩니다.ㆍ모집분야별로 마감일이 상이할 수 있으니 유의하시길 바랍니다.'),
#  Document(metadata={'rec_idx': 50029843, 'company_nm': '(주)위펀', 'recruit_kewdcdnm': "['영업관리', '영업지원', '영업직', '영업MD', '네트워크영업']", 'company_place': '서울 강남구 외', 'career': '경력무관 · 계약직 외', 'education': '학력무관'}, page_content='(주)위펀 - B2B영업 인턴쉽 (채용연계형)\n\n채용공고 상세'),
#  Document(metadata={'rec_idx': 50029997, 'company_nm': '좋은일자리센터', 'recruit_kewdcdnm': "['안내데스크', '사무보조', '전화응대', '영업관리', '영업지원']", 'company_place': '광주 서구 외', 'career': '신입 · 경력 · 정규직 외', 'education': '학력무관'}, page_content='[영업-절대-아님] 신용카드-콜센터 순수-인바운드(받는전화)상담 채용공고 상세 [모집공고]\xa0▶하나카드[광주고객센터] 순수-인바운드 상담원\xa0[초보가능/ 남녀무관]\xa0 \xa0\xa0[순수-인바운드상담(영업-절대-XX)][정착금+격려금=총130만지급]\xa0\xa0[담당업무]▶하나카드 (대표번호로 걸려오는 전화) 문의응대 전화상담\xa0[영업 전혀 없음]▶결제금액확인/주소변경 등의 단순상담\xa0[초보자도 빠른 적응가능]\xa0 \xa0 \xa0ex)카드를 분실했어요! 재발급은 어떻게 하나요?\xa0 \xa0 \xa0 \xa0 \xa0 \xa0카드고지서를 집주소에서 회사주소로 변경해주세요~\xa0 \xa0 \xa0 \xa0 \xa0 \xa0결제금액이 잘못된것 같아요, 확인을 해주세요~\xa0[근무요일]▶평일-주 5일근무\xa0(주말 및 공휴일은 휴무)[근무시간] ▶ \xa009:00~18:00\xa0[급여조건]▶[고정급 2,097,000원]+[정착지원금 & 격려금] + [평균성과급] = 월 평균 250만원\xa0↑\xa0ⓐ정착지원금 & 격려금은\xa0총 130만원\xa0지급됩니다. (만근기준)\xa0 \xa0 :\xa0정착지원금▶\xa0총-70만원\xa0(1개월차 30만원 + 2개월차 20만원 + 3개월차 20만원)\xa0 \xa0 :\xa0격려금▶\xa0총-60만원\xa0(7개월차 30만원 + 13개월차 30만원)\xa0\xa0ⓑ성과급은 상담품질, 근태관리 등으로 책정하여 지급됩니다. (영업-평가-XX)\xa0ⓒ교육비는\xa0日 6만원(=총 90만원)\xa0지급됩니다.\xa0(첫달, 교육비 포함지급)\xa0 \xa0※상기급여는 만근시 지급기준입니다.\xa0[근무장소]\xa0\xa0▶하나카드/광주고객센터 :\xa0광주 서구 천변좌로 268 (KDB생명빌딩)\xa0\xa0 [①호선 양동시장역 1번출구, 도보 5분거리]\xa0[근무형태]▶㈜KS한국고용정보 소속 정규직 (파견, 계약직아님)[면접일정]\xa0▶서류전형합격자 개별문자통보\xa0[면접일자/선택가능]\xa0[교육일정]▶3/24(월)\xa0~평일 15일간 진행 (교육시간 09시~18시)\xa0\xa0 \xa0[교육비▶하루 6만원 X 교육일수=총 90만원 지급]\xa0 \xa0*최종 교육수료자에 한해 정규직 입사[지원방법(택1)]▶취업포털사이트 온라인입사지원▶[구글폼_입사지원]☞https://forms.gle/kQQDUVYvRaqUkJ4d9\xa0★빠른 서류검토 및 면접안내를 위해[구글폼_간편입사지원]적극 권장!!★'),
#  Document(metadata={'rec_idx': 50030056, 'company_nm': '메이린의원잠실롯데호텔점', 'recruit_kewdcdnm': "['피부관리사']", 'company_place': '서울 송파구', 'career': '경력 1년↑ · 정규직 외', 'education': '학력무관'}, page_content="경력- 주4일 잠실롯데호텔피부과-피부관리사 모십니다.\n\n채용공고 상세\n경력- 주4일 피부관리사 모십니다.기업 소개 또는 채용 안내를 작성해보세요. 불필요시 '소개글'을 OFF하면 소개 영역이 숨겨집니다."),
#  ...]

# %%
index_documents_to_es(index_name, documents)
# Out:
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
es_retriever = ElasticsearchRetriever(es, index_name, k=10)
hybrid_retriever = HybridRetriever(es_retriever, vector_retriever, alpha=0.5)

# %%
query = resume_text
docs = hybrid_retriever.get_relevant_documents(query)

for i, doc in enumerate(docs, 1):
    print(f"[{i}] 공고 번호: {doc.metadata.get('rec_idx')} | 회사: {doc.metadata.get('company_nm')}")
    print(doc.page_content[:200] + "...\n")
# Out:
# /root/miniconda3/envs/apps/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /tmp/ipykernel_1901/2073118433.py:9: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   vec_docs = self.vector_retriever.get_relevant_documents(query)
# [1] 공고 번호: 50226095 | 회사: (주)엘지씨엔에스
# 2025년 상반기 신입사원 채용 채용공고 상세
# ㈜LG CNS 2025년 상반기 신입사원 채용
# 솔루션·SI·ERP·CRM > SI·시스템통합, 시스템관리
# 기획·전략 > 직무·직업 > 웹기획
# 기획·전략 > 직무·직업 > 전략기획
# 기획·전략 > 직무·직업 > PL(프로젝트리더)
# 기획·전략 > 직무·직업 > PM(프로젝트매니저)
# 기획·전략 > 직무·직업 > PMO...
#
# [2] 공고 번호: 50280660 | 회사: (주)팜스토리 서울사료 인천
# (주)팜스토리서울사료 수의사 신입/경력 특별채용
#
#
# 사람인
#
#
#
# 본문 바로가기
# 2025년 상반기 공채 시작!
# 2025년 상반기 공채 시작!
# 로그인
#
# 회원가입
# 기업서비스
# 로그인
# 회원가입
#
# 기업홈
# 공고 등록
# 지원자 관리
# 인재풀
# 스마트 리크루터
# 인적성 · 평가도구
# HR매거진
# 채용상품
# 사람인 비즈니스
# 전체메뉴
# 채용정보
# 지역별
# 직업별
# 역세권별
# HOT100
# 헤...
#
# [3] 공고 번호: 49902739 | 회사: 블리비의원
# [서울] 블리비의원 상담실장 신규/추가 모집
#
#
# 사람인
#
#
#
# 본문 바로가기
# 2025년 상반기 공채 시작!
# 2025년 상반기 공채 시작!
# 로그인
#
# 회원가입
# 기업서비스
# 로그인
# 회원가입
#
# 기업홈
# 공고 등록
# 지원자 관리
# 인재풀
# 스마트 리크루터
# 인적성 · 평가도구
# HR매거진
# 채용상품
# 사람인 비즈니스
# 전체메뉴
# 채용정보
# 지역별
# 직업별
# 역세권별
# HOT100
# 헤드헌...
#
# [4] 공고 번호: 50283279 | 회사: 이지스터디학원
# 대구시 동구  수학학원강사 신입&경력 채용 ( 초중등 강사)
#
#
# 사람인
#
#
#
# 본문 바로가기
# 2025년 상반기 공채 시작!
# 2025년 상반기 공채 시작!
# 로그인
#
# 회원가입
# 기업서비스
# 로그인
# 회원가입
#
# 기업홈
# 공고 등록
# 지원자 관리
# 인재풀
# 스마트 리크루터
# 인적성 · 평가도구
# HR매거진
# 채용상품
# 사람인 비즈니스
# 전체메뉴
# 채용정보
# 지역별
# 직업별
# 역세권별
# H...
#
# [5] 공고 번호: 50273596 | 회사: 설연고학원
# 업계최고 복지 / 수지학원가 유명교육기업 / 수학 정규강사 채용
#
#
# 사람인
#
#
#
# 본문 바로가기
# 2025년 상반기 공채 시작!
# 2025년 상반기 공채 시작!
# 로그인
#
# 회원가입
# 기업서비스
# 로그인
# 회원가입
#
# 기업홈
# 공고 등록
# 지원자 관리
# 인재풀
# 스마트 리크루터
# 인적성 · 평가도구
# HR매거진
# 채용상품
# 사람인 비즈니스
# 전체메뉴
# 채용정보
# 지역별
# 직업별
# 역세권별...
